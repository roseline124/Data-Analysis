# %%
#-*-coding:utf-8

from selenium import webdriver
from time import sleep
import bs4

URL = "http://newsrank.hani.co.kr/"

driver = webdriver.Chrome("C:\chrome\chromedriver.exe")

driver.get(URL)
sleep(1)

# %%
YEAR = 13 # 13 : 2016, 14: 2017, 15: 2018
WEEK = 23 # 23주

# %%
# 컨트롤 

# 주간 선택 버튼 
week_button = driver.find_element_by_xpath('//*[@id="contents"]/div/div[1]/table/tbody/tr[1]/td/a[2]/img')
week_button.click()
sleep(0.5)

year = driver.find_element_by_xpath(f'//*[@id="s_year"]/option[{YEAR}]') 
year.click()
sleep(0.5)

week = driver.find_element_by_xpath(f'//*[@id="s_week"]/option[{WEEK}]')  
week.click()
sleep(0.5)

search_button = driver.find_element_by_xpath('//*[@id="contents"]/div/div[1]/table/tbody/tr[4]/td[2]/a/img')
search_button.click()
sleep(0.5)

# %%
html = driver.page_source
soup = bs4.BeautifulSoup(html, 'html.parser')

# %%
tags = soup.find_all("a")
txt = [t.getText().strip() for t in tags]
txt
# Out:
# ['본문 바로가기',
#  '전체',
#  '정치',
#  '정치일반',
#  '청와대',
#  '국회·정당',
#  '행정·자치',
#  '국방·북한',
#  '외교',
#  '정치BAR',
#  '사회',
#  '사회일반',
#  '여성',
#  '노동',
#  '환경',
#  '장애인',
#  '인권·복지',
#  '의료·건강',
#  '미디어',
#  '궂긴소식',
#  '인사',
#  '엔지오',
#  '교육',
#  '종교',
#  '전국',
#  '경제 Weconomy',
#  '경제일반',
#  '금융·증권',
#  '산업·재계',
#  '자동차',
#  '부동산',
#  '쇼핑·소비자',
#  'IT',
#  '직장·취업',
#  '중기·스타트업',
#  '기업PR',
#  '글로벌워치',
#  '국제',
#  '국제일반',
#  '해외토픽',
#  '아시아·태평양',
#  '미국·중남미',
#  '유럽',
#  '중국',
#  '일본',
#  '중동·아프리카',
#  '국제기구·회의',
#  '국제경제',
#  '문화',
#  '문화일반',
#  '영화·애니',
#  '방송·연예',
#  '여행·여가',
#  '음악·공연·전시',
#  '학술',
#  '책과 생각',
#  '제주&',
#  '스포츠',
#  '스포츠일반',
#  '축구·해외리그',
#  '야구·MLB',
#  '골프',
#  '경기일정',
#  '경기결과',
#  '바둑',
#  '미래과학',
#  '미래',
#  '과학',
#  '기술',
#  '환경',
#  '시각',
#  '애니멀피플',
#  '야생동물',
#  '반려동물',
#  '농장동물',
#  '인간과동물',
#  '생태와진화',
#  '오피니언',
#  '사설',
#  '칼럼',
#  '왜냐면',
#  '렌즈세상',
#  '만화',
#  'ESC',
#  '토요판',
#  '뉴스그래픽',
#  '퀴즈',
#  '연재',
#  '이슈',
#  '함께하는교육',
#  '헤리리뷰',
#  '사람',
#  '탐사보도',
#  '서울&',
#  '스페셜',
#  '기찬몸',
#  '휴심정',
#  '물바람숲',
#  '사진마을',
#  '베이비트리',
#  '미래 창',
#  '과학 읽기',
#  '포토',
#  '화보',
#  '포토스페셜',
#  '최신포토뉴스',
#  '카드뉴스',
#  '한겨레TV',
#  '시사·보도',
#  '교양·라이프',
#  '엔터테인먼트',
#  '스페셜',
#  '지식공감, 10분',
#  '시청자참여',
#  '뉴스서비스',
#  '많이본기사',
#  '날짜별한겨레',
#  '지난톱기사',
#  '디지털초판',
#  'PDF서비스',
#  'RSS서비스',
#  '기사제보',
#  '기사투고',
#  '매거진',
#  '한겨레21',
#  '씨네21',
#  '이코노미인사이트',
#  '사업',
#  '한겨레휴센터',
#  '테마여행',
#  '독자프리미엄서비스',
#  '고객센터',
#  '',
#  '회원가입',
#  '로그인',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '전광훈 목사 “문 대통령 하야 때까지 청와대 앞 릴레이 단식”',
#  '',
#  '황교안 ‘문화융성’ 이야기하자 이문열 “블랙리스트는 잘못”',
#  '',
#  '세월호 가족의 촛불 “헝가리 실종자, 단 한명이라도 살아 오길”',
#  '',
#  '“김정남 CIA 정보원이었다…위협 느낀 김정은이 살해 명령”',
#  '',
#  '인양 크레인 도착 이틀째, 헝가리 침몰 유람선 결속 작업 착수',
#  '',
#  '전체기사RSS',
#  'RSS페이지 목록',
#  '안드로이드',
#  'IOS',
#  '안드로이드',
#  'IOS',
#  '',
#  '',
#  '서비스 전체보기',
#  '전체',
#  '정치',
#  '정치일반',
#  '청와대',
#  '국회·정당',
#  '행정·자치',
#  '국방·북한',
#  '외교',
#  '정치BAR',
#  '사회',
#  '사회일반',
#  '여성',
#  '노동',
#  '환경',
#  '장애인',
#  '인권·복지',
#  '의료·건강',
#  '미디어',
#  '궂긴소식',
#  '인사',
#  '엔지오',
#  '교육',
#  '종교',
#  '전국',
#  '경제',
#  '경제일반',
#  '증권',
#  '부동산',
#  '금융·재테크',
#  '광고·마케팅',
#  '쇼핑·소비자',
#  '직장·창업·취업',
#  '자동차',
#  'IT',
#  '헤리리뷰',
#  '기업PR',
#  '국제',
#  '국제일반',
#  '해외토픽',
#  '아시아·태평양',
#  '미국·중남미',
#  '유럽',
#  '중국',
#  '일본',
#  '중동·아프리카',
#  '국제기구·회의',
#  '국제경제',
#  '문화',
#  '문화일반',
#  '영화·애니',
#  '방송·연예',
#  '여행·여가',
#  '음악·공연·전시',
#  '학술',
#  '책',
#  '스포츠',
#  '스포츠일반',
#  '축구·해외리그',
#  '야구·MLB',
#  '골프',
#  '경기일정',
#  '경기결과',
#  '바둑',
#  '과학',
#  '과학일반',
#  '과학기술',
#  '과학향기',
#  '오피니언',
#  '사설',
#  '칼럼',
#  '왜냐면',
#  '렌즈세상',
#  '만화',
#  'esc',
#  '토요판',
#  '뉴스그래픽',
#  '퀴즈',
#  '연재',
#  '이슈',
#  '함께하는교육',
#  '헤리리뷰',
#  '사람',
#  '탐사보도',
#  '스페셜',
#  '휴심정',
#  '물바람숲',
#  '사진마을',
#  '사이언스온',
#  '베이비트리',
#  '투코리아',
#  '스페셜+',
#  '미래 창',
#  '자료로 본 한국, 한국인',
#  '앱으로 여는 작곡세상',
#  '만화가게 아가씨',
#  '중동대전',
#  '도시잡기',
#  '슬로푸드',
#  '경제 신호등',
#  '여성생존백서',
#  '길과 풍경',
#  '포토',
#  '화보',
#  '포토스페셜',
#  '최신포토뉴스',
#  '카드뉴스',
#  '한겨레TV',
#  '시사·보도',
#  '교양·라이프',
#  '엔터테인먼트',
#  '스페셜',
#  '지식공감, 10분',
#  '시청자참여',
#  '많이본기사',
#  '날짜별한겨레',
#  '지난톱기사',
#  '디지털초판',
#  'PDF서비스',
#  'RSS서비스',
#  '기사제보',
#  '기사투고',
#  '한겨레21',
#  '씨네21',
#  '이코노미인사이트',
#  '한겨레경제사회연구원',
#  '한겨레휴센터',
#  '독자프리미엄서비스',
#  '고객센터',
#  '',
#  '',
#  '회사소개',
#  '구독신청',
#  '지면광고',
#  '온라인광고',
#  '사업제휴',
#  '채용',
#  '기사제보',
#  '투고',
#  '고객센터',
#  '고충처리',
#  'face book',
#  'twitter',
#  '저작권',
#  '회원약관',
#  '개인정보취급방침',
#  '지적재산보호정책',
#  '이메일주소 무단수집거부',
#  '사이트맵',
#  '한겨레 가족',
#  '하니누리',
#  '주주센터',
#  '한겨레출판',
#  '한겨레경제사회연구원',
#  '한겨레교육문화센터',
#  '한겨레통일문화재단',
#  '한겨레S&C',
#  '사람과디지털연구소']

# %%
week_headlines = []

for n in range(1,8):
    if n == 7 : 
        curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text
        curr_idx = txt.index(curr_week)
        check = txt[curr_idx+1]
        
        if check != '':
            headlines = txt[curr_idx+1:curr_idx+20]
            week_headlines.append(headlines)
        else :     
            week_headlines.append([])
            
    else :
        curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text # div2 / 1~7 주까지 있다
        next_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n+1}]/h4/a').text 
        curr_idx = txt.index(curr_week)
        next_idx = txt.index(next_week)

        headlines = txt[curr_idx+1:next_idx]

        week_headlines.append(headlines)
    
# week_headlines

# %% [markdown]
# ### 모듈화

# %%
def control_button(YEAR):
    # 주간 선택 버튼 
    week_button = driver.find_element_by_xpath('//*[@id="contents"]/div/div[1]/table/tbody/tr[1]/td/a[2]/img')
    week_button.click()
    sleep(0.5)

    year = driver.find_element_by_xpath(f'//*[@id="s_year"]/option[{YEAR}]') 
    year.click()
    sleep(0.5)

# %%
def search_news(WEEK):
    week = driver.find_element_by_xpath(f'//*[@id="s_week"]/option[{WEEK}]')  
    week.click()
    sleep(0.5)

    search_button = driver.find_element_by_xpath('//*[@id="contents"]/div/div[1]/table/tbody/tr[4]/td[2]/a/img')
    search_button.click()
    sleep(0.5)

# %%
def parse_page():
    html = driver.page_source
    soup = bs4.BeautifulSoup(html, 'html.parser')
    
    tags = soup.find_all("a")
    txt = [t.getText().strip() for t in tags]
    
    return txt

# %%
def collect_news(txt):
    week_headlines = []
    
    # empty인 경우 
    if txt[140] == '':
        return week_headlines.append([]*7)

    for n in range(1,8):
        if n == 7 : 
            curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text
            curr_idx = txt.index(curr_week)
            check = txt[curr_idx+1]

            if check != '':
                headlines = txt[curr_idx+1:curr_idx+20]
                week_headlines.append(headlines)
            else :     
                week_headlines.append([])

        else :
            curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text # div2 / 1~7 주까지 있다
            next_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n+1}]/h4/a').text 
            curr_idx = txt.index(curr_week)
            next_idx = txt.index(next_week)

            headlines = txt[curr_idx+1:next_idx]

            week_headlines.append(headlines)

    return week_headlines

# %%
def collect_res_news(txt, check):
    week_headlines = []

    # empty인 경우 
    if txt[140] == '':
        return week_headlines.append([]*7)
    
    for n in range(1,check+1):
        if n == check : 
            curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text
            curr_idx = txt.index(curr_week)
            check = txt[curr_idx+1]

            if check != '':
                headlines = txt[curr_idx+1:curr_idx+20]
                week_headlines.append(headlines)
            else :     
                week_headlines.append([])

        else :
            curr_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n}]/h4/a').text # div2 / 1~7 주까지 있다
            next_week = driver.find_element_by_xpath(f'//*[@id="news-rank"]/div[{n+1}]/h4/a').text 
            curr_idx = txt.index(curr_week)
            next_idx = txt.index(next_week)

            headlines = txt[curr_idx+1:next_idx]

            week_headlines.append(headlines)

    return week_headlines

# %%
def get_all_headlines(YEAR, WEEK):
    """
    년단위 주별 HOT 뉴스 크롤링
    """
    control_button(YEAR)
    
    WEEK += 6
    TIME = (52-WEEK)//7
    check = 52 - (WEEK + 7*TIME)

    # 검색
    all_headlines = []
    
    for n in range(TIME+1):
        search_news(WEEK + 7*n)

        txt = parse_page()
        week_headlines = collect_news(txt)
        all_headlines.append(week_headlines)

    # 나머지 뉴스
    search_news(52)
    txt = parse_page()
    week_headlines = collect_res_news(txt, check)
    all_headlines.append(week_headlines)

    return all_headlines

# %%
#-*-coding:utf-8

from selenium import webdriver
from time import sleep
import bs4

URL = "http://newsrank.hani.co.kr/"

driver = webdriver.Chrome("C:\chrome\chromedriver.exe") # 크롬드라이버 주소 바꾸기 

driver.get(URL)
sleep(1)

# 상수
YEAR = 14
WEEK = 1

# %%
WEEK += 6
TIME = (52-WEEK)//7
check = 52 - (WEEK + 7*TIME)

# 검색
for n in range(TIME+1):
    search_news(WEEK + 7*n)

    txt = parse_page()
    week_headlines = collect_news(txt)
    all_headlines.append(week_headlines)

# 나머지 뉴스
search_news(52)
txt = parse_page()
week_headlines = collect_res_news(txt, check)
all_headlines.append(week_headlines)

all_headlines
# Out:
# [[['[사회] [단독]특검, 이재용 15일께 재영장 방침…“최순실이 합병 도와” 진술 확보',
#    '[사회] [단독] 박상진 삼성 사장 메모에 “검찰 수사 받으면 삼성 폭발”',
#    '[사회] 박대통령, ‘독일 도피’ 최순실과 차명폰 127번 통화',
#    '[사회] [속보] 이재용 영장 발부…삼성 총수 첫 구속',
#    '[정치] 반기문 팽목항 방문 현장, 분노 유발 5장면',
#    '[사회] [단독] 518 진압군 ‘헬기 기총소사 추정 탄피’ 첫 발견',
#    '[사회] 고영태 “대통령은 최순실을 지킬 거니까”',
#    '[정치] 박대통령 탄핵심판 지연, 빤한 수법 5가지',
#    '[국제] “‘김정남 살해’ 추가 체포된 여성, 한국 여권 소지”',
#    '[과학] 인공지능 번역, 언어통일 시대가 오고 있다',
#    '[사회] [단독] 조동원 “친노좌파와 영화계 고리 끊어야” 안종범에 수차례 문자',
#    '[사회] 새벽 3시 368달러…내 카드가 미국에서 결제됐다',
#    '[사회] [단독]박통, 세월호 청문회 직전 “증인 성향 파악, 예상 Q&A 준비 철저” 지시',
#    '[정치] 조선일보 편집국장 출신 강효상 의원 “황교안, 특검 해임해야”',
#    '[사회] 정호성 “대통령, ‘정윤회문건’ 후 최순실에 문건 그만보내라 해”',
#    '[사회] 헌재 나온 이동흡 “대한민국과 결혼한 대통령, 따뜻하게 봐야”',
#    '[사회] [속보] 법원, 특검 “청와대 압수수색 허용해달라” 신청 각하',
#    '[정치] 박 대통령 대리인 손범규 변호사 “터무니없는 탄핵…국회 오만방자”',
#    '[국제] ‘김정남 살해’ 여성 용의자 호텔방서 100달러 지폐 3장 발견',
#    '[정치] [포토] CCTV에 포착된 김정남 피살 용의자 보니…'],
#   ['[정치] 목소리까지 갖춘 귀상?…‘황교안 대망론’ 뜯어보니',
#    '[정치] 국민의당 강연재 부대변인, 촛불시민 두고 “구태국민” 망언',
#    '[사회] 이러려고 증인 신청? 대통령 대리인 횡설수설에 재판관 “이해 안돼”',
#    '[사설·칼럼] [편집국에서] 재판관은 아스팔트 위에 서있지 않다 / 박용현',
#    '[정치] “촛불집회에 ‘북한이 희망’ 깃발” 새누리 막장 색깔론',
#    '[정치] 새누리 ‘표창원 사퇴 ’ 시위에 이재정 의원 ‘사이다 돌직구 ’',
#    '[정치] “권력 휘두르면 큰 화 입는다”던 조윤선, 정작 본인은 왜?',
#    '[사회] 고영태 “최순실이 장관 앉히는 거 보고 겁나 그만뒀다”',
#    '[사회] [단독] 특검, 공정위 압수수색때 ‘청와대 외압일지’ 발견',
#    '[정치] 박대통령 탄핵심판 지연, 빤한 수법 5가지',
#    '[사회] 최순실-이성한 설전 “대체 뭘로 녹음한 거냐”',
#    '[경제] [단독] 전경련, 사회공헌기금 25억 보수단체에 쏟아부었다',
#    '[사회] “황교안, 청와대 수색 승인하라” 유명인시민들 특검 응원',
#    '[사회] [단독] 조동원 “친노좌파와 영화계 고리 끊어야” 안종범에 수차례 문자',
#    '[정치] 조선일보 편집국장 출신 강효상 의원 “황교안, 특검 해임해야”',
#    '[사회] [단독]박근혜-최태원 ‘사면 거래’…특검, 교도소 녹음파일 확보',
#    '[정치] 박 대통령 대리인 손범규 변호사 “터무니없는 탄핵…국회 오만방자”',
#    '[사회] [단독] 최순실, 관세청 차장국장인천세관장 인사도 개입',
#    '[정치] 문재인, 다자양자 모두 1위…안희정도 급부상',
#    '[사회] 헌재, 2월 탄핵 선고 물건너가…22일까지 증인신문'],
#   ['[사회] [단독] “챙겨줘 고마우이” 유재경 입열게 한 문자메시지',
#    '[정치] 목소리까지 갖춘 귀상?…‘황교안 대망론’ 뜯어보니',
#    '[사회] [단독]청와대, 4대기업 70억 걷어 ‘아스팔트 우파’ 지원',
#    '[사회] 김기춘 “뿌리 깊은 좌파 척결에 불퇴전 각오로 싸워라” 지휘',
#    '[정치] 반기문 “TV 화면 보니 촛불 민심 변질됐다는 기분 들어”',
#    '[정치] 새누리 ‘표창원 사퇴 ’ 시위에 이재정 의원 ‘사이다 돌직구 ’',
#    '[정치] “권력 휘두르면 큰 화 입는다”던 조윤선, 정작 본인은 왜?',
#    '[정치] 반기문의 ‘기이한 하루’…불출마 30분전 심상정 만나',
#    '[정치] “동생 하는 일 잘 모른다”더니…반기문, 동생 소개로 중국 기업인 만나',
#    '[사회] “국내 3위 사랑의교회 목사를 끌어내리겠다니… ”',
#    '[정치] “황교안은 필패 카드” 여권서 ‘비토론’ 쏟아져',
#    '[사회] [단독] “최순실, 매달 청와대서 대통령 옷값 1000만원씩 건네”',
#    '[정치] 반, 불출마 선언문 주머니 넣은채 3당 차례로 예방한 뒤 깜짝 회견',
#    '[사회] [속보] 특검, 청와대 곧 압수수색…민정실의무실 등 최대규모',
#    '[사회] “황교안, 청와대 수색 승인하라” 유명인시민들 특검 응원',
#    '[사회] 박근혜 정부, 한국사회 전 분야 ‘블랙리스트’ 만들었다',
#    '[사회] [단독]우병우, ‘특별감찰관실 해체’ 주도...법무부 검찰국 관여 정황',
#    '[사회] [단독] 조윤선 구속 결정적 계기는 ‘고엽제전우회 데모’ 지시였다',
#    '[사회] [단독] 인천세관장 ‘최순실에 상품권 보은’ 의혹 일자 사표',
#    '[사회] 검찰이 불기소한 김진태, 선거법 위반 재판받는다'],
#   ['[정치] [단독] 반기문 조카 10여년 병역기피 ‘지명수배’ 드러나',
#    '[정치] 국민의당 강연재 부대변인, 촛불시민 두고 “구태국민” 망언',
#    '[정치] [단독] 선관위 전체회의도 안 열고 “반기문 출마 가능”',
#    '[정치] 정두언 “‘반기문 종쳤다’는 말, 반 캠프분들도 공감”',
#    '[정치] 표창원, ‘대통령 풍자 누드’ 전시회 주최로 당 윤리심판원 회부',
#    '[정치] 30년 청와대 경호원 “관저근무? 더 이상 헛소리 마라”',
#    '[정치] “동생 하는 일 잘 모른다”더니…반기문, 동생 소개로 중국 기업인 만나',
#    '[사회] “국내 3위 사랑의교회 목사를 끌어내리겠다니… ”',
#    '[사회] [단독] “최순실, 매달 청와대서 대통령 옷값 1000만원씩 건네”',
#    '[사회] ‘기춘대원군’, ‘대통령의 여자’ 모두 구속',
#    '[정치] 반기문, 장관 퇴직때 재산 11억 신고…현재는 20억 넘어',
#    '[만화·만평] 1월 18일 한겨레 그림판',
#    '[사회] [포토]최순실 “억울하다” 소리 치자 들려온 한 마디는…',
#    '[사회] 강제소환 최순실 “억울하다…민주 특검 아니다” 고성',
#    '[정치] 반기문 20% 붕괴-문재인 30% 육박',
#    '[정치] 황교안 , ‘대통령 놀이 ’ 비판 바른정당에 “이럴거냐 ” 항의전화',
#    '[사회] 새벽 3시 368달러…내 카드가 미국에서 결제됐다',
#    '[사회] [단독] 조윤선 구속 결정적 계기는 ‘고엽제전우회 데모’ 지시였다',
#    '[사회] 대통령 쪽 공정성 문제 삼자, 헌재 “재판부에 대한 모독”',
#    '[사회] 박한철 헌재소장 “3월13일 전 탄핵심판 최종 결정돼야”'],
#   ['[사회] [단독] “반기문 아무리 부인해도 ‘박연차 리스트’에 적힌 건 팩트”',
#    '[사회] [단독] 조윤선, 어버이연합 ‘반세월호 집회’ 열도록 주도',
#    '[정치] [단독] 반기문 쪽 인천공항에 ‘특별 의전’ 요구했다 ‘퇴짜’',
#    '[사회] [단독] 박연차, 검찰도 몰랐던 ‘반기문 이름’ 스스로 리스트에 적어 내',
#    '[사회] [단독] 김기춘, 박대통령에 ‘블랙리스트’ 보고했다',
#    '[정치] 반기문 팽목항 방문 현장, 분노 유발 5장면',
#    '[정치] 정두언 “‘반기문 종쳤다’는 말, 반 캠프분들도 공감”',
#    '[사회] 법원, 사랑의교회 도로 점용 “취소하라”',
#    '[정치] 30년 청와대 경호원 “관저근무? 더 이상 헛소리 마라”',
#    '[사회] “국내 3위 사랑의교회 목사를 끌어내리겠다니… ”',
#    '[사회] [단독] 박 대통령 “CJ 좌파성향 바꿔라” 손경식 “죄송, 모두 정리”',
#    '[사회] ‘기춘대원군’, ‘대통령의 여자’ 모두 구속',
#    '[만화·만평] 1월 18일 한겨레 그림판',
#    '[사회] [속보] 이재용 영장 기각…특검팀, 박 대통령 뇌물 수사 차질',
#    '[사회] 새벽 3시 368달러…내 카드가 미국에서 결제됐다',
#    '[사회] 최순실, ‘정유라 특혜 대응문건’도 작성…이대 전달 정황',
#    '[사회] 특검 , 이재용 ‘뇌물공여 혐의 ’ 사전구속영장 청구',
#    '[사회] 최순실 “김기춘 모른다…차은택에 물어보라” 쏘아붙여',
#    '[정치] “반기문 동생, ‘유엔대표단’ 직함 달고 미얀마서 사업”',
#    '[경제] [현장에서] 삼성 ‘4번의 말바꾸기’와 뒤늦은 ‘후회’'],
#   ['[사회] [단독] 박 대통령 한화 독대 말씀자료에 “면세점 황금티켓 땄으니…재단 지원을”',
#    '[사회] [단독] 박대통령 , 2015년초 “정유라 키워야” 콕 찍어 지원 지시',
#    '[정치] [단독] 반기문 쪽 인천공항에 ‘특별 의전’ 요구했다 ‘퇴짜’',
#    '[사회] [단독] 조윤선 수석실, 문화계 ‘적군리스트’ 만들어 특별관리',
#    '[사회] 박근혜를 예수에 비유…‘궤변 변론’ 서석구 변호사는 누구?',
#    '[정치] 사생활 집착한 박근혜에게 청와대는 최적화된 ‘시크릿 가든’',
#    '[사회] [단독] 김기춘, 박대통령에 ‘블랙리스트’ 보고했다',
#    '[사회] 법원, 사랑의교회 도로 점용 “취소하라”',
#    '[사회] 헌재 “박 대통령 세월호 7시간 행적 다시 제출하라”',
#    '[정치] 30년 청와대 경호원 “관저근무? 더 이상 헛소리 마라”',
#    '[사회] 신동욱, 박지만 수행비서 죽음에 ‘타살 의혹’ 제기',
#    '[사회] 최순실, 재판서 변희재를 증인으로 신청',
#    '[사회] 검찰 “계속 되는 증거 부동의, 대통령이 배후냐” 강력 반발',
#    '[사회] 주심 강일원 재판관, 박 대통령 불성실한 답변에 불만',
#    '[정치] [생중계] ‘최순실 국정농단’ 7차 청문회',
#    '[정치] 그분 옥바라지는 대체 누가 할까',
#    '[사회] 최순실, ‘정유라 특혜 대응문건’도 작성…이대 전달 정황',
#    '[사회] 촛불은 민심 아니라고?… 누리꾼들 “박근혜는 대통령 아니거든!”',
#    '[사회] [팩트체크] “김대중노무현도 관저정치”? 박대통령의 거짓궤변',
#    '[정치] 다음 ‘여성 대통령’ 꿈도 꾸지 말라는 이들에게'],
#   ['[사회] [단독]박 대통령, ‘정윤회 문건’ 터지자 “최순실 자문 멈춰라” 지시',
#    '[사회] [단독] 박대통령, 네덜란드 국왕에도 ‘최순실 지인회사’ 민원 정황',
#    '[사회] 박지만 수행비서 숨진채 발견돼',
#    '[사회] [단독] 우병우 민정실 “최순실 죄 안된다” 대통령에 보고',
#    '[문화] [단독] “조윤선 장관 취임 뒤 블랙리스트 파기 지시 내려와”',
#    '[사회] [단독] 박 대통령 한화 독대 말씀자료에 “면세점 황금티켓 땄으니…재단 지원을”',
#    '[사회] [단독] ‘기치료 아줌마’는 70대 오씨...“지난 여름까지 청와대 출입”',
#    '[사회] 박대통령 “세월호 참사 작년인가, 재작년인가” 발언 파문',
#    '[사회] ‘버럭’ 전원책 막무가내 토론, 논란의 세가지 장면',
#    '[사회] 박근혜를 예수에 비유…‘궤변 변론’ 서석구 변호사는 누구?',
#    '[사회] [단독] 정부, 국민의례때 ‘세월호, 518 묵념 금지’ 못박아',
#    '[사회] 정유라 어제 덴마크서 체포... 아들 등 4명 검거',
#    '[사회] 대통령 대리인단 “촛불 민심은 국민 뜻 아냐”…색깔론까지',
#    '[사회] 박 대통령 쪽 “윤석열 수사팀장 못믿어…증거 인정 못해”',
#    '[사회] 신동욱, 박지만 수행비서 죽음에 ‘타살 의혹’ 제기',
#    '[사회] [단독] 최순실, 새누리 최고위원 인선까지 개입했다',
#    '[사회] 특검 “김기춘조윤선, 문화계 블랙리스트 개입 확인”',
#    '[사회] [영상] 박사모 집회서 박근혜 규탄 발언한 남성 화제',
#    '[정치] 안희정, 손학규 향해 “어떻게 동지가 해마다 바뀌냐”']],
#  [['[정치] 홍준표의 손석희 ‘뉴스룸’ 인터뷰 황당했던 순간3',
#    '[만화·만평] 3월 31일 한겨레 그림판',
#    '[사회] 성균관대 사물함 2억원 주인은 최유정 변호사 부부',
#    '[정치] [팩트체크] 안철수 기념사진 청년들 ‘조폭’인지 확인해보니…',
#    '[문화] ‘친일 논란’ 강동원 외증조부 이종만, 그는 노동운동가였다?',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[사회] 김대두, 그는 정말 연쇄살인범이었을까',
#    '[사회] 43추념식 봉행…황교안, 추모사 절반 “제주 관광” 딴소리',
#    '[사회] 전두환 회고록 첫날 판매량 보니…',
#    '[정치] ‘문재인-안철수 양자대결’은 허상이다',
#    '[사회] ‘박 전 대통령 영장심사’ 강부영 판사-서향희 변호사 ‘인연’ 주목',
#    '[정치] 안철수? 기권? 보수 후보?…‘멘붕 보수’의 세 갈래 길',
#    '[사회] 전직 노조위원장이 전하는 감옥살이 노하우 “박근혜씨 유캔두잇”',
#    '[정치] 민주당 이언주 의원 “안철수 돕겠다”…이르면 6일 탈당',
#    '[사회] 박 전 대통령, 3.2평 독방서 1440원 식단…직접 설거지',
#    '[국제] 미, 시리아 공군기지에 토마호크 60발 발사…화학무기 ‘응징’',
#    '[정치] [리스티클] 탄핵부터 구속까지, 우리의 예상을 깬 15가지 순간',
#    '[사회] [속보] 세월호 육지로 옮기기 늦어진다',
#    '[정치] 홍준표가 떠올리게 한 ‘방명록 망신살’',
#    '[사회] 윤병세 장관, 위안부 피해자 할머니 빈소 찾지 않고 방명록에 이름만'],
#   ['[사회] 박지만 수행비서 숨진채 발견돼',
#    '[정치] [그래픽뉴스] ‘최후의 방패’ 유영하를 보면 박근혜가 보인다',
#    '[정치] 헉! 소리나는 박 대통령의 변호사들',
#    '[사회] “세월호 2층 화물칸 벽, 철제 대신 천막으로 막아”',
#    '[사회] 박근혜 전 대통령 구속',
#    '[사회] 검찰, 박 전 대통령 ‘뇌물죄 적용’ 구속영장 청구',
#    '[만화·만평] 3월 31일 한겨레 그림판',
#    '[사회] [단독] 박 전 대통령 “포토라인 안 서게 해달라”…법원서 거부',
#    '[사회] ‘박근혜의 운명’ 손에 쥔 강부영 판사, 과거 이력 보니',
#    '[사회] [속보] 굳은 표정 박 전 대통령, 아무말없이 법정 올라가',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[사회] 삼성동 자택앞 친박 시위대, 등교 학생에 “빨갱이 나라서…”',
#    '[정치] 야권, 문재인 ‘전두환 표창장’ 난타…누리꾼 “심하다”',
#    '[사회] [단독] 신연희 “세월호, 문재인 책임”…카톡 비방글 또 나왔다',
#    '[사회] 세월호 침몰 원인 ‘안갯속’, 증거물 소홀히 다루는 해양수산부',
#    '[정치] 호남 ‘큰 산’ 넘은 문재인, 결선투표 없이 본선 직행하나',
#    '[사회] ‘세월호 리본 구름’은 진짜 하늘의 선물…“숨이 멎는 줄”',
#    '[사회] ‘박 전 대통령 영장심사’ 강부영 판사-서향희 변호사 ‘인연’ 주목',
#    '[경제] 세월호 참사 증거물 ‘선미 램프’ 왜 잘려 나갔나?',
#    '[사회] [속보] 세월호 목포신항 도착…1080일만에 뭍으로 오다'],
#   ['[경제] 1073일 만에 물 밖으로 나온 세월호는 처참했다',
#    '[정치] 전여옥 “박근혜, 도덕관념 없는 아모랄…검사, 뒷목 잡았을것”',
#    '[사회] [단독] 신연희 구청장 “놈현문죄인 엄청난 비자금” 유포 논란',
#    '[경제] [속보] 1073일 어둠을 뚫고…세월호 물위로 떠오르다',
#    '[정치] 문재인 4%p 하락안희정 5%p 상승…민주 경선 불붙는다',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[English Edition] Lee Jae-hoon apologizes real estate speculation during hearing',
#    '[정치] 야권, 문재인 ‘전두환 표창장’ 난타…누리꾼 “심하다”',
#    '[사회] [단독] 신연희 “세월호, 문재인 책임”…카톡 비방글 또 나왔다',
#    '[사회] ‘세월호 리본 구름’은 진짜 하늘의 선물…“숨이 멎는 줄”',
#    '[사회] 14시간 격돌...검, 정유라삼성 추궁에 박 “그런적 없다” 발뺌',
#    '[경제] 세월호 참사 증거물 ‘선미 램프’ 왜 잘려 나갔나?',
#    '[정치] 유시민, 문재인 ‘전두환 표창’ 논란에 “수준 이하 난독”',
#    '[사회] 검찰 “박 전 대통령 조사 마친 뒤 귀가 방침”…긴급체포 않을 듯',
#    '[사회] 김평우 변호사 “박 전 대통령 만나…그는 순교자, 존경한다”',
#    '[경제] 정부, 4대강 수질악화 인정…“보 열어 물 대량 방류”',
#    '[English Edition] Special Prosecutor ends 90-day investigation referring 17 people for trial',
#    '[사회] 박 전 대통령 자택 출발…아무 말 없이 차에 타',
#    '[사회] 3년 만에 떠오른 세월호, “이렇게 꺼낼 수 있는 것을…”',
#    '[경제] “삼성을 살린 판결이 결국 이재용을 잡은 셈이 됐다”'],
#   ['[국제] ‘방송 사고’ 켈리 교수, “문 잠그는 것 깜빡”',
#    '[사회] 제 꾀에 넘어간 박근혜…헌재 , 수사 거부 문제삼아',
#    '[경제] [단독] ‘이건희 동영상’ 혐의 CJ 부장, 이맹희 의전 담당이었다',
#    '[경제] “격려금도 줘”…‘최순실 유착 주역’ 이승철의 후안무치',
#    '[국제] 외신, 박근혜 탄핵 긴급 타전…“비극적 정치의 종언”',
#    '[사회] “통진당은 대역행위” 안창호 재판관, 탄핵 찬성한 까닭은',
#    '[정치] ‘워킹맘’ 이정미 재판관, 6년 전 인터뷰 보니…',
#    '[사회] 대통령 박근혜를 파면한다',
#    '[사회] [단독] 전경련 “허현준 행정관, 돈 맡긴 듯 ‘아스팔트 보수’ 지원 요구”',
#    '[사회] [전문] 헌재 전원일치 ‘대통령 파면’ 결정문',
#    '[사회] “간첩이다”…지지자들 고성과 아침 맞은 박 전 대통령 자택',
#    '[사회] ♬앞뒤가 똑같은 민↗정↗수↘석~ ‘우병우 구속가’ 나왔다',
#    '[경제] [속보] 이승철 전경련 상근고문직격려금 못받는다',
#    '[사회] 박근혜 자택옆 초등학교 ‘봉변’…박사모 집회 제한 가능할까?',
#    '[정치] 황교안, 대선 불출마…5월9일 대선일 지정',
#    '[사회] 김평우 변호사 “박 전 대통령 만나…그는 순교자, 존경한다”',
#    '[사회] [속보] 검찰, ‘피의자 박근혜’ 21일 오전 9시30분 소환 통보',
#    '[사회] ‘촛불집회 1억 빚’ 소식에…시민들 십시일반 8억 모아',
#    '[국제] 덴마크 검찰 “정유라 한국 보내기로 결정”',
#    '[사회] ‘올림머리’ 미용사, 박근혜 삼성동 자택 찾아…오늘 외부 일정 있나'],
#   ['[사회] 임은정 검사 “황교안 특검 연장 불허, 너무 걱정마시라”',
#    '[사회] [단독] 이병기 전 원장 “국정원, 보수단체에 돈 댔다” 실토',
#    '[사회] “누구 좋으라고”…정미홍 “목숨 내놓겠다” 발언 번복',
#    '[사회] 제 꾀에 넘어간 박근혜…헌재 , 수사 거부 문제삼아',
#    '[정치] “박정희 스위스 비자금 수조원대…최순실이 세탁”',
#    '[국제] 외신, 박근혜 탄핵 긴급 타전…“비극적 정치의 종언”',
#    '[사회] “통진당은 대역행위” 안창호 재판관, 탄핵 찬성한 까닭은',
#    '[사회] [단독] 우병우, 수사대상 때 검찰국장과 1000여차례 통화',
#    '[사회] 헌재 “최순실이 국정개입” 만장일치 대통령 파면',
#    '[사회] 박 대통령 대리인들이 막가는 까닭',
#    '[문화] ‘친일 논란’ 강동원 외증조부 이종만, 그는 노동운동가였다?',
#    '[사회] 대통령 박근혜를 파면한다',
#    '[사회] 국가가 정한 정년은 60살, 삼성화재 정년은 50살?',
#    '[사회] ‘탄핵열차 종착역’ 10일 오전 11시',
#    '[사회] “국민 여러분, 죄송합니다” 박영수 특검이 머리 숙인 까닭',
#    '[사회] 흙수저? 이선애 내정자, 28년전 한겨레에 ‘독자투고’한 이유',
#    '[사회] 박 전 대통령, 오늘 삼성동 사저로 안간다',
#    '[사회] 박영수 특검 “박대통령, 뇌물수수 혐의 확인했다”',
#    '[사회] [전문] 헌재 전원일치 ‘대통령 파면’ 결정문',
#    '[사회] 이건희 성매매 동영상, CJ그룹 직원이 촬영 지시'],
#   ['[사회] 임은정 검사 “황교안 특검 연장 불허, 너무 걱정마시라”',
#    '[정치] 국민의당 강연재 부대변인, 촛불시민 두고 “구태국민” 망언',
#    '[정치] 헉! 소리나는 박 대통령의 변호사들',
#    '[정치] “박정희 스위스 비자금 수조원대…최순실이 세탁”',
#    '[사회] 대통령쪽, 최후진술도 우왕좌왕…“당뇨 있어” 또 생떼',
#    '[사회] [단독] 우병우, 수사대상 때 검찰국장과 1000여차례 통화',
#    '[사회] [단독] 김진태 검찰총장 “세월호 해경수사팀 해체하라”압력 의혹',
#    '[사회] [르포] 태극기집회 참가해보니…“젊은 사람이 기특하네”',
#    '[정치] 하태경 “황교안 권한대행 기념시계, 대통령 탄핵 기념하는 거냐”',
#    '[사회] ‘빨갱이는 죽여도 돼’ 일베스님과 인증샷 찍은 MBC 언론인',
#    '[정치] 국민의당, ‘특검 연장 불허’ 황교안 탄핵 추진',
#    '[정치] 황교안 대행 “특검 수사기간 연장 요청, 승인 않기로 결정”',
#    '[사회] 막장 치닫는 탄핵반대…특검문재인손석희 집 앞 ‘위협시위’',
#    '[사회] 박대통령 서면 최후진술 “법과 원칙 지키는 사람이 잘 사는 세상 소망했다”',
#    '[정치] 문재인 “박근혜-황교안, 부끄러움도 없는 최악의 한 팀”',
#    '[정치] 김문수, 119전화 ‘나 도지사인데’ 발언 “내가 아주 잘한 것”',
#    '[문화] 태극기 휘두르며 ‘빨갱이 죽여도 된다’ 외치는 이들에게…',
#    '[사회] 김기춘 “구속될 사람은 특검” 적반하장',
#    '[경제] “삼성을 살린 판결이 결국 이재용을 잡은 셈이 됐다”',
#    '[사회] “탄핵은 반란, 김정은이 촛불 부추겨”… 대통령쪽 최후변론도 ‘종북몰이’'],
#   ['[사회] [단독] 박상진 삼성 사장 메모에 “검찰 수사 받으면 삼성 폭발”',
#    '[정치] 헉! 소리나는 박 대통령의 변호사들',
#    '[사회] 박근혜를 예수에 비유…‘궤변 변론’ 서석구 변호사는 누구?',
#    '[정치] “박정희 스위스 비자금 수조원대…최순실이 세탁”',
#    '[사회] 대통령쪽 “헌재, 약한 여자 편 안들고 국회 편들어” 막말',
#    '[사회] [단독]최순실, 인수위 시기 대법관 및 3대 사정기관 후보 19명 ‘인사자료’ 수집',
#    '[사회] “재판관 9명 못 채우면 내란 일어날 수도” 협박까지',
#    '[정치] 하태경 “황교안 권한대행 기념시계, 대통령 탄핵 기념하는 거냐”',
#    '[국제] 순식간에…김정남 피습 당시 CCTV 영상 첫 공개',
#    '[사회] ‘빨갱이는 죽여도 돼’ 일베스님과 인증샷 찍은 MBC 언론인',
#    '[사회] 국회의장까지 증인 신청…박대통령쪽 ‘막가파식 지연작전’',
#    '[정치] 정치권 “박근혜, 탄핵 불복형 자진사퇴” 가능성 솔솔',
#    '[정치] 황교안, 특검연장 사실상 거부…야4당 “직권상정 추진”',
#    '[사회] 대통령 대리인 “왜 함부로 재판 진행해요” 헌재서 난동',
#    '[사회] ‘법망’ 찢은 우병우…구속영장 기각',
#    '[사회] “골드바, 택배왔습니다”…사립유치원, 교육청 감사 저지 ‘로비’',
#    '[사회] [단독] 최순실 ‘집사변호사’ 인사자료엔 “법조 생불” “MB때 벼락성장”',
#    '[국제] 말레이 경찰 “북한 대사관 직원도 김정남 살해 연루”',
#    '[정치] 문재인 32%안희정 21%…안철수황교안이재명 8%']],
#  [['[사회] [단독] 87년 6월 이한열 열사 피격 전후 사진 최초 공개',
#    '[사회] [단독] 넥슨, 우병우 처가땅 알고 거래…검찰, 확인하고 덮어',
#    '[정치] 문 대통령 “4대강 6개보, 6월1일부터 상시 개방” 지시',
#    '[정치] 국민의당 강연재 부대변인, 촛불시민 두고 “구태국민” 망언',
#    '[사회] [영상] ‘돈 봉투 만찬’ 안태근 검찰국장 답변 태도 다시 논란',
#    '[국제] 중국, 특사단에 사드 관련 ‘황교안 파문’ 직접 언급',
#    '[사회] 김무성, 캐리어 ‘노 룩 패스’ 논란에 “그걸 왜 해명해야 해?”',
#    '[사회] 박 전 대통령쪽, ‘돈봉투 만찬’ 거론하며 혐의 부인',
#    '[사회] [단독]‘대한노인회 혜택’ 발의한 이낙연, 간부에 1500만원 후원금 받아',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[정치] 이낙연 “교사 아내 강남학교 가려 위장전입…국민이 평가해달라”',
#    '[사회] 광주교도소 사건서 ‘사라진 17명’…군, 명단 공개해야',
#    '[사회] “가뭄 걱정 말라더니…‘4대강 탓’ 물 말라 농사꾼만 죽어나”',
#    '[정치] ‘정치 종가’ 동교동계의 패배…국민의당 ‘탈당 카드’ 속내는?',
#    '[정치] [단독] ‘종교인 과세 2년 더 유예’ 총대 멘 김진표 국정기획위원장',
#    '[정치] [단독] 전작권, 3~4년 앞당겨 2020년대초 환수 추진',
#    '[사회] 53일만에 모습 드러낸 박 전 대통령…사복에 올림머리',
#    '[정치] 쌈짓돈, 검은돈, 뻔뻔한 돈…특수활동비 흑역사',
#    '[사회] 김혜숙 교수, 이대 총장 당선',
#    '[정치] 문 대통령 “우리는 다시 실패하지 않을 것”'],
#   ['[사회] [단독] 국정농단 수사팀-조사대상 검찰국장…‘부적절한’ 만찬',
#    '[사회] [단독] 87년 6월 이한열 열사 피격 전후 사진 최초 공개',
#    '[사회] “요것이 바로 진정한 기념식이여…”',
#    '[사회] ‘버럭’ 전원책 막무가내 토론, 논란의 세가지 장면',
#    '[전체기사] 진짜판별기 메인페이지',
#    '[사회] [영상] ‘돈 봉투 만찬’ 안태근 검찰국장 답변 태도 다시 논란',
#    '[정치] ‘저질 막말’ 홍준표와 손잡은 ‘바르지 못한’ 의원들',
#    '[사회] [단독] 보안사, 비밀조직 꾸려 “518 폭동”으로 조작',
#    '[정치] 문 대통령 관저 입주 늦어진 이유가…박근혜 ‘거울방’ 때문?',
#    '[만화·만평] 5월 15일 한겨레 그림판',
#    '[정치] 서울중앙지검장에 ‘국정농단 수사팀장’ 윤석열 임명',
#    '[정치] ‘부탄 예찬’ 문 대통령, 행복 정책 도입할까',
#    '[정치] “어금니 꽉 깨문” 문 대통령, 검찰 개혁 이번엔 다르다',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[정치] 청와대, ‘박근혜최순실 측근’ 이영선 경호관 직위해제',
#    '[사회] ‘돈봉투 만찬 물의’ 안태근 법무부 검찰국장이영렬 서울중앙지검장 사의 표명',
#    '[정치] 이낙연 “아들 공익근무라도 희망한다” 탄원서 공개',
#    '[문화] 성유리안성현 결혼했다',
#    '[정치] 청와대, ‘노무현 전 대통령 일베 이미지’ 내보낸 SBS에 “매우 유감”',
#    '[사회] 문 대통령이 518 기념사에서 호명한 ‘광주 열사’ 4명 누구'],
#   ['[사회] [단독] 우병우 민정실 “최순실 죄 안된다” 대통령에 보고',
#    '[정치] 문 대통령 최측근 ‘3철’ 엇갈린 행로 눈길',
#    '[정치] 비서실장 임종석, 안보실장 서훈…호남 총리 확실',
#    '[정치] 국민의당 강연재 부대변인, 촛불시민 두고 “구태국민” 망언',
#    '[전체기사] 진짜판별기 메인페이지',
#    '[정치] ‘저질 막말’ 홍준표와 손잡은 ‘바르지 못한’ 의원들',
#    '[정치] [영상] 홍준표 ‘장인 영감탱이’ 발언 패륜 논란으로 번져',
#    '[정치] 민주 지도부 ‘공직 인사추천위 구성’ 싸고 불협화음',
#    '[정치] 30년 청와대 경호원 “관저근무? 더 이상 헛소리 마라”',
#    '[정치] 민정수석 조국인사수석 조현옥홍보수석 윤영찬 임명',
#    '[정치] 화려한 인맥과 거리 먼 문재인 가족…부모형제자녀 모두 ‘소시민’',
#    '[정치] 첫 총리 내정자 이낙연 전남지사 “신명 다해 소임을 수행하겠다”',
#    '[경제] 재벌, ‘문재인 대통령’ 취임 축하 광고…삼성만 ‘소녀 사진’',
#    '[정치] 안희정, 문재인에 ‘기습 뽀뽀’…“광화문 맥주 동나게 하자”',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[정치] 이낙연 “아들 공익근무라도 희망한다” 탄원서 공개',
#    '[정치] 문 대통령, 인천공항 비정규직 1만명 정규직화 약속',
#    '[정치] “문재인 간택” 논평 국민의당 대변인, 이번엔 누리꾼에 막말',
#    '[정치] ‘국정원 댓글 수사’ 박형철, 반부패비서관에',
#    '[정치] 박영선 “심상정 노동부 장관? 가능한 이야기”'],
#   ['[정치] 문재인의 ‘대구’ 안철수의 ‘광주’…지역민심 들어보니',
#    '[전체기사] 진짜판별기 메인페이지',
#    '[정치] ‘저질 막말’ 홍준표와 손잡은 ‘바르지 못한’ 의원들',
#    '[정치] “박정희 스위스 비자금 수조원대…최순실이 세탁”',
#    '[정치] 김성태홍문표 등 13명 “바른정당 탈당” 선언',
#    '[국제] 트럼프 ‘본색’…한국에 사드 비용 1조1300억 요구',
#    '[정치] 이준석 “배신자도 과분, 그들은 ‘쫄보’”',
#    '[정치] ‘자유한국당 복귀’ 장제원 2008년 고함치던 흑역사 영상 화제',
#    '[정치] 유진룡 “블랙리스트는 홀로코스트…처벌받아야 할 사람 더 있다”',
#    '[정치] 홍준표 “국정농단 친박들 다 용서하자”…‘적폐’ 세력 끌어안기',
#    '[정치] 문재인, 대통령 당선보다 더 어려운 과제 두 가지',
#    '[정치] 노회찬 “김종인은 대리기사, 안철수는 3수 준비해야”',
#    '[정치] [영상] 박주민 “문재인 대통령 만들어 실컷 부리자” 연설 화제',
#    '[정치] 홍준표 “당헌 발동해 오늘 친박계 복권시키겠다”',
#    '[사회] 대선 코앞 ‘색깔론 망령’…13번 자리 ‘인공기’ 덧칠',
#    '[국제] 미국 “사드 비용 재협상까지만 준수”…청와대 설명 정면 반박',
#    '[문화] 이동건조윤희 부부 됐다',
#    '[정치] [영상] 이은재가 바른정당 탈당한 이유는 ‘사모님’ 때문?',
#    '[사회] SBS ‘세월호 인양 해수부-문재인 거래 의혹’ 보도 사과',
#    '[사회] ‘유승민 딸 성추행 혐의’ 남성 “정신장애” 주장'],
#   ['[사회] 서울대 의대교수 “김미경 점수 ‘미양’ 주자 학교쪽서 ‘곤란’ 말해”',
#    '[정치] 문재인의 ‘대구’ 안철수의 ‘광주’…지역민심 들어보니',
#    '[전체기사] 진짜판별기 메인페이지',
#    '[사회] [단독] 서울대 본부, ‘김미경 특채’ 내리꽂고 ‘정년 보장’ 밀어붙여',
#    '[정치] 민심이 색깔론에 등돌린 3가지 이유',
#    '[정치] 문재인 “송민순 발언은 ‘제2 NLL’ 북풍공작…책임 묻겠다”',
#    '[경제] 삼성전자 “지주회사 전환 안한다” 공식 발표',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[국제] 트럼프 ‘본색’…한국에 사드 비용 1조1300억 요구',
#    '[정치] 원탁토론 위에 형성된 날카로운 대립각',
#    '[정치] 유진룡 “블랙리스트는 홀로코스트…처벌받아야 할 사람 더 있다”',
#    '[정치] [단독] 전두환, 박정희 사망 일주일 만에 1212 “확고한 결심”',
#    '[정치] 문재인 회견장서 성소수자 기습 시위… 문 후보 입장 밝히기로',
#    '[정치] “내가 MB 아바타입니까” 안철수가 목소리 높인 이유는?',
#    '[정치] [단독] 안철수가 손본다는 ‘포괄임금제’, 정작 안랩은 수십년째 그대로',
#    '[경제] [짜판] 홍준표 “강성노조 때문에 기업 해외로”…근거없는 억지주장',
#    '[정치] 안철수는 왜 TV토론 때 ‘세월호 리본’을 안 달았을까',
#    '[사회] ‘우병우 검찰 압박설’이 잦아들지 않는 이유',
#    '[정치] 문재인, ‘동성애 반대’ 밝혔다가 ‘동성혼 반대’',
#    '[정치] 홍준표, 대학때 돼지흥분제로 ‘성폭력 모의’ 뒤늦게 밝혀져'],
#   ['[경제] 갤럭시S8 ‘붉은 화면’ 의심되면 이렇게 해봐요',
#    '[정치] 문재인의 ‘대구’ 안철수의 ‘광주’…지역민심 들어보니',
#    '[전체기사] 진짜판별기 메인페이지',
#    '[사회] “‘혼술남녀’ 피디였던 형이 스스로 목숨을 끊었습니다”',
#    '[정치] 문재인 “송민순 발언은 ‘제2 NLL’ 북풍공작…책임 묻겠다”',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[만화·만평] 4월 17일 한겨레 그림판',
#    '[만화·만평] 4월 14일 한겨레 그림판',
#    '[정치] “북한을 ‘주적’이라 부를 거냐?”…‘색깔론’ ‘사상검증’으로 물든 토론회',
#    '[정치] 안철수 포스터 조언한 이제석 “얼굴 반전은 모르겠다',
#    '[정치] 홍준표, ‘세월호 막말’ 물의 빚은 명성교회 부활절 예배',
#    '[정치] 후보님들, 우린 그냥 늙으면 되나요?…1인가구 유권자의 ‘방백’',
#    '[사회] [영상] 홍석현 “손석희 교체 외압 5~6번…2번은 박근혜 대통령”',
#    '[정치] 안철수 현충원 방문때 천안함 유가족 내쫓은 뉴스는 ‘사실’',
#    '[정치] [짜판] 안철수, 불 끄려다 기름 부은 ‘단설 유치원’ 해명',
#    '[정치] [독점공개] 전두환, 박정희 사망 일주일 만에 1212 “확고한 결심”',
#    '[정치] 안철수도 비서에게 ‘아내 심부름’ 시켰다',
#    '[정치] 안철수, 선거 포스터 논란에 “변화 의지 보여드리려는 것”',
#    '[정치] 워킹맘 눈물 닦아줄 대선 후보는 누굴까',
#    '[정치] 안철수는 왜 TV토론 때 ‘세월호 리본’을 안 달았을까'],
#   ['[전체기사] 진짜판별기 메인페이지',
#    '[만화·만평] 3월 31일 한겨레 그림판',
#    '[정치] [팩트체크] 안철수 기념사진 청년들 ‘조폭’인지 확인해보니…',
#    '[사회] ‘이젠 돌아오길…’ 기억해야 할 세월호 미수습자 9명',
#    '[만화·만평] 4월 14일 한겨레 그림판',
#    '[국제] ‘승객 학대’ 유나이티드항공에 ‘복수’한 중동 항공사',
#    '[사회] 김대두, 그는 정말 연쇄살인범이었을까',
#    '[사회] 큰절하는 홍준표…소금 뿌린 도민들',
#    '[정치] 문재인-안철수 나란히 37.7%…보수층 ‘안’으로 대이동',
#    '[사회] 해수부 “세월호 선체서 휘어짐구부러짐 현상 발견”',
#    '[정치] [짜판] 안철수, 불 끄려다 기름 부은 ‘단설 유치원’ 해명',
#    '[정치] 안철수도 비서에게 ‘아내 심부름’ 시켰다',
#    '[정치] 안정적 국정운영은 “문재인”…내 삶 나아지게 할 후보 “안철수”',
#    '[사회] ‘태블릿피시’ 협조한 건물관리인 “진실규명 도움되고 싶었다”',
#    '[정치] 안-문, 규제프리존 놓고 “통과시켜야” “대기업 청부 입법” 충돌',
#    '[경제] [짜판] 홍준표 “강성노조 때문에 기업 해외로”…근거없는 억지주장',
#    '[정치] 여권 벌써 ‘야당본색’…문안 누가되든 대통령 앞길 ‘캄캄’',
#    '[사회] 유나이티드항공 ‘오버부킹’, 국내항공사들은 어떻게 대응할까',
#    '[사회] [속보] 우병우 전 민정수석 구속영장 또 기각']],
#  [['[정치] 국민의당 이언주 의원, 파업 비정규직 노동자에 막말 파문',
#    '[정치] [단독] 9조 더 쓰고 ‘지각 이전’…미8군 내일부터 평택행',
#    '[사회] ‘모두 돌아오길…’ 우리가 기억해야 할 세월호 9명',
#    '[정치] 권은희 “제보조작 당이 기획한 것이면 국민의당 해체해야”',
#    '[사회] 안종범 수첩 ‘직접증거’ 불발에도 특검이 웃는 이유',
#    '[경제] ‘운전기사 갑질’ 이장한 종근당 회장 “공식 사과하겠다”',
#    '[정치] 바른정당 입당 박종진, 종편서 “대학 다닐 때 성매매 하셨죠?”',
#    '[정치] [영상] 밥하는 아줌마=어머니? 매를 버는 이언주',
#    '[정치] ‘여성 비하’ 탁현민 행정관 조만간 경질',
#    '[사회] [뉴스AS] ‘햄버거병’에 걸린 4살 아이, 그리고 맥도날드',
#    '[경제] [단독]다주택자 임대소득 연 20조원…세금은 8%에만 매겨',
#    '[정치] 안철수 “제보 조작 책임 통감”…정계은퇴는 안해',
#    '[정치] MB 안보수석 “박근혜 정부 전작권 전환 연기는 최대 실책”',
#    '[정치] 박근혜 정부 ‘삼성 경영권 승계 지원 문건’ 나왔다',
#    '[정치] 추미애박지원 ‘막말 지르기’ 승자는 누구?',
#    '[사회] [그래픽뉴스] 이언주가 소환한 국회의원 ‘반노동 막말’',
#    '[사회] [단독] 종근당 회장, 운전기사 욕설폭언…1년새 3명 ‘퇴사’',
#    '[사회] 4년 돌고 돈 ‘국정원 댓글사건’ 결심… 뒤바뀐 운명',
#    '[정치] 자유한국당 “문 대통령에 박수” G20 논평 놓고 내부 설전',
#    '[사회] 국민의당 이준서 구속…‘제보조작 핵심’ 검찰 주장 탄력'],
#   ['[정치] 문 대통령 “성명만 낼 상황 아냐”…탄도미사일 사격 지시',
#    '[정치] 한-미 정상 첫 만남…문 대통령 “힘에 기반한 트럼프 외교에 전적으로 동감”',
#    '[경제] [단독] 공공부문 비정규직, 이르면 9월부터 정규직화 돌입',
#    '[정치] 노회찬 “박지원 ‘녹취록 조작’ 특검 제안은 대선 불복”',
#    '[사회] 안종범 수첩 ‘직접증거’ 불발에도 특검이 웃는 이유',
#    '[정치] 정두언 “안철수 종 쳤다…제보조작 치명타”',
#    '[문화] ‘앵커’ 전원책 “문 대통령, 지지층만의 대통령으로 남을 건가”',
#    '[사회] [단독]‘이청연 뇌물수수’ 핵심 관련자 “검찰 회유로 허위 진술”',
#    '[사회] [뉴스AS] ‘햄버거병’에 걸린 4살 아이, 그리고 맥도날드',
#    '[사회] [영상] 조선인 ‘위안부’ 피해자 촬영한 동영상 첫 발견',
#    '[사회] [단독] 서울시, 무기계약직 2435명 모두 올안 정규직화',
#    '[사회] [단독] ‘4대문 안 혼잡통행료 8000원 보고서’ 3년 묵힌 이유',
#    '[정치] ‘문무일 연수원 동기’ 이재명 “적폐청산의 길, 제대로 열어갈 것”',
#    '[사회] 잘 알려지지 않은 ‘우병우 사단’의 실체',
#    '[정치] 자유한국당 새 대표에 홍준표…대선패배 두달만에 복귀',
#    '[사회] ‘블랙리스트’ 김기춘 징역 7년조윤선 6년 구형',
#    '[사회] 40대 집배원, 안양우체국 앞에서 분신',
#    '[정치] 머그컵은 죄가 없다…국회 반입 금지 물품에 얽힌 사연',
#    '[사회] [영상] ‘맨발 투혼’ 류여해가 누구길래…패러디 영상까지',
#    '[정치] 노회찬 “국민의당, 냉면집 주인이 ‘대장균 단독범행’ 주장하는 격”'],
#   ['[사회] [단독] 파리바게뜨 회장 한마디에…제빵사들 “화장실 갈 시간도 없어요”',
#    '[경제] [단독] ‘이건희 동영상’ 혐의 CJ 부장, 이맹희 의전 담당이었다',
#    '[정치] 이유미, 대선전날 이준서에 “사실대로 말하면 국민의당 망한다”',
#    '[정치] 한-미 정상 첫 만남…문 대통령 “힘에 기반한 트럼프 외교에 전적으로 동감”',
#    '[사회] 서울 이어 대구서도 “자유한국당 해체” 집회 시작',
#    '[정치] [단독] 대통령 경호실 “이영선, 경호관 위상 실추”…5월말 파면',
#    '[정치] ‘문준용 제보 조작’ 이유미, 안철수 제자…박근혜와 인증샷도',
#    '[정치] 노회찬 “박지원 ‘녹취록 조작’ 특검 제안은 대선 불복”',
#    '[정치] 정두언 “안철수 종 쳤다…제보조작 치명타”',
#    '[정치] [단독] “송영무가 군납비리 수사 막았다고 들어…비리 카르텔 우려”',
#    '[사회] 누리꾼들 ‘성지’된 자유한국당 5행시 공모전',
#    '[정치] 국민의당 ‘문준용 의혹 조작’ 몸통은 누구인가',
#    '[정치] 이혜훈 바른정당 신임 대표 “진영에 매몰돼 발목잡는 정치 안하겠다”',
#    '[정치] 국민의당 “문준용 채용 비리 제보는 조작…사과드린다”',
#    '[정치] 법무장관 후보자 박상기, 권익위원장 박은정',
#    '[정치] 문 대통령이 워싱턴서 묵는 ‘블레어하우스’란?',
#    '[정치] 자유한국당, 김상곤 청문회장 ‘벽보 도배’…민주 “유례없어”',
#    '[사회] ‘2만원 치킨’ 시대…웃는 자는 따로 있다',
#    '[정치] [영상] 이은재가 바른정당 탈당한 이유는 ‘사모님’ 때문?',
#    '[정치] 문 대통령 “핵 동결 땐 북한에 무엇을 줄지 미국과 협의해야”'],
#   ['[정치] 문 대통령의 ‘엉큼한 인사’에 모두들 혀를 내두른다',
#    '[사회] [단독] ‘삼우는 위장계열사’ 삼성임원 녹취록 나왔다',
#    '[사회] 서울 이어 대구서도 “자유한국당 해체” 집회 시작',
#    '[사회] 자유한국당 서울시당위원장 “문재인은 깡패 같은 놈” 막말',
#    '[정치] ‘정치 종가’ 동교동계의 패배…국민의당 ‘탈당 카드’ 속내는?',
#    '[사회] 밀양 할머니, 문 대통령에 편지 “나를 빨갱이라고…너무 억울”',
#    '[정치] [단독] “송영무가 군납비리 수사 막았다고 들어…비리 카르텔 우려”',
#    '[사회] 누리꾼들 ‘성지’된 자유한국당 5행시 공모전',
#    '[정치] 자유한국당 앞날이 비관적인 두 가지 이유',
#    '[사회] 박정희가 물고문전기고문하더니 박근혜가 ‘이자고문’ 하더라',
#    '[사회] 금속노조 “비정규직 위한 일자리기금 2500억 내겠다”',
#    '[정치] 문 대통령 “김정은 원하는 건 체제 보장과 대미관계 개선”',
#    '[정치] 청와대 앞길 50년만에 24시간 전면 개방',
#    '[경제] [단독] 엔씨소프트, ‘거래소 없는’ 모바일용 리니지 출시',
#    '[사회] ‘국정농단’ 최순실 첫 선고…‘이대 비리’ 징역 3년',
#    '[사회] ‘2만원 치킨’ 시대…웃는 자는 따로 있다',
#    '[사회] 잘 알려지지 않은 ‘우병우 사단’의 실체',
#    '[정치] 박지원 “문정인 옳았다…한미 정상회담 앞두고 계산된 발언”',
#    '[사회] 백선하 교수 “고 백남기 농민은 ‘병사’…소신 변함없다”',
#    '[경제] [단독] 경쟁입찰한다면서…국토부, 적자노선 또 코레일 떠넘겨'],
#   ['[정치] 문 대통령의 ‘엉큼한 인사’에 모두들 혀를 내두른다',
#    '[사회] [단독] ‘피의자와 룸살롱’ 판사…대법, 검찰 비위통보 묵살했다',
#    '[경제] [단독] ‘박근혜때 일방 강행’ 성과연봉제 폐기한다',
#    '[국제] 런던 24층 아파트 화재 아비규환…아이들 창문 밖으로 던져',
#    '[정치] 노회찬 “문 대통령 마주친 자유한국당, 에프킬라 발견한 모기 같은 상황”',
#    '[사회] 고 백남기 농민 사망진단서 ‘병사’→‘외인사’로 수정',
#    '[사회] 자유한국당이 ‘방송장악 저지’ 투쟁? “적반하장” 비판 봇물',
#    '[사회] 자유한국당 서울시당위원장 “문재인은 깡패 같은 놈” 막말',
#    '[정치] ‘정치 종가’ 동교동계의 패배…국민의당 ‘탈당 카드’ 속내는?',
#    '[정치] 고민정 “가까이서 본 문 대통령, 연설 잘할 수밖에 없어요”',
#    '[정치] 자유한국당 앞날이 비관적인 두 가지 이유',
#    '[사회] 안경환 후보 “기회 주면 소명 다해, 사퇴 생각 없다”',
#    '[사회] [단독] ‘조현오 뇌물’ 수사중에…부산 향판-건설업자 유착 드러나',
#    '[사회] 박정희가 물고문전기고문하더니 박근혜가 ‘이자고문’ 하더라',
#    '[사회] 조대엽 노동부장관 후보자, 고려대 교수시절 학생들 향해 고성반말 논란',
#    '[정치] 문 대통령 “국민이 고단한 원인은 일자리, 추경 협력해달라”',
#    '[경제] [단독] 신분당선, 노인 운임 유료화 추진',
#    '[사회] 중국 세계 첫 무궤도 자동 열차 선봬',
#    '[정치] 통일 조명균농림 김영록여성 정현백미래 유영민',
#    '[사회] 잘 알려지지 않은 ‘우병우 사단’의 실체'],
#   ['[사회] [단독] 87년 6월 이한열 열사 피격 전후 사진 최초 공개',
#    '[정치] [단독] 김기정 청와대 안보실 2차장 경질',
#    '[사회] [단독] ‘돈봉투 만찬’ 참석 검찰간부, 자기 부서에 ‘셀프 배당’',
#    '[정치] 문 대통령의 ‘엉큼한 인사’에 모두들 혀를 내두른다',
#    '[사회] [단독] 황교안, ‘해경 과실치사죄’ 적용 맞선 검사들 인사 보복',
#    '[사회] [단독] 임우재 전 삼성전기 고문 ‘공무원에 수억원’ 뇌물 혐의',
#    '[사회] 돈봉투 돌려준 시점 말바꿔…김영란법 위반 ‘물타기’',
#    '[정치] ‘정치 종가’ 동교동계의 패배…국민의당 ‘탈당 카드’ 속내는?',
#    '[정치] 고민정 “가까이서 본 문 대통령이요? 문자중독 같아요”',
#    '[국제] “우리집 개도 봤다”…트럼프 탄핵시계는 몇 시?',
#    '[정치] ‘새 시대의 첫차’ 노무현의 꿈, 문재인이 이룰 수 있을까',
#    '[사회] “월급 40여만원 반환하라” 9년전 숨진 일병 부모에 소송 건 국방부',
#    '[정치] 청와대 “위승호 국방정책실장이 사드 보고 삭제 지시”',
#    '[정치] 김종대 “국방부, 장군 의전은 챙기면서 병사들은 개돼지 취급”',
#    '[사회] [단독] 국정원 알바 부대 ‘알파팀’ 조직원의 최초 폭로',
#    '[사회] ‘피고인’ 대신 “대통령님이”…유영하 변호사는 한결같았다',
#    '[사회] ‘돈봉투 만찬’ 이영렬안태근 면직 청구…대검에 수사 의뢰',
#    '[국제] 지구 미래 외면한 트럼프…미국 중심 국제질서 흔들',
#    '[정치] 문재인 정부 인사의 최고 실세도 ‘시스템’일까?',
#    '[사회] 610항쟁 출발은 이 두 사람의 ‘감옥편지’였다'],
#   ['[사회] [단독] 황교안, 세월호 수사 외압 드러났다',
#    '[사회] [영상] ‘돈 봉투 만찬’ 안태근 검찰국장 답변 태도 다시 논란',
#    '[사회] “황교안 법무부, 선거 의식해 세월호 수사 지연시켰다”',
#    '[사회] [단독] 황교안, ‘해경 과실치사죄’ 적용 맞선 검사들 인사 보복',
#    '[만화·만평] 5월 29일 한겨레 그림판',
#    '[정치] 세비 반납 피하려…자유한국당 26명, 마감 하루전날 법안 발의',
#    '[정치] 사드발사대 4기 추가반입 뒤늦게 보고…문 대통령 “매우 충격”',
#    '[정치] ‘정치 종가’ 동교동계의 패배…국민의당 ‘탈당 카드’ 속내는?',
#    '[정치] [단독] ‘종교인 과세 2년 더 유예’ 총대 멘 김진표 국정기획위원장',
#    '[사회] [단독] 이건희 일가 인테리어비용 수상한 결제…경찰 수사 착수',
#    '[사회] ‘박 전 대통령 영장심사’ 강부영 판사-서향희 변호사 ‘인연’ 주목',
#    '[국제] 16살에 40살 여인에 구혼…마크롱은 어떻게 권력을 쟁취했나',
#    '[정치] 행자 김부겸국토 김현미문화 도종환해수 김영춘 장관 후보 지명',
#    '[정치] 한민구 국방장관 “사드 반입 더 할 말 없다”',
#    '[경제] 김상조는 왜 좌우 모두에서 공격받을까',
#    '[정치] [단독] 이인걸 청 반부패실 행정관, 국정농단 사건 롯데쪽 변호 맡아',
#    '[국제] 미국 현대차 홍보모델 “생리 이유로 해고 당했다” 고발',
#    '[정치] 이낙연 총리 후보자 “인준 찬성” 72.4%-“반대” 15.4%',
#    '[정치] 청와대 “국방부, 사드 추가 반입 보고 의도적으로 누락”']],
#  None,
#  [['[English Edition] Pro-Pyongyang group in Japan faces financial crisis',
#    '[문화] 죽고 강간당한 50만은 어디에…‘남한산성’이 거세한 것들',
#    '[정치] ‘월천거사’ 이철희, 국감스타 된 비결은',
#    '[경제] [단독] 이건희, 차명계좌 실명전환 않고 4조4천억 싹 빼갔다',
#    '[사회] ‘다스 비자금’ 단서, 검찰 캐비닛에 있다',
#    '[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[사회] 땅속 김치통에 든 수상한 돈뭉치가 보성군수 ‘뇌물’ 덜미 잡았다',
#    '[전체기사] 개들은 새벽에 죽는다…그는 200만원을 번다',
#    '[사회] 나는 신고리 56호기 공론조사 시민참여단입니다',
#    '[사회] 배우 김여진 “추함의 끝이 어딘지 눈뜨고 보고 있기 힘들다”',
#    '[국제] ‘박근혜 인권 침해’ 주장한 MH그룹은 어떤 곳?',
#    '[사회] “김치 여군” “전쟁나면 몸 바쳐야”…여대 교수 여성혐오 막말',
#    '[정치] [단독] “1명당 2천만원” 강원랜드 채용 돈거래 드러나',
#    '[정치] “구치소서 인권침해” 당했다는 박 전 대통령의 수감생활은?',
#    '[사회] 법정서 처음 입 연 박근혜 “추가 구속 받아들이기 어렵다”',
#    '[사회] [단독] 단체장 비리의혹 수사 뭉갠 ‘경찰 내부자들’',
#    '[경제] [단독] 공정위, 삼성 ‘총수’ 이건희에서 이재용으로 바꾼다',
#    '[사회] [단독] 추명호, 우병우에게 이석수 사찰 내용 ‘깨알 비선보고’',
#    '[정치] 노회찬 의원이 국감장에 신문지 깔고 드러누운 사연은',
#    '[정치] [영상] 하늘에서 360도로 찍은 평양 시내, 대동강이 ‘한눈에’'],
#   ['[정치] 종편TV 억대벌이 ‘메뚜기’ 평론가들 어디 갔지?',
#    '[사회] “나는 핵연료봉을 10시간 넘게 신발 집게로 치웠다”',
#    '[사회] [단독] ‘박근혜 국정원’ 곧 수사…‘NLL 대화록 폭로’ 김무성도 포함',
#    '[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[정치] 대선 직전 사드 알박기 ‘김관진 주도’ 드러났다',
#    '[정치] 이상돈 “MB 비리 파헤치면 갈 곳은 ‘딱 한군데’밖에 없다”',
#    '[경제] 삼성전자 권오현 부회장 사퇴 선언…“후배 경영진이 쇄신할 때”',
#    '[사회] 배우 김여진 “추함의 끝이 어딘지 눈뜨고 보고 있기 힘들다”',
#    '[사회] 운전자 30%만 알고 있는 도로 위 다이아몬드의 뜻은?',
#    '[정치] 언제는 친박 용서하자더니? 홍준표의 ‘탈박’ 꼼수냐 큰 수냐',
#    '[사회] 이완용까지 찬성자 명단에…엉터리 국정교과서 여론조사',
#    '[사회] [단독] 단체장 비리의혹 수사 뭉갠 ‘경찰 내부자들’',
#    '[사회] 고영주, MBC 여의도 사옥 ‘묻지마 매각’ 종용 의혹',
#    '[정치] 청와대 “세월호 당일 일지 조작…박근혜 첫 보고 시점 30분 늦춰”',
#    '[특화섹션] [ESC] 잔치국수짜장면소바, 국수 삼국지의 승자는?',
#    '[정치] 8월엔 총리, 추석엔 직접 방문…문 대통령, 안동 콕 찍은 이유',
#    '[사회] “명절마다 사촌동생 몰카 올라와”…청와대 누리집에 일베 폐지 청원',
#    '[사회] [단독] ‘NLL 대화록’ 유출에 국정원 개입…“남재준, 검찰서 설명해야”',
#    '[사회] 본인도 모르는 ‘장애인 특보’…안철수 캠프, 대선때 임명장 남발',
#    '[사회] [단독] 사학비리 비호한 보수정부 10년, 신종 비리 이렇게 진화했다'],
#   ['[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[정치] “문 대통령님, 휴가 주세요” 그 사병의 운명은 휴가? 기합?',
#    '[정치] 이상돈 “MB 비리 파헤치면 갈 곳은 ‘딱 한군데’밖에 없다”',
#    '[사회] [단독] “손석희 민심호도” ”김재원 친박편파”… 정부비판에 쌍심지',
#    '[사회] 배우 김여진 “추함의 끝이 어딘지 눈뜨고 보고 있기 힘들다”',
#    '[사회] 시속 100㎞ ‘구간단속’에서 평균 110㎞로 달리면 단속될까?',
#    '[English Edition] As he wished, German journalist laid to rest in Gwangju',
#    '[사회] “월급 40여만원 반환하라” 9년전 숨진 일병 부모에 소송 건 국방부',
#    '[정치] 언제는 친박 용서하자더니? 홍준표의 ‘탈박’ 꼼수냐 큰 수냐',
#    '[사회] 잘 알려지지 않은 ‘우병우 사단’의 실체',
#    '[국제] 라스베이거스 ‘대량살상’ 키운 99달러짜리 개조장치 ‘범프 스탁’',
#    '[정치] ‘문라이트’ 언제까지 빛날까',
#    '[정치] 국방부, ‘댓글 양심선언 예고’ 군무원 김석중씨 ‘수상한 죽음’도 조사',
#    '[사회] 이국종 교수 “기대도 희망도 없지만, 원칙 버리진 않겠다”',
#    '[사회] 서해순 “이 모든 게 돈 때문…김광석 관련 일 더 관여 안할 것”',
#    '[정치] 고속도로 통행료 2천만원 떼먹은 ‘미납왕’을 공개합니다',
#    '[국제] 라스베이거스 참사, 범인은 회계사 출신 재력가',
#    '[정치] ‘죽음의 백조’ 북한 위협할 때 미군은 왜 한국군 배제했나',
#    '[사회] 13',
#    '[정치] 유승민-김무성, 그것은 이별의 입맞춤이었나'],
#   ['[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[사회] [단독] 한국당 신보라 의원의 ‘아스팔트 우파단체’ 등 압수수색',
#    '[정치] “문 대통령님, 휴가 주세요” 그 사병의 운명은 휴가? 기합?',
#    '[사회] [단독] 권해효김민선이 SBS에서 사라진 이유',
#    '[전체기사] [영상] 어느 어촌마을의 ‘레드데이’…일본 고래사냥 장면 공개',
#    '[정치] 이상돈 “MB 비리 파헤치면 갈 곳은 ‘딱 한군데’밖에 없다”',
#    '[사회] 청년 제빵기사들이, 33살의 파리바게뜨 회장에게',
#    '[사회] [단독] “손석희 민심호도” ”김재원 친박편파”… 정부비판에 쌍심지',
#    '[정치] [단독] MB가 ‘댓글공작 사이버사 증원’ 직접 지시했다',
#    '[정치] “이념전쟁서 승리”…자유한국당 ‘온라인 전사’ 118명 떴다',
#    '[정치] 북 핵실험, 100년 넘게 잠자고 있는 백두산 깨울까',
#    '[정치] MB, 군사 보안시설 기무사서 ‘황제 테니스’',
#    '[정치] [단독] ‘빽’ 동원한 부정입사자 해고 안된다고? “응징해야지요”',
#    '[사회] ‘변호인 그 이상’ 유영하와 이경재',
#    '[사회] 법도 사람도 무력했다…고래고기 21톤이 사라졌다',
#    '[English Edition] As he wished, German journalist laid to rest in Gwangju',
#    '[사회] “월급 40여만원 반환하라” 9년전 숨진 일병 부모에 소송 건 국방부',
#    '[정치] 문 대통령 “감옥 있는 한상균 위원장, 저도 눈에 밟힙니다”',
#    '[정치] ‘박근혜 캐비닛’서 ‘문화계 블랙리스트 MB 보고’ 단서 나왔다',
#    '[전체기사] 우리에서 물려 죽은 호랑이 ‘뒹굴이’…동물원이 위험하다'],
#   ['[정치] 미군 고물헬기에 1500억 날린 박근혜 정부',
#    '[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[English Edition] South Korea’s electric car market growing, but still in infancy',
#    '[사회] [단독] 권해효김민선이 SBS에서 사라진 이유',
#    '[사회] “독도의용수비대원이 33명? 완전히 날조됐다”',
#    '[사회] [단독] “손석희 민심호도” ”김재원 친박편파”… 정부비판에 쌍심지',
#    '[사회] 남경필 경기도지사 첫째 아들 ‘필로폰 투약’ 혐의 긴급체포',
#    '[국제] 사드 보복, 중국 선양 롯데백화점 50% 세일에도 손님 뚝',
#    '[정치] 북 미사일 또 쐈지만, 미국 대응은 예전과 달랐다',
#    '[English Edition] Samsung faces difficult choices over reforming owner-management model',
#    '[사회] 배우 김여진 “추함의 끝이 어딘지 눈뜨고 보고 있기 힘들다”',
#    '[사회] 법도 사람도 무력했다…고래고기 21톤이 사라졌다',
#    '[사회] 세월호 차량 블랙박스는 ‘416’을 기억한다',
#    '[사회] “살아있다더니…” 가수 김광석 딸, 10년전 사망 확인',
#    '[경제] 한국형 핵발전소가 세계 최고라는데…왜 잘 안팔릴까요?',
#    '[사회] 곰팡내 심해 온종일 커피향 방향제, 그 방에 6살 아이가…',
#    '[정치] 김정은 “사상 최고 초강경 대응조치 단행 고려”',
#    '[경제] 삼성 비자금 폭로 10년, 정의구현사제단 신부의 10년',
#    '[사회] 제빵기사 직접고용땐 파리바게뜨 위태롭다고?',
#    '[정치] ‘엄마부대’ 주옥순이 자유한국당 젊은 지지층과 소통한다?'],
#   ['[정치] [영상] 야당 의원들 멘붕에 빠뜨린 이낙연 총리 ‘사이다 답변’',
#    '[정치] [단독] 강원랜드 합격자 518명 중 493명 ‘빽’ 있었다',
#    '[사회] 518 발포 명령권자 밝혀낼 단서 나왔다',
#    '[정치] [단독] 염동열 의원 쪽도 80여명 청탁…강원랜드 20~30명 채용됐다',
#    '[사회] 굴욕 견뎌내고 돌아온 칼잡이',
#    '[사회] ‘학력 허위 게재’ 이철규 자유한국당 의원, 항소심서 무죄',
#    '[사회] 권은희 대 김용판윤석열 대 조영곤…댓글 사건 주연들 ‘엇갈린 운명’',
#    '[문화] 남진 대 나훈아…가요사의 해묵은 논쟁 이제 끝내자',
#    '[정치] 북 미사일 또 쐈지만, 미국 대응은 예전과 달랐다',
#    '[정치] MB 국정원도 ‘블랙리스트’…김여진, 문소리, 오광록 포함',
#    '[사회] 배우 김여진 “추함의 끝이 어딘지 눈뜨고 보고 있기 힘들다”',
#    '[사회] 세월호 차량 블랙박스는 ‘416’을 기억한다',
#    '[정치] [단독] “4백명 청탁자가 1천명 채용 부탁”…강원랜드는 ‘청탁랜드’',
#    '[스포츠] 히딩크, 잉글랜드도 중국도 거절하더니…“한국팀 맡고 싶다”',
#    '[경제] ‘이건희 동영상’ 판결문엔 어떤 내용이 담겨 있나',
#    '[사회] 제자가 본 ‘인간 마광수’…“그는 늘 맘껏 써보라고 말했다”',
#    '[정치] 김이수 추천했던 박지원 “청와대 오만…김명수도 장담 못해”',
#    '[사회] “518 사망자 광주교도소 3곳에 암매장됐다”',
#    '[사회] [단독] “댓글 수사받느라 고생”…국정원, 황당한 복지확대',
#    '[정치] [속보] 김이수 헌재소장 후보자 임명동의안 2표차 ‘부결’'],
#   ['[전체기사] 떡볶이 프랜차이즈1년새 점포수 두배↑',
#    '[정치] [단독] 권성동 의원 비서관, 강원랜드 부정청탁 입사',
#    '[사회] [단독] 김장겸 쪽, 안철수에 “MBC가 도울 일 없나?” 접촉 시도',
#    '[사회] 구내식당 탓? 삼성-수원 ‘48년 동맹’이 흔들린다',
#    '[사회] 서울 이어 대구서도 “자유한국당 해체” 집회 시작',
#    '[사회] “결혼은 안 해도 퇴사는 한다”',
#    '[사회] 내 영상이 돌다니…“몰카, 지워도 지워도 끝나지 않는 지옥”',
#    '[사회] 서경덕 교수, 댓글 연루 부인…“국정원 직원 허위보고”',
#    '[사회] 굴욕 견뎌내고 돌아온 칼잡이',
#    '[사회] [단독] 권성동 또다른 비서관도 특채…공공기관 채용비리 만연',
#    '[사회] 권은희 대 김용판윤석열 대 조영곤…댓글 사건 주연들 ‘엇갈린 운명’',
#    '[문화] 남진 대 나훈아…가요사의 해묵은 논쟁 이제 끝내자',
#    '[사회] [영상] 최원정 아나운서 “KBS 총파업 대단한 각오로 임하고 있다”',
#    '[사회] ‘초등생 성폭행 교사’, 강간죄 처벌 기준 왜 ‘13살’일까요?',
#    '[사회] 차관도 차관급도 아닌데, 관용차는 왜 타요?',
#    '[정치] “김장겸 ‘내가 무너지면 한국당이 무너진다’ 얘기하고 다녀”',
#    '[정치] “사드는 스스로도 보호하지 못하는 장비”…효용성 논란 재점화',
#    '[사회] [단독] 국정원, ‘민간 댓글팀장’에 준 돈 ‘수령증’ 보관',
#    '[스포츠] 히딩크, 잉글랜드도 중국도 거절하더니…“한국팀 맡고 싶다”']],
#  [['[사회] 대법 “경비원, 아파트와 용역업체 계약 끝나도 해고 못한다”',
#    '[사회] 배현진, 오늘 MBC ‘뉴스데스크’부터 빠진다',
#    '[사회] [단독] 지상파 3사 모두 ‘재허가 탈락점수’…초유의 사태',
#    '[사회] 가난과 죽음의 바닷길 따라 국민생선 명태가 온다',
#    '[사회] [단독] 에어포켓 생존자 “공기 모자랐지만 썰물 덕에 살았다”',
#    '[정치] 첫 발언부터 사과까지…문재인과 박근혜, 이것이 달랐다',
#    '[사회] 고독사 이미지, 반려견이 2주간 곁을 지켰다',
#    '[정치] 노회찬 “여당에 유리하면 평창올림픽도 연기하자 할 거냐?”',
#    '[문화] 영조가 사도세자 묘지문에서 직접 밝힌 죽음의 이유',
#    '[특화섹션] [ESC] 사랑섹스…‘초딩’이라고 무시하지 마세요',
#    '[정치] 홍준표, 국회 특활비 3번째 말바꾸기 “기억 착오” 발뺌',
#    '[사회] 바퀴벌레와 동거하던 반지하 탈출…“기숙사 생기고 숨통이 트였어요”',
#    '[사회] 최승호, 해직 1997일 만에 ‘MBC 사장’으로 복직',
#    '[국제] [포토] ‘자연스런’ 저녁식사',
#    '[정치] 자유한국당 빠진채 본회의 열자 “안들어온단 말 안했잖아”',
#    '[국제] 트럼프 “이스라엘 수도는 예루살렘” 위험한 도박 왜?',
#    '[사회] “전국 최고 용접공이었는데”…눈물 참던 아내 끝내 오열',
#    '[문화] 고조선 왕검성은 평양이 아닌 요동에 있었다?',
#    '[정치] 지역예산 안주면 여야 합의 “통째로 깨버리겠다”는 정책위 의장',
#    '[문화] 최수종, 고독사한 이미지에 “좋은 배우 넘어선 사람이었다”'],
#   ['[경제] GDP 잠정치, 속보치와 왜 다를까',
#    '[사회] 김앤장 변호사들이 김동선 처벌을 원치 않는 사연',
#    '[사설·칼럼] 홍준표를 보고 무능한 선조가 떠오른 이유',
#    '[사회] “스스로 물러나지 않으면 쫓겨나”…나이 쉰이 ‘죄’인 일터',
#    '[사회] 가난과 죽음의 바닷길 따라 국민생선 명태가 온다',
#    '[사회] 고독사 이미지, 반려견이 2주간 곁을 지켰다',
#    '[문화] 영조가 사도세자 묘지문에서 직접 밝힌 죽음의 이유',
#    '[특화섹션] [ESC] 사랑섹스…‘초딩’이라고 무시하지 마세요',
#    '[정치] 홍준표, 국회 특활비 3번째 말바꾸기 “기억 착오” 발뺌',
#    '[정치] 하태경 “정두언이 깔끔하게 정리, 다스 MB건데…”',
#    '[정치] 김관진 결재한 ‘사이버사 2012년 총선 대응 지침’ 나왔다',
#    '[정치] “미니스커트는 짧을수록 좋아” 송영무 국방장관 또 구설',
#    '[사회] [단독] 국정원  원세훈 비리 줄테니 댓글수사 중단하라  뒷거래 기획',
#    '[사회] 내 얼굴 찍힌 블랙박스 영상, SNS에 퍼나르는 보배드림',
#    '[정치] 자유한국당 심재철 “문 대통령 내란죄로 고발해야”',
#    '[사회] ‘도박 같은 게임’에 눈덩이빚…청소년 중독 심각',
#    '[문화] 최수종, 고독사한 이미지에 “좋은 배우 넘어선 사람이었다”',
#    '[사회] ‘이국종 신드롬’이 들춰낸 사각지대, 죽음에도 계급이 있다',
#    '[사회] 우병우가 “가슴 아프다” 말한 최윤수는 누구인가',
#    '[사회] “목숨 내놓고 하라” 국선변호인에 고함친 박근혜 지지자들'],
#   ['[사회] 김종대 “탈북병사 인격테러” 이국종 “비난 견디기 어렵다”',
#    '[사회] 김앤장 변호사들이 김동선 처벌을 원치 않는 사연',
#    '[사설·칼럼] 홍준표를 보고 무능한 선조가 떠오른 이유',
#    '[사회] [단독] “족집게로 뽑아낸듯”…‘우병우 처가’ 삼남개발 압수수색 영장도 기각',
#    '[정치] ‘살벌’했던 끝장토론장…“박지원 비판에 안철수 부르르”',
#    '[사회] 세월호 유족 철수 소식을 전하던 SBS 아나운서 울먹',
#    '[사회] [단독] “권성동 돈 받은 목사 ‘거짓진술’ 시인…검찰이 뭉갰다”',
#    '[특화섹션] [ESC] 사랑섹스…‘초딩’이라고 무시하지 마세요',
#    '[경제] [단독] ‘친박’ 권영세, 법무법인 끼고 현대차에서 고액 자문료 챙겨',
#    '[정치] 홍준표, 국회 특활비 3번째 말바꾸기 “기억 착오” 발뺌',
#    '[정치] 하태경 “정두언이 깔끔하게 정리, 다스 MB건데…”',
#    '[스포츠] “거두절미하고 ‘히딩크 데려오라’ 하니 오만 정이 떨어지더라”',
#    '[사회] 강남 절반 ‘지진 액상화’ 위험지역…우리 동네는 안전한가',
#    '[정치] 문 대통령 외국순방 숨가쁜 일정엔 ‘쿠션’이 있었다',
#    '[정치] ‘JSA 귀순’ 영상 보니…북 추격조 4명 지근거리 근접 ‘긴박’',
#    '[정치] 간담회장 웃음바다 만든 대통령의 한마디 “국내문제 말고”',
#    '[사회] ‘7개월 방치’ 진도체육관 ‘엿새만에 칸막이’ 포항 지진 대피소',
#    '[사회] “자료 모으며 폭로 준비…난 그냥 꼴통”',
#    '[사회] 열여덟번째 생일을 나흘 앞두고…제주 현장실습생의 죽음',
#    '[사회] ‘귀순 북한군’ 총상 수술…다시 보는 이국종 인터뷰'],
#   ['[경제] 두산인프라코어는 어쩌다 위기를 맞게 되었을까요',
#    '[English Edition] Fila Korea going global with acquisition of Acushnet Holdings',
#    '[사회] 이영표, 명성교회 부자 세습에 “비참한 퇴장” 비판',
#    '[사회] 포항서 규모 5.4 강진…아스팔트 갈라지고 외벽 ‘와르르’',
#    '[사회] [영상] “광주 시민군 3명 사살해 암매장” 전직 소령 첫고백',
#    '[사회] 세월호 유족 철수 소식을 전하던 SBS 아나운서 울먹',
#    '[정치] 귀순병사,북쪽 총격 피하며 지프로 군사분계선까지 내려와',
#    '[사회] 표창원, ‘적폐수사 반발’ 검찰 비판 “나치 전범 논리 그대로”',
#    '[국제] [영상] “사람 팝니다, 90만원 낙찰!” 21세기 노예시장 리비아',
#    '[사회] [단독] “권성동 돈 받은 목사 ‘거짓진술’ 시인…검찰이 뭉갰다”',
#    '[정치] “나라가 과거에 발목 잡혀” MB는 왜 ‘미운 말’만 골라 할까',
#    '[사회] [단독] ‘박근혜 탄핵’ 시민이 뽑은 역사적 사건 2위, 그럼 1위는?',
#    '[사회] 명성교회 담임목사에 김하나 목사 취임…‘부자 세습’ 완결',
#    '[사회] 검찰 수사 코앞…MB 발목 잡을 ‘결정적 증거’ 3가지',
#    '[스포츠] “거두절미하고 ‘히딩크 데려오라’ 하니 오만 정이 떨어지더라”',
#    '[정치] 간담회장 웃음바다 만든 대통령의 한마디 “국내문제 말고”',
#    '[사회] ‘귀순 북한군’ 총상 수술…다시 보는 이국종 인터뷰',
#    '[정치] 정두언 “박근혜는 ‘태극기’라도 있지만 MB는…”',
#    '[사회] [단독] 전병헌 수석 주중 소환…검찰 “혐의 입증할 증거진술 확보”',
#    '[국제] “한살배기를 불에 던졌다…그 비명을 잊을 수 없다”'],
#   ['[정치] ‘철새’ 김용태황영철에 누리꾼들 “대의고 나발이고…”',
#    '[사회] 다섯 장면으로 정리한 부산 신혼부부 실종사건',
#    '[사설·칼럼] 홍준표를 보고 무능한 선조가 떠오른 이유',
#    '[정치] 전희경 때아닌 ‘주사파 논쟁’에 하태경 “여자 김진태”',
#    '[사회] 박근혜 청와대 특활비 연 200억인데 왜 국정원 돈 썼을까',
#    '[사회] 벤츠 몰며 가게 6곳 운영하는 사장님, 중국동포셨어요?',
#    '[정치] 거듭된 ‘색깔론’ 전희경의 정치 인생은 어땠을까',
#    '[사회] “손님이 남긴 고기를 반찬으로”…서러운 10대의 노동',
#    '[사회] [단독] 원세훈 재판 핵심증인 ‘러시아 출장’ 빼돌린 검사 이제영',
#    '[사회] 표창원, ‘적폐수사 반발’ 검찰 비판 “나치 전범 논리 그대로”',
#    '[경제] [단독] 김준규 전 검찰총장, 삼성현대차에 ‘로스쿨 딸’ 인턴 청탁',
#    '[사회] [단독] “권성동 돈 받은 목사 ‘거짓진술’ 시인…검찰이 뭉갰다”',
#    '[정치] “나라가 과거에 발목 잡혀” MB는 왜 ‘미운 말’만 골라 할까',
#    '[경제] 문 대통령 경제사절단에서 빠진 권오준신동빈 회장',
#    '[사회] ‘국정원 댓글 수사방해 의혹’ 변창훈 검사 투신 사망',
#    '[정치] 전희경 ‘색깔론 폭탄’ 던지고 운영위 사임',
#    '[경제] 카카오 AI스피커 ‘카카오미니’ 판매 시작',
#    '[사회] 검찰 수사 코앞…MB 발목 잡을 ‘결정적 증거’ 3가지',
#    '[정치] 하태경 “정두언이 깔끔하게 정리, 다스 MB건데…”',
#    '[정치] 자유한국당 ‘막장 드라마’의 주연은 서청원'],
#   ['[English Edition] Chaebol-associated non-profit foundations invest through common stocks',
#    '[사회] [단독] 수사방해NLL 대화록 공개…남재준의 ‘7인회’ 작품',
#    '[사설·칼럼] 홍준표를 보고 무능한 선조가 떠오른 이유',
#    '[사회] 이재만 “국정원 돈, 금고에 두고 박근혜 지시 따라 사용”',
#    '[사회] 박근혜 청와대 특활비 연 200억인데 왜 국정원 돈 썼을까',
#    '[문화] 막 올린 원순씨의 서울 도시극장 “문제는 디테일과 콘텐츠”',
#    '[사회] [단독] ‘댓글수사 방해’ 검사, 국정원 직원 자살 전 수차례 통화',
#    '[정치] 박근혜 국정원 “CJ 이미경, 친노의 대모…나영석 PD는 좌파”',
#    '[정치] 하태경 “정두언이 깔끔하게 정리, 다스 MB건데…”',
#    '[정치] 자유한국당 ‘막장 드라마’의 주연은 서청원',
#    '[사회] “자료 모으며 폭로 준비…난 그냥 꼴통”',
#    '[경제] 상여금식비를 기본급으로 돌려 최저임금 안올리기 꼼수 만연',
#    '[사회] 배우 김주혁, 교통 사고로 사망',
#    '[사회] “자유는 차고 넘친다” 국정원 부역 검사의 비뚤어진 확신',
#    '[정치] [단독] “고추농사 짓겠다” 산 땅, 편법으로 골프장 만든 회장님',
#    '[문화] 노무현 미화했다며…문체부, 연극 ‘개구리’ 대본까지 고쳤다',
#    '[사회] [속보] 이재만안봉근, 국정원 특활비 받은 혐의 긴급체포',
#    '[사회] “1원의 사익도 없었다”던 박근혜, ‘문고리 3인방’ 진술로 치명타',
#    '[정치] 김상헌도 최명길도 없고…저 살기 급급한 ‘우왕좌왕 보수’',
#    '[사회] 굿바이 고영주…방문진, 이사장 불신임안 5 대 1 의결'],
#   ['[정치] [영상] 태극기 집회서 태극기에 맞아 울음 터뜨린 류여해',
#    '[문화] 죽고 강간당한 50만은 어디에…‘남한산성’이 거세한 것들',
#    '[국제] 중국 ‘섹스인형’ 대여서비스 나흘만에 중단한 사연',
#    '[사회] 몸속 환경호르몬 2주 만에 절반 줄인 생활습관 10가지',
#    '[경제] [단독] 한-중 정상회담 맞춰 중국에 10조 투자 ‘깜짝선물’',
#    '[사회] [단독] “한일관 대표 지난해에도 같은 개에 물렸다”',
#    '[정치] 자유한국당 ‘막장 드라마’의 주연은 서청원',
#    '[특화섹션] [ESC] 미역도 섹스를 한다는데, 나는?',
#    '[정치] 청와대, 노동계 만찬 메뉴로 ‘전어’까지 올렸건만…',
#    '[사회] 대법 “섬마을 교사 성폭행 학부모 모든 범행 공모…다시 재판”',
#    '[사회] [단독] 추명호, 우병우에게 이석수 사찰 내용 ‘깨알 비선보고’',
#    '[사회] [속보] 방통위, 김경환이진순 방문진 이사 임명 의결',
#    '[정치] [영상] 하늘에서 360도로 찍은 평양 시내, 대동강이 ‘한눈에’',
#    '[경제] “정몽구 회장이 북한에 현대차 공장을 지으려고 한 까닭은…”',
#    '[사회] [단독]국정원 적폐청산 핵심 ‘서버’ 조사…이를 막는 ‘내부자들’',
#    '[사회] “MB 청와대, ‘다스’ 투자금 회수 개입”…봉인 풀린 ‘BBK’',
#    '[정치] 문 대통령 “공공기관 부정 채용 당사자, 합격 무효화 검토”',
#    '[경제] ‘죽음의 에어백’ 다카타 장착 리콜 않고 버티는 벤츠지엠',
#    '[사회] ‘박근혜 성공’ ‘문제인 정부’…구미 박정희 추도식 ‘황당 추도사’']],
#  [['[정치] 형으로 갈아타거나 좀비로 떠돌거나…‘권불 14년’ 친박 생존법',
#    '[정치] 채동욱의 강제퇴임 막전막후, 황교안 “변호사가 돈은 됩니다”',
#    '[사회] 말바꾼 정호영 전 특검, ‘MB 다스 면죄부’ 의혹 키웠다',
#    '[사회] “그렇게 살지 마세요” 그 한마디에 10년 체증이 내려갔다',
#    '[정치] “재보선 안 나가…수구꼴통으로 매도당하는 행태 버릴 것”',
#    '[사회] 돌아온 ‘뉴스데스크’…홍준표 “MBC가 참 이상해졌네”',
#    '[사회] 드론 자격증은 김건모의 노후를 정말 보장해줄까',
#    '[사회] 10년 묵힌 ‘다스’ 의혹 재수사 시동…‘58일간의 싸움’',
#    '[사회] 용산철거민정봉주 등 6444명 특별사면 단행',
#    '[사회] 검찰청 포토라인에 선 ‘황교안 선생’ 언제쯤 볼 수 있을까',
#    '[경제] ‘전안법’ 시행 논란…만원 티셔츠 바지 없어지나?',
#    '[정치] 박근혜 정부의 거짓말…위안부 ‘이면합의’ 있었다',
#    '[정치] ‘MB 저격수’ 정봉주, 특별사면에 “복권! 실감나질 않습니다”',
#    '[사회] MBC 간판이었던 ‘배신남매’ 배현진신동호의 운명은?',
#    '[정치] “위안부 이면합의 없다”던 박근혜윤병세김무성의 말말말',
#    '[정치] “성희롱 발언, 단 한 번도 없다”는 홍준표, 진실은?',
#    '[사회] “박근혜 국정원, MB정부와 UAE 원전 이면계약 조사”',
#    '[정치] 유인태 “안철수, 뭘 몰라 저래…전당대회서 틀림없이 각목 나올것”',
#    '[정치] 홍정욱, 서울시장 불출마선언…자유한국당 인재영입 계획 ‘삐걱’',
#    '[경제] 문 대통령도 놀란 중국 간편결제, 우리는 어떤가 봤더니…'],
#   ['[정치] 형으로 갈아타거나 좀비로 떠돌거나…‘권불 14년’ 친박 생존법',
#    '[정치] 악마의 편집? ‘아베에 허리숙여 인사’ 사진이 억울한 홍준표',
#    '[정치] 채동욱의 강제퇴임 막전막후, 황교안 “변호사가 돈은 됩니다”',
#    '[사회] [단독] 대안학교 출신 첫 수능 만점자…제도권 교육만 정답인가요?',
#    '[정치] [영상] 웃으며 시작해 울며 끝난 류여해의 페북라이브',
#    '[문화] 영조가 사도세자 묘지문에서 직접 밝힌 죽음의 이유',
#    '[특화섹션] [ESC] 사랑섹스…‘초딩’이라고 무시하지 마세요',
#    '[사회] ‘아아악’ 비명 최순실, 오늘은 “독일 갔다 오든가” 특검에 핀잔',
#    '[정치] 홍준표, 국회 특활비 3번째 말바꾸기 “기억 착오” 발뺌',
#    '[사회] [단독] ‘다스BBK 고발’ 2주째…검찰, 기초조사도 안했다',
#    '[정치] 홍준표 정치인생 갈림길…‘성완종 리스트’ 사건 22일 대법원 선고',
#    '[사회] 유니세프 간부 “접대부 영어” 직원 성희롱…내부고발자만 해고',
#    '[사회] 외국인 남성이 “유 아 소 뷰티풀”…칭찬 아닌 ‘성희롱’',
#    '[사회] 소방당국 주차차량에 막히고, 통유리 창문에 구조 지연',
#    '[정치] 후원금 SNS 영상 읍소…‘완판남 거지갑’ 따라하기',
#    '[사회] MBC 간판이었던 ‘배신남매’ 배현진신동호의 운명은?',
#    '[국제] 유엔, 반트럼프 ‘예루살렘 결의안’ 압도적 채택',
#    '[정치] 안철수 의총 불참에 통합반대파 “끌고라도 와” 충돌',
#    '[사회] 위험천만 ‘알바 노동자’…안전판은 없다',
#    '[문화] 모두가 주인공이었던, 1987년을 정면으로 마주보다'],
#   ['[사회] 대법 “경비원, 아파트와 용역업체 계약 끝나도 해고 못한다”',
#    '[사회] 배현진, 오늘 MBC ‘뉴스데스크’부터 빠진다',
#    '[정치] 형으로 갈아타거나 좀비로 떠돌거나…‘권불 14년’ 친박 생존법',
#    '[사회] [단독] 지상파 3사 모두 ‘재허가 탈락점수’…초유의 사태',
#    '[사회] 가난과 죽음의 바닷길 따라 국민생선 명태가 온다',
#    '[사회] [단독]일부 일탈이라더니…다이소 ‘절대복종 각서’ 16년간 써',
#    '[사회] [단독] 대안학교 출신 첫 수능 만점자…제도권 교육만 정답인가요?',
#    '[사회] 검찰, 최순실 징역 25년 구형 “마지막까지 반성 없어”',
#    '[사회] 환자부담 줄인다는 ‘문재인 케어’ 의사들은 왜 반대할까',
#    '[사회] 7년 만에 돌아온 “MBC 뉴스 이용마입니다”',
#    '[사회] 연간 출국자 2천만명 넘는데…여권 속 ‘주민번호’가 위험하다',
#    '[정치] 홍준표, 국회 특활비 3번째 말바꾸기 “기억 착오” 발뺌',
#    '[사회] ‘문재인 케어 반대’ 의협 최대집 투쟁위원장, 극우단체 대표로 드러나',
#    '[사회] 우병우 구속 결정타 된 이석수는 아직도 ‘피의자’',
#    '[사회] 연세대 교수, 수업중 여학생 줄세우고 남학생들에 “선택하라”',
#    '[정치] 탄핵 없었다면 대선 D-6…다시 보는 보수언론 ‘문재인 저주’',
#    '[사회] [속보] 우병우 전 민정수석 ‘3번째 영장심사’ 끝에 구속',
#    '[사회] [단독] “MB소유 의혹 다스 수사, 윗선 지휘 안받는 특임검사 필요”',
#    '[정치] “뺑소니 야반도주”…민주당, 하와이행 자유한국당 국방위원들 맹폭']]]

# %%
#-*-coding:utf-8

from selenium import webdriver
from time import sleep
import bs4

URL = "http://newsrank.hani.co.kr/"

driver = webdriver.Chrome("C:\chrome\chromedriver.exe") # 크롬드라이버 주소 바꾸기 

driver.get(URL)
sleep(1)

# 상수
YEAR = 13
WEEK = 23

all_heads = get_all_headlines(YEAR, WEEK)
all_heads
# Out:
# [[[], [], [], [], [], [], []],
#  [[], [], [], [], [], [], []],
#  [[], [], [], [], [], [], []],
#  [['[사회] [단독] 최순실이 이 나라 대통령이었다',
#    '[사회] [단독] 황교안, 세월호 수사 틀어막고 인사보복 했다',
#    '[정치] [청문회] “완전 조작으로 몰아라” 최순실 통화음성 공개',
#    '[사회] [단독] ‘남편’ 최순실, ‘아내’ 박근혜, ‘사촌’ 문고리 3인방',
#    '[사회] [단독] 박 대통령 ‘왕수석’에 전화지시…“쓰고있냐” 채근',
#    '[정치] 변기 뜯고 해외 호텔에 화장 부스 만든 대통령',
#    '[사회] [단독] 최순실 청와대 쥐락펴락-김기춘 대리통치 ‘국정 양분’',
#    '[정치] [청문회] “정현식 왜 못막았어” 최순실 녹음파일 추가 공개',
#    '[정치] ‘꼼수’ 부리다 제 꾀에 걸려든 새누리당 ‘탄핵 방해자들’',
#    '[정치] 친박 막말의 끝은 어디인가…“패륜” “인간 이하”',
#    '[정치] [청문회] 친박 이완영, 비판여론 폭주에 “국조특위 간사 사퇴”',
#    '[정치] 최경환의 공개편지 “탄핵 막아야 한다”',
#    '[정치] ‘민폐 의전’ 황교안, 이번엔 대통령급 요구',
#    '[정치] 파이터? 막말꾼? 품격 없다지만 갈증도 없는 ‘성남 사이다’',
#    '[사회] [단독] ‘정윤회, 7억 인사개입’ 고 김영한 업무일지에서 확인',
#    '[사회] [영상] 김영재 의원 원장, 진료 기록 열람 막고 있어…특검 자료 받아가',
#    '[정치] 박정희박근혜최순실의 ‘추억’에 지워진 목소리',
#    '[정치] 친박 “김무성 유승민 나가” vs 비박 “최순실의 남자들 나가”',
#    '[사회] ‘박근혜 전용 변기’ 설치 위해 대기실 수도 공사까지',
#    '[정치] [단독] 삼성, 정유라에 주기로 계약한 돈은 220억이었다'],
#   ['[정치] [청문회] “최순실 모른다” 잡아떼던 김기춘, 영상 증거에 거듭 말바꾸기',
#    '[정치] [청문회] 얼굴 드러낸 장시호 “삼성서 16억문체부서 6억 받아”',
#    '[정치] [단독] 박 대통령, 세월호 가라앉을때 ‘올림머리’ 하느라 90분 날렸다',
#    '[경제] 전경련 탈퇴한다던 SKCJ, 말바꾸거나 오락가락',
#    '[사회] 김기춘 ‘야간의 주간화가정의 초토화…’ 살벌한 업무지침',
#    '[정치] [속보] 박대통령 즉각 퇴진 거부…“탄핵 절차 밟을 각오”',
#    '[사회] [단독]김기춘, ‘원세훈 무죄’ 비판한 판사 “직무배제” 지침 의혹',
#    '[정치] ‘꼼수’ 부리다 제 꾀에 걸려든 새누리당 ‘탄핵 방해자들’',
#    '[정치] [긴급] 박근혜 대통령 탄핵안 찬성 234표로 가결',
#    '[정치] 최경환의 공개편지 “탄핵 막아야 한다”',
#    '[경제] [청문회] 이재용 “전경련 활동하지 않겠다”',
#    '[경제] [단독] 재벌 총수들, 박대통령 독대때 구체적 ‘사업 민원’ 전달',
#    '[정치] 새누리 비주류발 ‘박근혜 1월 퇴진론’ 솔솔',
#    '[사회] 헌재 존립 흔드는 초유의 ‘김기춘-박한철 커넥션’ 의혹',
#    '[정치] 누리꾼박영선 손발 척척, ‘김기춘 거짓말’ 밝혀낸 전말은…',
#    '[정치] [청문회] 여명숙 “차은택 등이 받은 혜택? 종점을 모를 정도”',
#    '[정치] 친일후손 보수주의자가 새누리 의원들에게',
#    '[사회] 이건 ‘혁명에 준하는 상황’이 아니고 혁명이다',
#    '[사회] “대통령 ‘세월호 7시간’ 놀아도 된다”는 새누리 의원',
#    '[정치] 청와대 “대통령 옷가방값 정확히 지급했다” 해명'],
#   ['[사설·칼럼] [세상 읽기] 용서받지 못할 자 / 정남구',
#    '[정치] ‘질서있는 퇴진’ 제안 원로들도 “대통령 간교한 꼼수 써”',
#    '[정치] [속보] 새누리 ‘박대통령 4월 퇴진6월 대선’ 당론 채택',
#    '[사회] ‘박근혜 게이트 ’ 특검 , 수사팀장에 윤석열 지명',
#    '[사회] 이건 ‘혁명에 준하는 상황’이 아니고 혁명이다',
#    '[만화·만평] 12월 1일 한겨레 그림판',
#    '[정치] [속보] 추미애김무성 회동, 대통령 퇴진시기 합의 못해',
#    '[정치] ‘탄핵 명단 공개’ 표창원 트위터 “저를 비난하라”',
#    '[정치] 표창원, ‘탄핵 반대’ 의원 명단 SNS에 공개',
#    '[정치] ‘역대급’ 욕 먹었던 국민의당의 기나긴 하루',
#    '[정치] [단독] ‘친박 9인회’ 매일 모임…‘박대통령 반격 작전’ 짰다',
#    '[정치] 새누리 비박계 “7일 오후 6시까지 박대통령 퇴진시점 밝혀야”',
#    '[정치] 국민통합위원장에 ‘세월호 막말’ 전력 최성규 목사',
#    '[사회] [영상] ‘윤석열 특검 수사팀장’ 다시 보는 결정적 발언 세 장면',
#    '[사회] [단독] 삼성전자 ‘최순실에 80억’, 그룹 미래전략실에 사전보고했다',
#    '[정치] [팩트TV 생중계] ‘6차 촛불집회’ 이 시각 여의도',
#    '[사회] [단독] “경찰, 세월호 리본 단 경복궁 관람객 CCTV 감시미행 했다”',
#    '[사회] 탄핵 망설이는 국회 향한 ‘청원압박’ 사이트 등장',
#    '[정치] [댓글중계] 표창원 덕에 ‘SNS스타’된 새누리 장제원',
#    '[사회] [단독]국정교과서에 “유신헌법이 민주화운동 근거” 넣으려 했다'],
#   [],
#   [],
#   [],
#   []],
#  [['[사회] [단독] 최순실이 이 나라 대통령이었다',
#    '[사회] [단독] 정호성 휴대폰에 “주사 아줌마 들어가십니다”',
#    '[사회] [단독] 김기춘과 수시 통화한 김진태 총장, 정윤회 집 압수수색 막아',
#    '[정치] [영상] 반기문, 신천지 후계자로 꼽히는 여성과 악수 장면 포착',
#    '[사회] 청와대, ’세월호 감사자료’ 미리보고 고쳤다',
#    '[사회] [단독] “이완영 의원, 감사원 재직때 뒷돈 받아 사표 내”',
#    '[정치] [단독] ‘직권남용’ 딱 걸린 우병우…“이번엔 빠져나가기 힘들 것”',
#    '[정치] 변기 뜯고 해외 호텔에 화장 부스 만든 대통령',
#    '[정치] [영상] 우병우 말문 막히게 한 김경진의 ‘취조’ 질의',
#    '[사회] [단독] “김경숙 교수가 2013년 특기자 종목에 ‘승마 넣자’ 제안”',
#    '[사회] 네티즌수사대 자로, ‘세월호 침몰 원인’ 다룬 다큐 ‘SEWOLX’ 공개 예고',
#    '[사회] [단독] 교육부 ‘국정화 방침’ 발표 15분전에 바꿨다',
#    '[사회] [단독] 문체부, 블랙리스트 작업 컴퓨터 ‘하드 교체’ 의혹',
#    '[사회] [더친기] 박근혜 정권은 사법부를 어떻게 길들였나',
#    '[사회] [단독] 정호성 휴대폰에 “대통령 채혈 잘 챙기겠다“…또다른 혈액 반출 있다',
#    '[정치] [청문회] 친박 이완영, 비판여론 폭주에 “국조특위 간사 사퇴”',
#    '[정치] “이완영, JTBC가 태블릿피시 절도한 걸로 하자 제안해”',
#    '[사회] 네티즌수사대 ‘자로’ “세월호는 잠수함 충돌에 의해 침몰”',
#    '[사회] [단독] ‘정유라 지원’ 최지성 개입 포착, 특검 수사 이재용 턱밑까지',
#    '[정치] 박영선 “교도소장이 최순실에 쩔쩔매…저런 수감자 처음 봐”'],
#   ['[사회] [단독] 최순실이 이 나라 대통령이었다',
#    '[사회] [단독] 황교안, 세월호 수사 틀어막고 인사보복 했다',
#    '[사회] [청문회] 우병우, 대통령 ‘찌라시’ 발언 근거 묻자 ‘당황’',
#    '[정치] 이슬비 대위, ‘공가’로 조여옥 청문회 동참…국방부 개입 의혹',
#    '[정치] [단독] 우병우 “해경 상황실 서버 수색 말라”…세월호 수사팀에 압력',
#    '[정치] [단독] ‘직권남용’ 딱 걸린 우병우…“이번엔 빠져나가기 힘들 것”',
#    '[정치] 변기 뜯고 해외 호텔에 화장 부스 만든 대통령',
#    '[정치] [영상] 우병우 말문 막히게 한 김경진의 ‘취조’ 질의',
#    '[사회] [단독] 특검 “이재용, 최순실 존재 작년 7월 대통령 독대땐 알았을 것”',
#    '[사회] [더친기] 박근혜 정권은 사법부를 어떻게 길들였나',
#    '[만화·만평] 12월 20일 한겨레 그림판',
#    '[정치] “이완영, JTBC가 태블릿피시 절도한 걸로 하자 제안해”',
#    '[정치] [생중계] ‘우병우 출석’…최순실 국정농단 5차 청문회',
#    '[정치] ‘민폐 의전’ 황교안, 이번엔 대통령급 요구',
#    '[사회] [단독] 최순실 “다른 변호사 알아봐 달라” 검사에 부탁, 왜?',
#    '[사회] [단독] ‘정윤회, 7억 인사개입’ 고 김영한 업무일지에서 확인',
#    '[사회] [영상] 김영재 의원 원장, 진료 기록 열람 막고 있어…특검 자료 받아가',
#    '[정치] 박정희박근혜최순실의 ‘추억’에 지워진 목소리',
#    '[사회] 이건 ‘혁명에 준하는 상황’이 아니고 혁명이다']]]

# %%
with open("han_2016.data", "w") as f :
    f.write(str(all_heads))

# %%
# Out:
# dict

# %%
# 지윤 : 18년 6월 1일 ~ 19년 6월 1일
# 혜민 : 17년 6월 1일 ~ 18년 6월 1일
# 현지 : 16년 6월 1일 ~ 17년 6월 1일
