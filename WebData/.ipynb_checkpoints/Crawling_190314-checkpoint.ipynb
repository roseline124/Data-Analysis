# %% [markdown]
# Window키 - 시작 버튼 우클릭 - powershell : 커맨드보다 더 상향된 프롬프트를 사용할 수 있다.

# %% [markdown]
# vscode : extensions - korean language pack 한글화 기능

# %% [markdown]
# 확장자 자리수가 3자리 제한이 있었다. (그래서 html이 아니라 htm로 저장했어야 했던 것)

# %%
print("안녕하세요")
# Out:
# 안녕하세요

# %% [markdown]
# python 코드를 쓰는 것은 영화, 연극의 대본(script)을 짜는 것과 비슷하다

# %% [markdown]
# vscode : shift + enter 쳐서 한 줄씩 실행 가능

# %% [markdown]
# 예약어 확인하기
#
# `import keyword` <br>
# `print(keyword.kwlist)`

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# ?keyword

# %% [markdown]
# 파이썬 코딩 두가지 유형
#
# 1. 대화식 : interactive -> 바로바로 결과를 확인하고, 테스트하기에 좋다.(인터프리터->기계어 바로 번역해서 실행)
# 2. 스크립트식 : 대본을 짜는 것과 같다.
#
# ※컴파일러 : 기계어로 한꺼번에 번역해서 파일(.exe)을 만든다. 그럼 컴퓨터는 파일을 읽어서 실행만 하면 된다.

# %%
x = 5

while x > 0 : 
    print("x :", x)
    x -= 1
# Out:
# x : 5
# x : 4
# x : 3
# x : 2
# x : 1

# %%
print("Hello World")
# Out:
# Hello World

# %%
plus = 3+5
devide = 3/5
sqrt = 3**2
modular = 3%3

# %%
plus, devide, sqrt, modular
# Out:
# (8, 0.6, 9, 0)

# %% [markdown]
# 괄호 > 제곱 > 곱셈, 나눗셈

# %%
print("hello"*2)
# Out:
# hellohello

# %% [markdown]
# 컴퓨터는 부동소수점을 갖고 계산 <br>
# 자릿수의 제한이 있다보니 근사값을 갖고 계산한다.

# %%
x = 0.1
x + x + x
# Out:
# 0.30000000000000004

# %%
x = 1
type(x)
# Out:
# int

# %%
aaa = '123'

# %%
int(aaa)
# Out:
# 123

# %%
float(aaa)
# Out:
# 123.0

# %%
str(aaa)
# Out:
# '123'

# %%
txt = """
Hello 
World
"""

txtn = "Hello\nWorld"

print(txt)
print(txtn)
# Out:
# Hello
# World
#
# Hello
# World

# %% [markdown]
# input 명령어로 원하는 파일을 불러올 수 있다.

# %%
name = input("who are you? >")

print("hello %s" %name)
# Out:
# who are you? >hyunji
# hello hyunji

# %%
# 시급 계산기 
def pay_calculator() : 
    hours = int(input("몇 시간 일했나요? "))
    pay = int(input("시급은 얼마입니까? "))
    total = hours * pay 
    print("지급액 : %s 원" %total)
    
pay_calculator()
# Out:
# 몇 시간 일했나요? 15
# 시급은 얼마입니까? 8350
# 지급액 : 125250 원

# %%
def print_t(total) :
    print(f'{total}')

# %%
print_t("hello")
# Out:
# hello

# %%
"""
어떤 사업장에서 1주일 일하고 주급을 지불하는데 8시간 단
위로 1일로 하여 1일치 임금 70,000원을 줍니다.
그러나 일일 8시간을 못 채운 시간에 대해서는 최저임금인
8,350원을 지급할 때 사용자의 1주 노동시간을 입력 받아 주
급을 계산하는 프로그램을 만드시오.
(1주일 일한 시간이 50시간이라면 6일 일하고 2시간 추가 근
무한 것으로 간주합니다.)
"""

# 8hours = 1days = 7만 원 
# if < 8 : 1hours = 8350 

work_hours = int(input("1주간 몇 시간 일했나요? "))
days = work_hours//8
hours = work_hours%8
pay = (days*70000) + (hours*8350) 

print("일한 날 %d 일 %d 시간" %(days, hours))
print("지급액 : %s 원" %format(pay, ','))
# Out:
# 1주간 몇 시간 일했나요? 60
# 일한 날 7 일 4 시간
# 지급액 : 523,400 원

# %% [markdown]
# # 190321

# %%
# 실습 3번

try : 
    x = int(input("당신의 점수는? > "))
        
    if (x < 0) | (x > 100) : 
        raise ValueError
        
    elif x < 60 : 
        print("F학점")

    elif x < 70 : 
        print("D학점")

    elif x < 80 : 
        print("C학점")

    elif x < 90 : 
        print("B학점")

    elif x <= 100 : 
        print("A학점")

except : 
    print("0~100점 사이의 점수를 입력하세요.")
# Out:
# 당신의 점수는? > 15153525
# 0~100점 사이의 점수를 입력하세요.

# %%
s = "d"

type(s) != int
# Out:
# True

# %%
x = '안녕'
int_x = int(x)
print(int_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-31121113a056> in <module>
#       1 x = '안녕'
# ----> 2 int_x = int(x)
#       3 print(int_x)
#
# ValueError: invalid literal for int() with base 10: '안녕'

# %% [markdown]
# ### Try Except

# %%
try : 
    work_hours = int(input("1주간 몇 시간 일했나요? "))
    days = work_hours//8
    hours = work_hours%8
    pay = (days*70000) + (hours*8350)

    print("일한 날 %d 일 %d 시간" %(days, hours))
    print("지급액 : %s 원" %format(pay, ','))
    
except : 
    
    print("숫자를 입력하세요.")
# Out:
# 1주간 몇 시간 일했나요? 15
# 일한 날 1 일 7 시간
# 지급액 : 128,450 원

# %%
def even_or_flat():
    try: 
        num = int(input("숫자를 적어주세요 : "))

        if num % 2 == 1 : # 홀
            result = '홀수'
        else : 
            result = '짝수'
        
        print(f'{result} 입니다.')
        
    except:
        
        print("잘못 입력하셨습니다.")

# %%
even_or_flat()
# Out:
# 숫자를 적어주세요 : s
# 잘못 입력하셨습니다.

# %% [markdown]
# # 180328

# %% [markdown]
# ### 반복문

# %%
x = 5 

while x > 0  :
    print(x)
    x -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
while True : 
    x = input("입력 >")
    
    if x == "다시" :
        print(x + "마")
        
    elif x == "냥" :
        print("continue")
        continue
    else : 
        break
# Out:
# 입력 >다시
# 다시마
# 입력 >냥
# continue
# 입력 >ㅇ

# %% [markdown]
# ### 가장 큰 수 찾기

# %%
nums = [3,54,8,234,3459,645,742,6,3242]
max_n = 0

for n in nums : 
    if n > max_n : 
        max_n = n 
        
print(max_n)
# Out:
# 3459

# %% [markdown]
# ### 루프에서 개수 세기

# %%
nums = [3,54,8,234,3459,645,742,6,3242]
max_n = 0

step = 0

for n in nums : 
    step += 1
    
    if n > max_n : 
        max_n = n 

print(step)
# Out:
# 9
# 3459

# %% [markdown]
# ### 루프 합계 구하기

# %%
nums = [3,54,8,234,3459,645,742,6,3242]
max_n = 0
sum_n = 0 

for n in nums : 
    
    sum_n += n
    
    if n > max_n : 
        max_n = n 
        
print(sum_n)
# Out:
# 8393

# %% [markdown]
# ### 루프 평균 구하기

# %%
nums = [3,54,8,234,3459,645,742,6,3242]
len_n = 0
sum_n = 0

for n in nums : 
    len_n += 1
    sum_n += n 
    
mean_n = sum_n / len_n    

print("개수 :",  len_n)
print("합계 :",  sum_n)
print("평균 : %2.3f" %mean_n) #앞은 2자리, 뒤는 3자리
# Out:
# 개수 : 9
# 합계 : 8393
# 평균 : 932.556

# %% [markdown]
# ### 40보다 큰 수만 출력하기

# %%
nums = [3,54,8,234,3459,645,742,6,3242]
true_n = 0
false_n = 0
for n in nums : 
    if n > 40 : 
        print("TRUE", n)
        true_n += 1
    else : 
        print("False", n)
        false_n += 1
print("True :", true_n)
print("False:",false_n)
# Out:
# False 3
# TRUE 54
# False 8
# TRUE 234
# TRUE 3459
# TRUE 645
# TRUE 742
# False 6
# TRUE 3242
# True : 6
# False: 3

# %% [markdown]
# ### 가장 작은값 찾기

# %%
nums = [9, 3,54,8,234,3459,645,742,6,3242]

min_n = nums[0]

for n in nums : 

    if min_n > n : 
        min_n = n
    
print(min_n)
# Out:
# 3

# %% [markdown]
# ### up & down 게임

# %%
import random 

answer = random.randrange(1, 101)
count = 0

while True : 
    count += 1
    
    try :
        user_input = int(input("숫자를 입력하세요 : "))

        if user_input == answer : 
            print("정답!")
            break
        
        elif user_input < answer : 
            print("UP!")
            
        else : 
            print("Down!")
    
    except : 
        print("1부터 100까지의 '숫자'를 입력하세요.")
        
if count <= 3 : 
    print("%d번 만에 맞춘 당신은 천재!" %count)
    
elif count <= 7 : 
    print("%d번 만에 맞춘 당신은 평균!" %count)
    
else : 
    print("%d번 만에 맞춘 당신은 바보!" %count)
# Out:
# 숫자를 입력하세요 : wdf
# 1부터 100까지의 '숫자'를 입력하세요.
# 숫자를 입력하세요 : 50
# UP!
# 숫자를 입력하세요 : 75
# UP!
# 숫자를 입력하세요 : 85
# Down!
# 숫자를 입력하세요 : 80
# Down!
# 숫자를 입력하세요 : 79
# 정답!
# 6번 만에 맞춘 당신은 평균!

# %%
import random 

# Pick Answer
answer = random.randrange(1, 101)
count = 0

# Up & Down 
while True : 
    try :
        user_input = int(input("숫자를 입력하세요 : "))
        
        if (user_input >= 100) | (user_input < 0) :
            raise ValueError
            
    except : 
        print("1부터 100까지의 '숫자'를 입력하세요.")
        
    else : 
        count += 1

        if user_input == answer : 
            print("정답!")
            break
        
        elif user_input < answer : 
            print("UP!")
            
        else : 
            print("Down!")
      
# Evaluation 
if count <= 3 : 
    print("%d번 만에 맞춘 당신은 천재!" %count)
    
elif count <= 7 : 
    print("%d번 만에 맞춘 당신은 평균!" %count)
    
else : 
    print("%d번 만에 맞춘 당신은 바보!" %count)
# Out:
# 숫자를 입력하세요 : 250
# 1부터 100까지의 '숫자'를 입력하세요.
# 숫자를 입력하세요 : sdf
# 1부터 100까지의 '숫자'를 입력하세요.
# 숫자를 입력하세요 : -213
# 1부터 100까지의 '숫자'를 입력하세요.
# 숫자를 입력하세요 : -1
# 1부터 100까지의 '숫자'를 입력하세요.
# 숫자를 입력하세요 : 50
# Down!
# 숫자를 입력하세요 : 75
# Down!
# 숫자를 입력하세요 : 25
# UP!
# 숫자를 입력하세요 : 35
# UP!
# 숫자를 입력하세요 : 45
# Down!
# 숫자를 입력하세요 : 40
# Down!
# 숫자를 입력하세요 : 48
# Down!
# 숫자를 입력하세요 : 47
# Down!
# 숫자를 입력하세요 : 46
# Down!
# 숫자를 입력하세요 : 39
# Down!
# 숫자를 입력하세요 : 38
# 정답!
# 11번 만에 맞춘 당신은 바보!

# %% [markdown]
# ### 190404
#
# 문자 카운트

# %%
from collections import Counter

# %%
print("내 이름은 %s이고, %d살입니다." %("송현지", 24))
# Out:
# 내 이름은 송현지이고, 24살입니다.

# %%
s = "hello world"
s.count("l")
# Out:
# 3

# %%
','.join(s)
# Out:
# 'h,e,l,l,o, ,w,o,r,l,d'

# %%
# 맨 첫글자만 대문자로 변환
s.capitalize()
# Out:
# 'Hello world'

# %%
s.find("wor")
# Out:
# 6

# %% [markdown]
# lstrip # left strip : 왼쪽의 공백 제거 <br>
# rstrip # right strip : 오른쪽의 공백 제거

# %%
word = '     hello     '

# %%
word.lstrip()
# Out:
# 'hello     '

# %%
word.rstrip()
# Out:
# '     hello'

# %%
word.strip()
# Out:
# 'hello'

# %% [markdown]
# ### 파일 읽기

# %%
with open("test.txt", "w", encoding="utf-8") as f : # r : 읽기 모드, t : text -> 둘 다 기본값. 
    f.write("hello world")

# %%
s.startswith("h")
# Out:
# True

# %% [markdown]
# ### 실습

# %%
with open("work_py/kakao.txt", "r", encoding="utf-8") as f : 
    lines = f.read()
    lines = lines.replace('\n', '').replace('2018년', '\n2018년')
    
with open("work_py/kakaofix.txt", "w", encoding="utf-8") as fd : 
    fd.write(lines)

# %% [markdown]
# ### 6주차 실습

# %%
import re 
from collections import Counter

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    lines = f.read()
    
    # 파싱
    p = re.compile('^From\s.*$', re.MULTILINE)
    Froms = p.findall(lines)
    days = list(map(lambda x: x.split()[-5], Froms))
    days_str = ' '.join(days)
    
    # 개수
    cnt_Fri = Counter(days)['Fri']
    print(cnt_Fit)
    
with open("work_py/day-s.txt", "w", encoding="utf-8") as fd : 
    fd.write(days_str)

# %%
with open("work_py/day-s.txt", "w", encoding="utf-8") as fd : 
    fd.write(days_str)

# %%
import re 

p = re.compile('^From')
results = p.findall(lines)

# %%
results
# Out:
# ['From']

# %%
txt = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n'

# %%
p = re.compile(r'^From\s\w+\W\w+\W\w+\W(?:\s|\w+)(?:\s|\W)(?:\s|\w+)\s(?:\s|\w+)', re.MULTILINE)

# %%
p = re.compile('^From\s.*$', re.MULTILINE)

# %%
Froms = p.findall(lines)

# %%
days = list(map(lambda x: x.split()[-5], Froms))

# %%
days_txt = ' '.join(days)
# Out:
# 'Sat Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Fri Thu Thu Thu Thu Thu Thu'

# %%
from collections import Counter

# %%
cnt_Fri = Counter(days)['Fri']
print(cnt_Fit)
# Out:
# 20

# %% [markdown]
# ### 190418

# %%
nums = [1,2,3,1,1]

num_dict = {}

for n in nums : 
    if n in num_dict : 
        num_dict[n] += 1
    else : 
        num_dict[n] = 1

# %%
num_dict
# Out:
# {1: 3, 2: 1, 3: 1}

# %%
for n in nums : 
    num_dict[n] : num_dict.get(n, 0) + 1 # 키가 있으면 n에 1을 더하고, 키가 없으면 기본값 0으로 설정

# %%
num_dict.get(4,0)
# Out:
# 0

# %% [markdown]
# ### 190502 정규표현식
#
# - [정규표현식](https://ko.wikipedia.org/wiki/%EC%A0%95%EA%B7%9C_%ED%91%9C%ED%98%84%EC%8B%9D)

# %%
import re 
from collections import Counter

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    lines = f.read()
    
    # 파싱
    p = re.compile('^From\s.*$', re.MULTILINE)
    Froms = p.findall(lines)
    days = list(map(lambda x: x.split()[-5], Froms))
    days_str = ' '.join(days)
    
    # 개수
    cnt_Fri = Counter(days)['Fri']
    print(cnt_Fri)
    
with open("work_py/day-s.txt", "w", encoding="utf-8") as fd : 
    fd.write(days_str)
# Out:
# 20

# %%
import re

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    hand = f.read().split('\n')
    for line in hand : 
        line = line.rstrip()
        if re.search('From:', line):
            print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
import re

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    hand = f.read().split('\n')
    for line in hand : 
        line = line.rstrip()
        if re.search('^From:', line):
            print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %% [markdown]
# **숫자, 문자 찾기**

# %%
import re 

x = 'My 2 fabcvorite numbers are 3 and 37'
y = re.findall('[0-9]+',x)
print(y)
z = re.findall('[AEIOU]+',x)
print(z)
t = re.findall('[ae]+',x)
print(t)

abc = re.findall('[a-c]+',x)
print(abc)
# Out:
# ['2', '3', '37']
# []
# ['a', 'e', 'e', 'a', 'e', 'a']
# ['abc', 'b', 'a', 'a']

# %% [markdown]
# **탐욕적인 방법**

# %%
x = 'From: Using the : character'
y = re.findall('^F.+:',x)
print(y)
# Out:
# ['From: Using the :']

# %% [markdown]
# **비탐욕적인 방법 : '?'**

# %%
x = 'From: Using the : character'
y = re.findall('^F.+?:',x)
print(y)
# Out:
# ['From:']

# %%
x = 'ac abc abbc abbbc'
y = re.findall('a.c', x)
print(y)
# Out:
# ['abc']

# %%
x = 'ac abc abbc abbbc'
y = re.findall('ab+c', x)
print(y)
# Out:
# ['abc', 'abbc', 'abbbc']

# %%
x = 'ac abc abbc abbbc'
y = re.findall('ab{2,3}c', x)
print(y)
# Out:
# ['abbc', 'abbbc']

# %% [markdown]
# - \S : 공백이 없다.

# %%
import re 
x = 'From guseod24@naver.com Thu Apr 4 13:35:21 2019'
y = re.findall('\S+@\S+', x)
print(y)
# Out:
# ['guseod24@naver.com']

# %% [markdown]
# - 시작할 때의 '^'은 시작점을 의미한다.
# - 대괄호 안의 '^'은 not을 의미한다.

# %%
import re 
x = 'From guseod24@naver.com Thu Apr 4 13:35:21 2019'
y = re.findall('@([^ ]*)', x)
print(y)

z = re.findall('^From .*@([^ ]*)', x)
print(z)
# Out:
# ['naver.com']
# ['naver.com']

# %% [markdown]
# ### 실습

# %%
import re

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    hand = f.read().split('\n')
    for line in hand : 
        line = line.rstrip()
        if re.search('^From:', line):
            print(line)

# %%
import re 

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    lines = f.read()
    
    p = re.compile('^X-DSPAM-Confidence:.*', re.MULTILINE)
    spam_prob = p.findall(lines)
    probs = [ prob[20:] for prob in spam_prob]
    print(max(probs))
# Out:
# 0.9907

# %%
len('X-DSPAM-Confidence: ')
# Out:
# 20

# %% [markdown]
# ### 숙제 리뷰

# %%
import re

with open("work_py/mbox-s.txt", "r", encoding="utf-8") as f : 
    numlist = []
    lines = f.read()
    lines = lines.split()
    for line in lines : 
        x = re.findall('^X-DSPAM-Confidence: ([0.-9]+)', line)
        numlist.append(x)
    
print('Max :', max(numlist))
# Out:
# Max : []

# %%
res = c.findall('life is too short')
res2 = n.findall('3 python 2')

print(res)
print(res2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9e1f864048c8> in <module>
# ----> 1 res = c.findall('life is too short')
#       2 res2 = n.findall('3 python 2')
#       3
#       4 print(res)
#       5 print(res2)
#
# NameError: name 'c' is not defined

# %% [markdown]
# ### 소켓 통신

# %%
import socket 

# socket.AF_INET IP4 버전으로 통신하겠다.
# socket.SOCK_STREAM : 패킷 단위가 아니라 물 흐르듯이 데이터를 통신하겠다.

mysocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM) 
mysocket.connect( ('www.example.com', 80) ) # 두번째는 port 번호. 일반 html 포트는 80번 포트 사용

cmd = 'GET http://www.example.com HTTP/1.0 \r\n\r\n'.encode() # 데이터 요청
mysocket.send(cmd)

while True:
    data = mysocket.recv(128) # 몇 바이트로 수신할 건지 설정 
    if (len(data)) < 1 : 
        break
    
    print(data.decode())
    
mysocket.close()
# Out:
# HTTP/1.0 200 OK
# Cache-Control: max-age=604800
# Content-Type: text/html; charset=UTF-8
# Date: Thu, 09 May 2019 05:01:35 GMT
# Eta
# g: "1541025663+ident"
# Expires: Thu, 16 May 2019 05:01:35 GMT
# Last-Modified: Fri, 09 Aug 2013 23:54:35 GMT
# Server: ECS (sec/97
# 6A)
# Vary: Accept-Encoding
# X-Cache: HIT
# Content-Length: 1270
# Connection: close
#
# <!doctype html>
# <html>
# <head>
#     <title>Ex
# ample Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#
#  <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         backgroun
# d-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, s
# ans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 50px;
#         background-co
# lor: #fff;
#         border-radius: 1em;
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#
# }
#     @media (max-width: 700px) {
#         body {
#             background-color: #fff;
#         }
#         div {
#             width:
# auto;
#             margin: 0 auto;
#             border-radius: 0;
#             padding: 1em;
#         }
#     }
#     </style>
# </hea
# d>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is established to be used for illustrative examples in documents
# . You may use this
#     domain in examples without prior coordination or asking for permission.</p>
#     <p><a href="http://www.ia
# na.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
import requests

res = requests.get('http://www.example.com')
ex = res.text

print(ex)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 50px;
#         background-color: #fff;
#         border-radius: 1em;
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         body {
#             background-color: #fff;
#         }
#         div {
#             width: auto;
#             margin: 0 auto;
#             border-radius: 0;
#             padding: 1em;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is established to be used for illustrative examples in documents. You may use this
#     domain in examples without prior coordination or asking for permission.</p>
#     <p><a href="http://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %% [markdown]
# ### 190516

# %% [markdown]
# **requests.get(url주소)**

# %%
import requests

url = "https://www.naver.com"
res = requests.get(url)
res.status_code
res.text
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta property="og:title" content="네이버">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://www.naver.com/">\n<meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n\n\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" />\n\n<link rel="stylesheet" type="text/css" href="https://pm.pstatic.net/css/main_v190430.css"/> \n<link rel="stylesheet" type="text/css" href="https://pm.pstatic.net/css/webfont_v170623.css"/>\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css"/>\n\n\n<script type="text/javascript" src="https://pm.pstatic.net/js/c/nlog_v181107.js"></script>\n\n<script type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/assets/js/common/min/probe.min.js"></script>\n<script type="text/javascript">\nvar nsc = "navertop.v3";\ndocument.domain = "naver.com";\nvar jindoAll = "";\nvar iframeLazyLoad = false;\nif (!!!window.console) {window.console={};window.console["log"]=function(){}}\nvar isLogin = false; \nfunction refreshLcs(etc) {etc = etc ? etc : {};if(document.cookie.indexOf("nrefreshx=1") != -1) {etc["mrf"]="1";} else {etc["pan"]="mov";}return etc;}\n\n</script>\n<title>NAVER</title>\n</head>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style>\n\t#_nx_kbd .setkorhelp a { display:none; }\n</style>\n<body class=\'\'>\n\t<!-- 스킵 내비게이션 -->\n\t<div class="u_skip">\n\t\t<a href="#news_cast" onclick="document.getElementById(\'news_cast2\').tabIndex = -1;document.getElementById(\'news_cast2\').focus();return false;"><span>연합뉴스 바로가기</span></a>\n\t\t<a href="#themecast" onclick="document.getElementById(\'themecast\').tabIndex = -1;document.getElementById(\'themecast\').focus();return false;"><span>주제별캐스트 바로가기</span></a>\n\t\t<a href="#time_square" onclick="document.getElementById(\'time_square\').tabIndex = -1;document.getElementById(\'time_square\').focus();return false;"><span>타임스퀘어 바로가기</span></a>\n\t\t<a href="#shp_cst" onclick="document.getElementById(\'shp_cst\').tabIndex = -1;document.getElementById(\'shp_cst\').focus();return false;"><span>쇼핑캐스트 바로가기</span></a>\n\t\t<a href="#account" onclick="document.getElementById(\'account\').tabIndex = -1;document.getElementById(\'account\').focus();return false;"><span>로그인 바로가기</span></a>\n\t</div>\n\t<!-- //스킵 내비게이션 -->\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\t<div id="PM_ID_ct" class="wrap" >\n\t\t<!-- 헤더 -->\n<div class="header" role="banner">\n\t\n\n\n\n\n\n\n<div class="special_bg">\n<div class="area_flex">\n<div class="area_logo">\n<h1>\n<a data-clk="top.logo" href="/"><span class="naver_logo">네이버</span></a>\n</h1>\n</div>\n<div class="area_links">\n<a data-clk="top.mkhome" href="http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver" class="al_favorite">네이버를 시작페이지로<span class="al_ico_link"></span></a>\n<span class="al_bar"></span>\n<a data-clk="top.jrnaver" href="http://jr.naver.com" class="al_jr"><span class="blind">쥬니어네이버</span><span class="al_ico"></span></a>\n<a data-clk="top.happyb ...

# %%
res.headers
# Out:
# {'Server': 'NWS', 'Date': 'Thu, 16 May 2019 03:23:46 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'PM_CK_loc=f5d35e36316126044ae43aad6723238a2173b1e13cac4a406d1c4af5824a077b; Expires=Fri, 17 May 2019 03:23:46 GMT; Path=/; HttpOnly', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'P3P': 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"', 'X-Frame-Options': 'DENY', 'X-XSS-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains', 'Referrer-Policy': 'unsafe-url'}

# %%
res.content
# Out:
# b'<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\n<meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://www.naver.com/">\n<meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta name="twitter:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>\n\n\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico" />\n\n<link rel="stylesheet" type="text/css" href="https://pm.pstatic.net/css/main_v190430.css"/> \n<link rel="stylesheet" type="text/css" href="https://pm.pstatic.net/css/webfont_v170623.css"/>\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css"/>\n\n\n<script type="text/javascript" src="https://pm.pstatic.net/js/c/nlog_v181107.js"></script>\n\n<script type="text/javascript" src="https://ssl.pstatic.net/tveta/libs/assets/js/common/min/probe.min.js"></script>\n<script type="text/javascript">\nvar nsc = "navertop.v3";\ndocument.domain = "naver.com";\nvar jindoAll = "";\nvar iframeLazyLoad = false;\nif (!!!window.console) {window.console={};window.console["log"]=function(){}}\nvar isLogin = false; \nfunction refreshLcs(etc) {etc = etc ? etc : {};if(document.cookie.indexOf("nrefreshx=1") != -1) {etc["mrf"]="1";} else {etc["pan"]="mov";}return etc;}\n\n</script>\n<title>NAVER</title>\n</head>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<style>\n\t#_nx_kbd .setkorhelp a { display:none; }\n</style>\n<body class=\'\'>\n\t<!-- \xec\x8a\xa4\xed\x82\xb5 \xeb\x82\xb4\xeb\xb9\x84\xea\xb2\x8c\xec\x9d\xb4\xec\x85\x98 -->\n\t<div class="u_skip">\n\t\t<a href="#news_cast" onclick="document.getElementById(\'news_cast2\').tabIndex = -1;document.getElementById(\'news_cast2\').focus();return false;"><span>\xec\x97\xb0\xed\x95\xa9\xeb\x89\xb4\xec\x8a\xa4 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a>\n\t\t<a href="#themecast" onclick="document.getElementById(\'themecast\').tabIndex = -1;document.getElementById(\'themecast\').focus();return false;"><span>\xec\xa3\xbc\xec\xa0\x9c\xeb\xb3\x84\xec\xba\x90\xec\x8a\xa4\xed\x8a\xb8 \xeb\xb0\x94\xeb\xa1\x9c\xea\xb0\x80\xea\xb8\xb0</span></a>\n\t\t<a href="#time_square" onclick="document.getElementById(\'time_square\').tabIndex = -1;document.getElementById(\'time_s ...

# %%
res.encoding
# Out:
# 'UTF-8'

# %% [markdown]
# ### url query string
#
# - url 에 파라미터를 전달해서 원하는 정보를 가져온다.
# - ? 다음 부분 : '?변수=값&변수=값'의 형태가 반복되는 형태
# - parameter 값을 딕셔너리로 지정해서 requests.get()에 params 옵션에 전달
# - requests.post()는 url이 아니라 body에 보낸다. data 옵션에 딕셔너리 전달
# - id와 pw로 인증하는 경우 : `res = requests.post(url, auth=["id", "password"])`
# - 요청 헤더 headers나 , cookies를 지정해줘야 하는 경우가 있다. 이런 경우는 get()의 headers, cookies 옵션을 지정해준다.

# %% [markdown]
# ### status code
#
# - 100 : 조건부 응답 / 서버가 데이터를 더 보내달라는 코드
# - 200 : 응답 성공
# - 300 : 리다이렉션 성공
# - 400 : 요청 오류
# - 500 : 서버 오류

# %% [markdown]
# ### BeautifulSoup4 : 파싱 모듈

# %% [markdown]
# ### 분석 단계
#
# 1. 어떤 정보를 가져올지 정한다.
# 2. F12로 사이트를 분석한다.

# %%
import requests, bs4 
url = "http://mis.re.kr"
res = requests.get(url)
html = res.text

bs = bs4.BeautifulSoup(html, 'html.parser')
tags = bs.select('h2.post-title')
print(tags)
# Out:
# [<h2 class="post-title">
# <a href="http://mis.re.kr/archives/1219">
#                                         [헤럴드 포럼-채미옥 한국감정원 부동산연구원장] 전·월세신고제 왜 필요한가                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1211">
#                                         [배준호의 역사구락부] 한일 격차 600년, (11) 주목할 일곱 선비                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1207">
#                                         [배준호의 역사구락부] 한일 격차 600년, (10) 축소ㆍ해소의 배경                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1200">
#                                         [기고-채미옥 한국감정원 부동산연구원장] 장기 미집행도시계획시설, 통합적 접근이 필요하다                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1189">
#                                         국가 존립의 문제, 저출산 위기와 대응 방향                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1185">
#                                         품질이 산업이다                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1177">
#                                         [기고] 산학민관 車산업 컨트롤타워 만들어야                    </a>
# </h2>, <h2 class="post-title">
# <a href="http://mis.re.kr/archives/1174">
#                                         빅데이타 플랫폼, 기초정보 수집체계부터 바로잡자                    </a>
# </h2>]

# %%
for line in tags:
    print(line.getText().strip()) #strip : 앞 뒤 공백제거
# Out:
# [헤럴드 포럼-채미옥 한국감정원 부동산연구원장] 전·월세신고제 왜 필요한가
# [배준호의 역사구락부] 한일 격차 600년, (11) 주목할 일곱 선비
# [배준호의 역사구락부] 한일 격차 600년, (10) 축소ㆍ해소의 배경
# [기고-채미옥 한국감정원 부동산연구원장] 장기 미집행도시계획시설, 통합적 접근이 필요하다
# 국가 존립의 문제, 저출산 위기와 대응 방향
# 품질이 산업이다
# [기고] 산학민관 車산업 컨트롤타워 만들어야
# 빅데이타 플랫폼, 기초정보 수집체계부터 바로잡자
