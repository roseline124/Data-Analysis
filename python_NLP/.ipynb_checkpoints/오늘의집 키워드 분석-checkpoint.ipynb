# %%
txt = """
인테리어 소품 가구
디자인,표현,컨텐츠커머스
인테리어. 가구. 구경
가구, 공유, 셀프인테리어
가구, 인테리어소품, 구매가격
집 인테리어
따뜻함, 트렌디, 심플함
인테리어 디자인 인스타그램
인테리어,다른사람들이한 인테리어,편리함
깔끔하다 아늑 집들이
자취 인테리어 모던함
카페 인테리어 감성
집이모티콘, 깔끔하다, 세련
후기, 저렴함, 추천 디자인
DIY 취향맞춤형 셀프인테리어
하늘색 집 모양 어플, 자취방 인테리어, 레드비트팀도 화이팅,,
인테리어. 집. 저렴하다.
인테리어, 소품, 자취방
쇼핑과 관상용으로 사용
개인의 창의성을 표현하는 매우 유용한 수단이라고 생각해요.컨텐츠와 커머스를 결합한 매우 유용한 비즈니스 플랫폼입니다
가구를 쉽게 찾아 구매할 수 있어서, 사람들이 좋은 상품이나 자신의 인테리어를 공유해서, 셀프 인테리어한 여러 집을 구경할 수 있어서
그런 제품 많이 봤다
오늘의 집이라서
이사갈때 집꾸미기에 도움이 많이되어씀
인테리어-그냥 가구 파는데 이쁨
다른사람들이 한 인테리어-다른사람들이 자기 집 인테리어를 많이 올려 참고가 됩니당
편리함-여려종류 집에 필요한것들이 모여있어 따로따로 찾을 필요가 없습니당
볼때마다 사고싶은것도 많고 예쁜 물건도 많고 인테리어도 다 너무 예뻐서
일단 사람들이 꾸민 인테리어에 대한 정보가 굉장히 많아서 생각이 났다 대부분 젊은이들이 감성적인 인테리어를 해서 저게 딱 생각났다 카페는 요즘 감성카페가 많은데 그런 디자인류가 어플에 많아서 (뜬금없지만) 제일 먼저 떠올랐다
감각적으로 자극하는 부분이 많음
오늘의집을 사용하게된 주된 장점
집를 어떻게 꾸밀지 막막한 사람들에게 맞는 인테리어 디자인을 제공해주기때문
자취방 꾸밀려고 저도 깔았거든요.
집인테리어를 저렴하게 할 수 있어서
인테리어 하기 좋은 소품 많아서"""

# %%
import nltk 
from konlpy.tag import Okt; t = Okt()

# %%
tokens_ko = t.morphs(txt)
tokens_ko
# Out:
# ['\n',
#  '인테리어',
#  '소품',
#  '가구',
#  '\n',
#  '디자인',
#  ',',
#  '표현',
#  ',',
#  '컨텐츠',
#  '커머스',
#  '\n',
#  '인테리어',
#  '.',
#  '가구',
#  '.',
#  '구경',
#  '\n',
#  '가구',
#  ',',
#  '공유',
#  ',',
#  '셀프',
#  '인테리어',
#  '\n',
#  '가구',
#  ',',
#  '인테리어',
#  '소품',
#  ',',
#  '구매',
#  '가격',
#  '\n',
#  '집',
#  '인테리어',
#  '\n',
#  '따뜻함',
#  ',',
#  '트렌디',
#  ',',
#  '심플',
#  '함',
#  '\n',
#  '인테리어',
#  '디자인',
#  '인스타그램',
#  '\n',
#  '인테리어',
#  ',',
#  '다른사람',
#  '들이한',
#  '인테리어',
#  ',',
#  '편리함',
#  '\n',
#  '깔끔하다',
#  '아늑',
#  '집들이',
#  '\n',
#  '자취',
#  '인테리어',
#  '모던',
#  '함',
#  '\n',
#  '카페',
#  '인테리어',
#  '감성',
#  '\n',
#  '집',
#  '이모티콘',
#  ',',
#  '깔끔하다',
#  ',',
#  '세련',
#  '\n',
#  '후기',
#  ',',
#  '저렴함',
#  ',',
#  '추천',
#  '디자인',
#  '\n',
#  'DIY',
#  '취향',
#  '맞춤',
#  '형',
#  '셀프',
#  '인테리어',
#  '\n',
#  '하늘색',
#  '집',
#  '모양',
#  '어플',
#  ',',
#  '자취',
#  '방',
#  '인테리어',
#  ',',
#  '레드',
#  '비트',
#  '팀',
#  '도',
#  '화이팅',
#  ',,',
#  '\n',
#  '인테리어',
#  '.',
#  '집',
# ...

# %%
ko = nltk.Text(tokens_ko, name='오늘의집')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 369
# 180

# %%
ko = nltk.Text(tokens_ko, name='오늘의집')
ko.vocab().most_common(10)
# Out:
# [('\n', 35),
#  ('인테리어', 25),
#  (',', 20),
#  ('집', 11),
#  ('이', 8),
#  ('.', 7),
#  ('가구', 6),
#  ('를', 6),
#  ('들', 6),
#  ('디자인', 5)]

# %%
stop_words = ['함', ',', '.', '\n', '이', '를', '들', '가', '의', '을', '한', '할', '수', '있어서', '많이', '-', '에', 
             '도', '많아서', '으로', '사용', '하는', '매우', '으로', '생각', '해서', '그런', '많고', '적', '저','과', '용', '이라고'
             '해요', '와', '이라고', '오늘', '집', '인테리어']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='오늘의집')
ko.vocab().most_common(20)
# Out:
# [('가구', 6),
#  ('디자인', 5),
#  ('소품', 4),
#  ('자취', 4),
#  ('셀프', 3),
#  ('다른사람', 3),
#  ('카페', 3),
#  ('감성', 3),
#  ('방', 3),
#  ('사람', 3),
#  ('표현', 2),
#  ('컨텐츠', 2),
#  ('커머스', 2),
#  ('구경', 2),
#  ('공유', 2),
#  ('구매', 2),
#  ('편리함', 2),
#  ('깔끔하다', 2),
#  ('어플', 2),
#  ('유용한', 2)]

# %%
from matplotlib import font_manager, rc 
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt 

# %matplotlib inline

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system. Sooooorry.')

plt.rcParams['axes.unicode_minus'] = False

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

data = ko.vocab().most_common(300)

wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.5,
                      background_color='white'
                     ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
