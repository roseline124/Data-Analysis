# %%
with open('dataset/tw_cereal.data', 'r', encoding='utf-8') as f: 
    tw = f.read()

# %%
import nltk 
from konlpy.tag import Okt; t = Okt()

# %%
tw_text = ''

for each_line in tw :
    tw_text = tw_text + each_line

# %%
tokens_ko = t.morphs(tw_text)
tokens_ko
# Out:
# ['노란색',
#  '하트',
#  '노란색',
#  '하트',
#  '기범이',
#  '의',
#  '아침',
#  '팬케이크',
#  '팬케이크',
#  '요리',
#  '요리',
#  '검정색',
#  '하트',
#  '검정색',
#  '하트',
#  '북어',
#  '채국',
#  '돼지고기',
#  '김치',
#  '볶음',
#  '맛김',
#  '배추김치',
#  '녹색',
#  '하트',
#  '녹색',
#  '하트',
#  '기범이',
#  '의',
#  '점심',
#  '야채',
#  '샐러드',
#  '야채',
#  '샐러드',
#  '속',
#  '을',
#  '채운',
#  '납작한',
#  '빵',
#  '속',
#  '을',
#  '채운',
#  '납작한',
#  '빵',
#  '파란색',
#  '하트',
#  '파란색',
#  '하트',
#  '닭볶음탕',
#  '만',
#  '두',
#  '튀김',
#  '배추',
#  '겉절이',
#  '현미',
#  '밥',
#  '깍두기',
#  '주황색',
#  '하트',
#  '주황색',
#  '하트',
#  '기범이',
#  '의',
#  '저녁',
#  '빠에야',
#  '빠에야',
#  '접시',
#  '및',
#  '포크',
#  '와',
#  '나이프',
#  '접시',
#  '및',
#  '포크',
#  '와',
#  '나이프',
#  '검정색',
#  '하트',
#  '검정색',
#  '하트',
#  '햄',
#  '치즈버거',
#  '삶은',
#  '달걀',
#  '감자',
#  '튀김시리',
#  '얼쌀',
#  '초코',
#  '혼합',
#  '두꺼운',
#  '빨간색',
#  '하트',
#  '두꺼운',
#  '빨간색',
#  '하트',
#  '기범이',
#  '의',
#  '후식',
#  '베이컨',
#  '베이컨',
#  '노란색',
#  '하트',
#  '노란색',
#  '하트',
#  '우유',
#  '딸기',
#  '제레미',
#  '이안',
#  '이',
# ...

# %%
ko = nltk.Text(tokens_ko, name='tweet')

# %%
ko = nltk.Text(tokens_ko, name='tweet')
ko.vocab().most_common(100)
# Out:
# [('하트', 20),
#  ('시리얼', 19),
#  ('이', 12),
#  ('을', 10),
#  ('에', 9),
#  ('의', 7),
#  ('파란색', 6),
#  ('와', 6),
#  ('초코', 6),
#  ('그릇', 6),
#  ('를', 5),
#  ('너무', 5),
#  ('노란색', 4),
#  ('기범이', 4),
#  ('검정색', 4),
#  ('가', 4),
#  ('도', 4),
#  ('크레마', 4),
#  ('손뼉', 4),
#  ('치는', 4),
#  ('손', 4),
#  ('기호', 4),
#  ('속', 3),
#  ('및', 3),
#  ('우유', 3),
#  ('으로', 3),
#  ('생각', 3),
#  ('한', 3),
#  ('은', 3),
#  ('하고', 3),
#  ('너', 3),
#  ('때', 3),
#  ('얼굴', 3),
#  ('에서', 3),
#  ('하는', 3),
#  ('아침', 2),
#  ('팬케이크', 2),
#  ('요리', 2),
#  ('녹색', 2),
#  ('야채', 2),
#  ('샐러드', 2),
#  ('채운', 2),
#  ('납작한', 2),
#  ('빵', 2),
#  ('두', 2),
#  ('주황색', 2),
#  ('빠에야', 2),
#  ('접시', 2),
#  ('포크', 2),
#  ('나이프', 2),
#  ('두꺼운', 2),
#  ('빨간색', 2),
#  ('베이컨', 2),
#  ('잠', 2),
#  ('깼는지', 2),
#  ('라고', 2),
#  ('날', 2),
#  ('보고', 2),
#  ('스푼', 2),
#  ('놓인', 2),
#  ('구매', 2),
#  ('님', 2),
#  ('안', 2),
#  ('거', 2),
#  ('흑', 2),
#  ('완전', 2),
#  ('왜', 2),
#  ('오늘', 2),
#  ('했어', 2),
#  ('시', 2),
#  ('우', 2),
# ...

# %%
stop_words = ['이', '의', '을', '에', '들', '가', '인데', '라고', 'ㅜ', '엔', 'ㅊㅐ', '저', '못',
             '내', '기', '대', '하고', '만', '네', '와', '적', '시', '이랑', '아니', '뭐', '하고', '분', '해'
             ,'수', '거', '와', '야', '가', '27', '에서', 'x', '적', '.......', '하고', '하면',
              '&#', '(', ')', ':', '는', '은', '으로', '한다', '한', '에서', '3', '을', '할', '/', '두',
             '를', '고','로','도','과','지','인','님','잘','다','어','아', '이라', 
             '그', '나', '너무', '진짜', '보고', '지금', '해서', 'ㅋㅋ', '원', '알', '장',
             '안', '팅', '때', '공', '이런', '대학생', '입니다']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='tweet')
ko.vocab().most_common(30)
# Out:
# [('하트', 20),
#  ('시리얼', 19),
#  ('파란색', 6),
#  ('초코', 6),
#  ('그릇', 6),
#  ('노란색', 4),
#  ('기범이', 4),
#  ('검정색', 4),
#  ('크레마', 4),
#  ('손뼉', 4),
#  ('치는', 4),
#  ('손', 4),
#  ('기호', 4),
#  ('속', 3),
#  ('및', 3),
#  ('우유', 3),
#  ('생각', 3),
#  ('너', 3),
#  ('얼굴', 3),
#  ('하는', 3),
#  ('아침', 2),
#  ('팬케이크', 2),
#  ('요리', 2),
#  ('녹색', 2),
#  ('야채', 2),
#  ('샐러드', 2),
#  ('채운', 2),
#  ('납작한', 2),
#  ('빵', 2),
#  ('주황색', 2)]

# %%
from matplotlib import font_manager, rc 
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt 

# %matplotlib inline

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system. Sooooorry.')

plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(15, 6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = ko.vocab().most_common(300)

wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.5,
                      background_color='white'
                     ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
