# %% [markdown]
# 내가 쓰는 것이 곧 나이다.

# %%
# !python --version
# Out:
# Python 3.5.5 :: Anaconda, Inc.

# %%
import feedparser

url = ("https://rss.blog.naver.com/homoludens14.xml")

my_text = []

def crawl_rss(url) :
    d = feedparser.parse(url) 
    
    for e in d.entries :
        print(e.description)
        my_text.append(e.description)
        

def main() :
    crawl_rss(url)

if __name__ == "__main__" : 
    main()
# Out:
# 프로듀스101 미청년 100명이 나와도 흔들리지 않던 내가2015년 이후 모든 덕질을 중단한 내가근 3년만에 덕질을 시작했다. 얼굴만 봐도 행복한 이 기분! 이름은 호일천(huytien) 중국어로 허이↑티엔↓ 정도로 읽는 듯.우리나라에는 &#x27;치아문적단순 소미호&#x27;로 처음 알려진 신인 배우다. 작년에 SNS에서 한창 떴을 때 별 관심없이 지나쳤다가요즈음 왓챠플레이에서 치아문단순문적 소미호를 보고선 입덕해버렸다. 까칠하지만 은근히 챙겨주는 장천 역할이 어찌나 찰떡인지! 드라마 내내 여주인공 천샤오시(심월)에게 못되게 구는 장면이 많은데 그것마저 다 이해되고 용서되는 비주얼이다ㅋㅋㅋ치아문적단순 소미호에서 절강대 의.......
# 출국, 그리고 시행착오꽤 늦은 시간 인천공항에서 출국 수속을 밟았다. 오후 11시 55분 비행기어서 학교에서는 저녁먹고 길을 나섰다. 공항버스에 타자마자 매우 피곤했다. 전 날 밤을 새기도 했고,,, 꽤 오래 자리를 비우게 되는 바람에 모든 일을 몰아서 해결해야 했기에 정작 여행 준비에 충실하지 못했다. 어느 정도였냐면 여행짐을 30분만에 쌌다ㅋㅋㅋㅋㅋㅋ (여행 내내 후회함) 오후 9시 반 쯤 출국 수속 시작! 하루종일 아무것도 안먹었지만 왠지 모를 긴장감에 별로 배고프진 않았다. 한국에서의 마지막 음식은 공차 딸기 버블 쉐이크였는데 지금 돌이켜보면 어리석은 선택이었다. 맛있는거 더 먹고갈걸ㅋㅋ 시간이 좀 남아 게이트 앞.......
# 특별히 할로윈 필터로 셀카를 찍었다. 기술이 많이 좋아졌어방구석 나홀로 할로윈 ^_^
# ...

# %%
import nltk 
from konlpy.tag import Okt; t = Okt()

# %%
blog_text = ''

for each_line in my_text[:10000] :
    blog_text = blog_text + each_line + '\n'

# %%
tokens_ko = t.morphs(blog_text)
tokens_ko
# Out:
# ['프로',
#  '듀스',
#  '101',
#  '미',
#  '청년',
#  '100',
#  '명',
#  '이',
#  '나',
#  '와도',
#  '흔들리지',
#  '않던',
#  '내',
#  '가',
#  '2015년',
#  '이후',
#  '모든',
#  '덕질',
#  '을',
#  '중단',
#  '한',
#  '내',
#  '가',
#  '근',
#  '3년',
#  '만에',
#  '덕질',
#  '을',
#  '시작',
#  '했다',
#  '.',
#  '얼굴',
#  '만',
#  '봐도',
#  '행복한',
#  '이',
#  '기분',
#  '!',
#  '이름',
#  '은',
#  '호일',
#  '천',
#  '(',
#  'huytien',
#  ')',
#  '중국어',
#  '로',
#  '허이',
#  '↑',
#  '티엔',
#  '↓',
#  '정도',
#  '로',
#  '읽는',
#  '듯',
#  '.',
#  '우리나라',
#  '에는',
#  '&#',
#  'x',
#  '27',
#  ';',
#  '치아',
#  '문적',
#  '단순',
#  '소',
#  '미호',
#  '&#',
#  'x',
#  '27',
#  ';',
#  '로',
#  '처음',
#  '알려진',
#  '신인',
#  '배우다',
#  '.',
#  '작년',
#  '에',
#  'SNS',
#  '에서',
#  '한창',
#  '떴을',
#  '때',
#  '별',
#  '관심',
#  '없이',
#  '지나쳤다가',
#  '요즈음',
#  '왓챠',
#  '플레이',
#  '에서',
#  '치아',
#  '문',
#  '단',
#  '순',
#  '문적',
#  '소',
#  '미호',
#  '를',
#  '보고선',
#  '입덕',
#  '해',
#  '버렸다',
#  '.',
#  '까칠하지만',
#  '은근',
#  '히',
#  '챙겨주는',
#  '장천',
#  '역할',
#  '이',
# ...

# %%
ko = nltk.Text(tokens_ko, name='블로그')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 3464
# 1561

# %%
ko = nltk.Text(tokens_ko, name='블로그')
ko.vocab().most_common(100)
# Out:
# [('.', 129),
#  ('이', 73),
#  ('을', 66),
#  ('에', 58),
#  (',', 44),
#  ('!', 40),
#  ('의', 39),
#  ('를', 38),
#  ('은', 33),
#  ('들', 31),
#  ('\n', 26),
#  ('는', 25),
#  ('에서', 24),
#  ('도', 24),
#  ('한', 23),
#  ('.......', 23),
#  ('가', 21),
#  ('로', 18),
#  ('것', 17),
#  ('인', 17),
#  ('했다', 15),
#  ('(', 14),
#  ('나', 14),
#  ('으로', 13),
#  ('가야금', 13),
#  ('그', 13),
#  (')', 12),
#  ("'", 12),
#  ('와', 11),
#  ('중', 11),
#  ('하는', 11),
#  ('수', 11),
#  ('이다', 11),
#  ('아스타나', 11),
#  ('못', 10),
#  ('다', 10),
#  ('주법', 10),
#  ('만', 10),
#  ('여행', 10),
#  ('카자흐스탄', 9),
#  ('때', 9),
#  ('적', 9),
#  ('수업', 9),
#  ('서', 9),
#  ('시간', 8),
#  ('할', 8),
#  ('있다', 8),
#  ('한국', 8),
#  ('1', 8),
#  ('바로', 7),
#  ('내', 7),
#  ('시작', 7),
#  ('사람', 7),
#  ('에게', 7),
#  ('입니다', 7),
#  ('해', 7),
#  ('ㅠㅠ', 7),
#  ('주', 7),
#  ('속', 7),
#  (':', 7),
#  ('문화', 7),
#  ('공연', 7),
#  ('마음', 7),
#  ('있는', 7),
#  ('과', 7),
#  ('게', 6),
#  ('더', 6),
#  ('박', 6),
#  ('두', 6),
#  ('학과', 6),
# ...

# %%
stop_words = ['.-', '안', '에서는', '게', '_', '위', '하면', '각', '?', '과', '다', '했다', '이다',
             '2', '\n', '.', '-', ',', '2', '1', ';', '을', '를', '의', '에', '들', '도', '위해'
             ,'수', '것', '와', '이', '가', '27', '로', 'x', '가요', '.......', '하고', '하면',
              '&#', '(', ')', ':', '는', '은', '으로', '한다', '한', '에서', '3', '하는', '할', '/', 
              '해', '저', '대', '두', '명', '입니다', '있습니다', '인', '자', '하여', '합니다', '에는', '전', '그리고', '때', 
            '적', '정도', '이번', '나', '중', '더', '서', '및', '식', '고', '못', '있다', '등', '그래서', '대한', '만', '일',
             '점', '차', '곳', '까지', '앞', '말', '간', '때문', '있는', '내', '됩니다', '분', '했으나', '가기', 'ㅋㅋㅋ','10',
             'B', '듯', '들고', '에게' ,'이라', 'L', '70:20', '잔', '꽤', '!', "'", '그', 'ㅠㅠ', '바로', '박', '주', '속', '4', '아니라',
             '쯤', '모든', '오랜', '지금', '본', '구', '...', '[', '인지', '이라는', '잘', '날', '했던', '안녕하세요', '그런데', '여','기',
             '요', ']', '라는' ,'한번' , '제대로', '주법']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='블로그')
ko.vocab().most_common(50)
# Out:
# [('가야금', 13),
#  ('아스타나', 11),
#  ('여행', 10),
#  ('카자흐스탄', 9),
#  ('수업', 9),
#  ('시간', 8),
#  ('한국', 8),
#  ('시작', 7),
#  ('문화', 7),
#  ('공연', 7),
#  ('사람', 7),
#  ('마음', 7),
#  ('학과', 6),
#  ('사실', 6),
#  ('일정', 6),
#  ('인류학', 6),
#  ('연습', 6),
#  ('스쿨', 6),
#  ('아리랑', 6),
#  ('클래스', 5),
#  ('악기', 5),
#  ('문화원', 5),
#  ('선비', 5),
#  ('친구', 5),
#  ('루덴스', 5),
#  ('엑스포', 5),
#  ('포스터', 5),
#  ('정말', 5),
#  ('지원', 5),
#  ('동안', 5),
#  ('버렸다', 5),
#  ('출국', 5),
#  ('첫', 5),
#  ('처음', 5),
#  ('모양', 5),
#  ('식사', 4),
#  ('후기', 4),
#  ('많이', 4),
#  ('취미', 4),
#  ('활동', 4),
#  ('동물원', 4),
#  ('서포터즈', 4),
#  ('샹그리라', 4),
#  ('생각', 4),
#  ('자유여행', 4),
#  ('이집트', 4),
#  ('오후', 4),
#  ('청년', 4),
#  ('소', 4),
#  ('다른', 4)]

# %%
from matplotlib import font_manager, rc 
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt 

# %matplotlib inline

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system. Sooooorry.')

plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(15, 6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = ko.vocab().most_common(300)

wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.5,
                      background_color='white'
                     ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import gensim
from gensim.models import word2vec

# %%
t = Okt()
results = []
lines = my_text

for line in lines :
    malist = t.pos(line, norm=True, stem=True)
    r = []
    
    for word in malist :
        if not word[1] in ["Josa", "Eomi", "Punctuation"] :
            r.append(word[0])
            
    r1 = (" ".join(r)).strip()
    results.append(r1)
    
    print(r1)
# Out:
# 체크 1 Django Q amp A 업로드 어제 마크다운 문서 생기다 오류로 업로드 안 돼다 문제 해결 블로그 업로드 썸네일 모르다 용 MTV 패턴 단어 사이 뭔가 괴리감 느껴지다 )https://djangohy.github.io/MTV-QA2 javascript 기본 문법 Object 원시 참조 데이터 타입 3 R 프로그래밍 hypergeometric binomial plot option if else 어렵다 강의 내용 자다 들어오다 않다 영상 사이 들리다 새 지 저 귀 소리 너무 좋다
# 내 삽질 기 궁금하다 않다 분 들 바로 스 크롤 내다 해결 파트 확인 문제 어제 Django 스터디 블로그 올리다 마크다운 문서 작성 업로드 하다 계속 build 실패하다 github 알다 준 오류 내용 보다 161 라인 근처 url 태그 잘 못 되어다 것 그 라인 부근 이렇다 코드 있다 혹시 이 문장 url 로 잘못 인식 게 아니다 싶다 마크다운 url 태그 alt 링크 주소 여기 대괄호 앞뒤 escape 문자 backtick x 60 써다 보다 github 늘다 꿈쩍 않다 내다 독촉 장 보내오다 깃 허다 블로그 build 실패하다 오류 원인 알다 메일 오다 2시간 동안 저 대괄호 붙잡다 삽질 하다 gg 치
# 체크 1 Django 스터디 첫 스터디 발표 MTV 이다 Django 가다 어떻다 돌아가다 설명 하다 위 발표 이다 너무 장황하다 오히려 더 복잡하다 느껴지다 것 같다 발표 끝나다 모두 침울하다 분위기 다시 분위기 띄우다 애씄다 오늘 전공 강의 배우다 것 x 27 선택 집중 x 27 이다 너무 많다 것 전달 하다 보다 핵심 놓치다 게 아니다 싶다 질문 받다 내 안다 생각 하다 것 들 사실 모르다 것 더 공부 열심히 하다 느끼다 질문 받다 않다 안다 착각 채 공부 하다 못 하다 것 나다 많이 질문 하다 것 스터디 원 들 많이 질문 하다 좋다 2 자바스크립트 기본 문
# ...

# %%
data_file = 'my_text'

with open(data_file, 'w', encoding='utf=8') as fp :
    fp.write("\n".join(results))

# %%
data = word2vec.LineSentence(data_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)

model.save('my_text.data')

# %%
model = word2vec.Word2Vec.load("my_text.data")

# %%
model.most_similar(positive=['연오'])
# Out:
# C:\Users\guseo\AppData\Local\conda\conda\envs\py35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('블로그', 0.9947835803031921),
#  ('8', 0.9940285682678223),
#  ('작성', 0.9934390187263489),
#  ('C', 0.9913380146026611),
#  ('준비', 0.9901577234268188),
#  ('카드', 0.9899927973747253),
#  ('3', 0.988692045211792),
#  ('박', 0.9838689565658569),
#  ('풀기', 0.9838278889656067),
#  ('만들기', 0.9830283522605896)]
