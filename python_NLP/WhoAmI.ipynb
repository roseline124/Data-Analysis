# %% [markdown]
# 내가 쓰는 것이 곧 나이다.

# %%
import feedparser

url = ("https://rss.blog.naver.com/guseod24.xml")

my_text = []

def crawl_rss(url) :
    d = feedparser.parse(url) 
    
    for e in d.entries :
        print(e.description)
        my_text.append(e.description)
        

def main() :
    crawl_rss(url)

if __name__ == "__main__" : 
    main()
# Out:
# 체크 1. Django Q&amp;A 업로드어제 마크다운 문서에 생긴 오류로 업로드가 안됐던 문제 해결. 블로그에 업로드.(썸네일의 몰라용과 MTV 패턴이라는 단어 사이에 뭔가 괴리감이 느껴진다)https://djangohy.github.io/MTV-QA2. javascript 기본 문법- Object - 원시, 참조 데이터 타입 3. R 프로그래밍- hypergeometric, binomial- plot option - if else어렵다. 강의 내용은 잘 들어오지 않는다. 영상 사이에 들리는 새 지저귀는 소리가 너무 좋다.
# 내 삽질기가 궁금하지 않은 분들은 바로 스크롤 내려서 해결 파트 확인문제어제 Django 스터디 블로그에 올릴 마크다운 문서 작성하고 업로드하려는데 계속 build에 실패했다. github에서 알려준 오류 내용을 보니 161라인 근처의 url 태그가 잘못되었다는 것. 그 라인 부근에는 이런 코드가 있었다. 혹시 이 문장을 url로 잘못 인식한 게 아닌가 싶어 (마크다운에서는 url 태그가 [alt](링크주소) 이다.) 여기 대괄호 앞뒤에 escape 문자로 backtick(&#x60;)을 써봤지만 github는 꿈쩍도 않고 내게 독촉장을 보내왔다. (깃헙 블로그 build에 실패하면 오류 원인을 알려주는 메일이 온다.) 2시간 동안 저 대괄호만 붙잡고 삽질하다가 gg치.......
# 체크 1. Django 스터디 첫 스터디 발표는 MTV였다. Django가 어떻게 돌아가는지 설명하기 위한 발표였는데, 너무 장황하여 오히려 더 복잡하게 느껴졌던 것 같다. 발표가 끝나고 모두 침울한 분위기라 다시 분위기를 띄우려고 애씄다. 오늘 전공 강의에서도 배운 것이 &#x27;선택과 집중&#x27;이었는데... 너무 많은 것을 전달하려다보니 핵심은 놓친 게 아닌가 싶다. + 질문을 받으면서 내가 안다고 생각했던 것들이 사실 몰랐던 것이고, 더 공부를 열심히 해야겠다고 느꼈다. 질문을 받지 않았다면 안다고 착각한 채 공부하지 못했을 것이다. 나도 많이 질문할 것이고, 스터디원들도 많이 질문하면 좋겠다. 2. 자바스크립트 기본 문.......
# 체크 1. R 프로그래밍- 문자열, 문자열 뒤집기- 정규분포 / 카이제곱 검증 함수 구현하기 - dotchart, ggvis - tapply카이제곱 검증 함수부터 삐걱거리기 시작했다. 그 이후 강의는 와르르.. 프로그래밍이 문제가 아니라 통계 지식이 더 중요한 것 같다. 통계 지식이 없으니 이 함수가 왜 필요하고, 어떤 용도로 쓰는지 알 수 없다. 연장을 들고도 쓰지 못하는 상태..2. 서울의 인구 대비 CCTV 설치 현황 데이터 분석 [파이썬으로 데이터 주물주물하기 :) ]- 라이브러리 : matplotlib, numpy, pandas - pandas 기초 + matplotlib으로 시각화하기 - 일반적으로 서울에서는 인구에 비례하여 인구당 CCTV 비율도 높아진다.- 다만 이 경향에.......
# 만델브로 셋 튜토리얼하려다가 tensorflow 설치에만 1시간 삽질 후 정리하는 글.텐서플로우 설치는 2단계이다.- 텐서플로우 설치 전 설치 환경을 확인- 설치 환경이 적합하면 tensorflow 설치 1. 설치 환경1. 32bit? 64bit?텐서플로우는 윈도우 64비트의 python 3.5.x 또는 3.6.x 버전만 지원한다. 만약 tensorflow 설치가 안되서 찾아온거라면,내 아나콘다가 설치된 경로로 가서 anaconda의 bit를 확인하고 32bit라면 64bit로 다시 깔자. 2. 버전 확인 : 텐서플로우는 python 3.6 까지 지원 - 파이썬 버전 확인 커맨드 라인이나 아나콘다 프롬프트에서 실행python 3.7은 아나콘다에서 다운그레이드해야한다. - 버전 다.......
# 체크 1. Javascript 기본 문법 - 정규표현식- 변수 유효 범위- 콜백 함수, 비동기처리 AJAX- 클로저 - 유사배열 arguments / apply()2. Pandas 핵심 functions- groupby - drop, drop_duplicates, duplication- apply, map, applymap- concat, unique 등등강의를 마치면 수료증을 준다(주는 강의도 있고 안주는 강의도 있다) 3. R 프로그래밍 - value, match, which- dataframe- tidyr- dice simulation, barplot 데이터 애널리틱스 강의에 R 프로그래밍이 필수라 독학을 시작했다. 생각보다 재밌다. 시각화가 편리하고, Pandas와 비슷한 명령어, 문법이 있어서 많이 낯설지는 않았다.다만, index가 0이 아니라 1부터 시작하는 것, 슬.......
# 1. 문제 상황- 아나콘다 프롬프트에서 import pandas, import tensorflow, import sklearn을 하면 정상적으로 실행됨- 그러나 같은 python 환경의 주피터 노트북에서는 no name module &#x27;pandas&#x27; 와 같은 에러가 뜸- 주피터에서 !pip install pandas 명령을 실행시켜도 아래와 같은 문구만 뜬다. ※ 참고로 tensorflow 설치가 안되는 사람은 이 포스팅을 확인하길 바란다.2. 해결 방법1. 원인 : 주피터 노트북의 커널이 잘못된 경로에 있는 python 환경을 가리키고 있는 경우 라이브러리를 인식하지 못한다.2. 해결 - 아나콘다 프롬프트 열기 - python 환경 실행 : 프롬프트에서 아래 명령어를 입력해 에러가 나고 있는 환경.......
# 체크 1. javascript (웹) - Object Model - BOM- 전역 객체 Window- alert, console.log, confirm, prompt2. javacript (기본 문법)- 줄바꿈과 여백 ~ UI와 API 문서 3. machine learing- kNN, 나이브 베이즈, 선형 회귀, kmean 클러스터링 - [kaggle]타이타닉 생존자 예측하기4. Twitter Crawling - 참고 : 파이썬을 이용한 트위터 크롤링 [Medium]- python으로 트위터 크롤링 - 환경 : python 3.5, jupyter, chromedriver / 사용된 라이브러리 : beautifulsoup, selenium, pandas, matplotlib - 코드 목적 : 2월 15일부터 3월 4일까지의 코멘트 중 &#x27;KIA&#x27;라는 키워드의 빈도 수 측정- 다음 : 텍스트 전처리를 위한 NLP .......
# 체크 1. react-native로 날씨 앱 만들기 (노마드 코더)- 개발 환경 : expo, npm, node.js, 안드로이드 폰, 안드로이드 애뮬레이터- react-native 관련 개념- loading view, weather view - error 메시지 출력 - 아이콘- API 호출 2. 파이썬 프로그래밍 입문서 끝 (박연오 블로그)- 텍스트 양식화- re(정규 표현식), datetime, time 모듈- 파일과 디렉터리 다루기 - 웹으로 정보 주고받기
# 체크 1. 독서 : 파이썬 코딩의 기술- PEP8 표준으로 파이썬 코딩하기 - p.37~ p.114
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. 1번 챕터의 털로 이해하는 SQL JOIN은 캐글과 관련이 없다.Kaggle에서도 JOIN을 알려주지만 INNER JOIN 밖에 안나와서 내용을 추가했다. 1. 털로 이해하는 SQL JOIN퇴사 전 SQL 속성 강의할 때 예시를 위해 사용했던 짤이다.캐글의 SQL/BigQuery 과정에서는 InnerJoin에 대한 실습만 나와 있다. 아래의 짤을 본 후, 설명을 들으면 JOIN의 이해가 더 쉬울 것이다. 1. INNER JOIN 예를 들어 &#x27;학생&#x27; 테이블과 &#x27;신청 과목&#x27; 테이블이 있을 때 &#x27;학생&#x27; 테이블의 &#x27;id&#x27; 컬럼, &#x27;신청 과목&#x27; 테이블의 &#x27;student_id&#x.......
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. Aliasing, 그리고 임시테이블 1. AS 별명 column, table을 원하는 이름으로 부를 수 있다. &#x27;AS&#x27;는 생략할 수 있다. 2. WITH ... AS ...AS 는 WITH와 함께 사용할 때 더 강력하다. WITH AS로 만든 테이블을 CTE(common table expression)이라고 한다. CTE는 우리가 쿼리로 만든 임시테이블이다. 임시이기 때문에 나중에 다시 참조할 수는 없다. 위와 같은 테이블에서 WITH AS로 Seniors라는 새로운 임시테이블을 만든다. 그리고 이 테이블을 조회하면 임시테이블을 만들 때 걸어두었던 조건 Years_old &gt; 5를 만족하는 row들이 나온다. .......
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. 1. Order by Order by는 데이터를 조회할 때 필수는 아니다. 하지만, 방대한 양의 데이터를 조회할 때 &#x27;가독성&#x27;을 위해서, 혹은 데이터의 순서가 중요할 때 꼭 필요한 명령어다. 날짜별로 날씨를 정리한 테이블을 조회한다고 하자. 이 테이블의 특이한 점은.. 날짜별로 날씨를 기록하지 않았다는 것이다. (억지스럽지만 일단 상황을 가정해보면)whether를 조회할 때, date라는 컬럼으로 조회할 테이블의 순서를 정리한다. 만약 내림차순으로 정리하고 싶다면, 컬럼 뒤에 DESC 를 붙인다. (descending의 약자이다) 2. Extract() 특정 데이터를 데이터베.......
# 체크 1. 파이썬 모듈과 패키지 (연오센세 블로그)- 모듈 : 기능별로 나누어 놓은 소스 코드 파일 - 라이브러리 : 다른 프로그램에 포함시키기 위해 기능을 미리 나누어 묶어 놓은 것- 표준 라이브러리 : 언어와 함께 제공되는 프로그래밍에 필요한 기본 기능 - 제 3자 라이브러리(Third Party Library) : 비공식적이지만 누군가 만들어놓은 모듈- 최상위 모듈 검사 - 패키지 : 모듈 파일들을 묶어놓은 것 - __init__.py : 패키지 디렉토리를 &#x27;패키지&#x27;로 인식시키게 하려면 __init__.py 파일을 생성해야 한다. 2. React로 Movie Web App 만들기 (노마드 코더 강의) -&gt; 실습까지 총 4시간 (강의는 2시간) 원래는 React Nati.......
# 체크 1. Python 예외 처리 (연오센세 블로그)- except ( 예외1, 예외2, ...) : 여러 예외를 일괄 처리- raise 예외 : 예외 발생시키기- assert 검증식, 처리문 : 식 검증하고 예외 처리 / 특정 예외를 처리할 수 없다.- 예외 유형 정의 : Exception 클래스를 상속하여 예외 클래스 만들기 / BaseException을 직접 상속하지 않는다.- finally : 중복 코드를 방지하기 위해 exept 코드 블럭이 끝난 후, 맨 마지막으로 실행되어야할 코드를 위치시킨다. 2. django MTV 패턴, Django 프로젝트 구성, Django 앱 디자인 기본 : 오늘 정리한 내용 - MTV 패턴을 좀 흥미롭게 소개할 수 없을까 고민하다가 좋은 영상을 발견했다.- 블로그만으로는.......
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. 1. 강의1. count() 테이블에서 해당 컬럼명이 몇 개 존재하는 지 카운트해서 알려준다. count()는 컬럼 안의 값들은 집계, 연산하는 집계 함수 중 하나이다. 집계 함수(aggregation function)에는 avg, sum 과 같은 함수가 있다. 집계 함수는 컬럼을 통해 많은 행들(rows)을 인자로 받지만, 결국 반환하는 값은 하나이다. (평균, 총합 등) 그렇기 때문에 group by 와 같이 어떤 기준으로 결과 행들을 통합할 건지 알려줘야 한다. 2. Group by student라는 테이블에 studentID와 gender라는 컬럼이 있다. 이때 학생들 수를 세는데, 남/여 학생을 나눠서 각각 몇 명이 존.......
# 체크 1. 아두이노 어제 받은 택배 뜯고 제품 확인하는데, 아두이노 나노랑 USB 케이블 아귀가 안맞음.USB mini-b 케이블로 샀는데 이상해서 구글링해보니 나노용이 따로 있음.아두이노 나노용 USB mini-B 케이블로 다시 구매(ㅠㅠ)2. 한 숟갈 더 스터디(Django Study)이름같이 욕심 많은 스터디가 됐음 좋겠다. 오늘 올린 실습환경 준비하기. 다수가 사용하는 github 블로그를 운영하게 되면서, pull request, 그리고 원본 저장소의 수정사항을 어떻게 반영하는지(fetch 또는 pull) 알게 됐다. 3. 박연오 블로그try except 공부  4. 소켓 프로그래밍 참고 : https://itsaessak.tistory.com/126Baccarat 코딩하다가 클라이.......
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. SQL의 핵심 Select, From, Where가 나온다. select, from, where만 알아도 SQL은 너무 재밌다. 인턴할 때 처음에 뭐가 테이블이고, 뭐가 컬럼이고 로우인지 몰라서 야근까지하며 한참 헤매다가 Select, From으로 처음 쿼리문이 성공했을 때 감격했던 기억이 난다... 크크 추억팔이kaggle에서 배운 건 특이하다. SQL을 쓰기 위해서 DBeaver나 TeamSQL이라는 툴을 사용해야 했는데, BigQuery는 그럴 필요가 없다.SQL 쿼리문으로 데이터를 조회하고, 이 데이터를 변수에 담아 BigQuery의 함수로 Pandas 데이터프레임으로 바꿔준다. 뭔 말이야 싶겠지만 코드를 보면 알 수 있.......
# ※ 링크 참고 (캐글 사이트) / 실습하려면 Fork 를 눌러야 한다. hacker_news라는 데이터로 BigQuery 함수 설명마지막에는 Chicago의 범죄 관련 데이터로 배운 함수 활용 1. 강의1. BigQuery 임포트하기 : import bq_helper2. BigQueryHelper 오브젝트 생성특정 데이터셋을 가리키기 위해 BigQueryHelper 오브젝트를 생성해야 한다.3. 스키마 : 데이터셋의 구조우리가 원하는 데이터베이스를 요청(query)하기 위해서 스키마를 이해해야 한다. BigQueryHelper.list_tables()은 데이터셋 안의 테이블들을 리스트업한다. 데이터베이스 자체는 여러개의 테이블들을 갖고 있다. 이 메서드를 쓰면 hacker_news라는 데이터.......
# 체크 1. Django 스터디 OT - 커리어 개발센터 11시에서 스터디 OT 진행 - 간단한 자기소개. - 스터디 시간 및 장소 정함.- 진행 일정 공유, 발표 순서 정함. - 다들 시간 여유가 되서 github 블로그를 작성할 수 있도록 fork 뜨는 법, pull request 하는 법 배움. - 연오센세에게 스터디 목차에 대해 조언을 구해보았고... 튜토리얼, 프로젝트 위주로 실습하는 게 좋다고 판단. 2. 삼성 SDS 프로그래밍 멘토링 - 삼성 SDS 개발자 멘토링. 강연에 가깝다. - 인문계열 비전공자를 위한 SCSA 채용 과정. 왜 삼성에서는 SCSA를 진행하는가? &#x27;융복합 인재&#x27;를 뽑기 위해서다. 개발자가 개발만 하는 시대를 넘어서 사용자가 어떻.......
# 체크 1. Django 스터디 오리엔테이션 준비- jekyll-now 템플릿이 너무 단순하고, 디자인이나 폰트, 그리고 작성자를 표시할 수 없어서 다른 템플릿으로 바꿨다.- jekyll-jasper로 바꿨는데 위의 요구를 모두 만족했다. 2. 웹(myfolio)프로젝트의 디테일한 과정을 추가하기 위해 projects_detail 페이지를 추가했다. 3. 웹 프로그래밍 튜토리얼 django 스터디할 때 발표자들이 참고할만 한 사이트를 찾다가 좋은 웹 프로그래밍 튜토리얼 사이트를 발견했다.너무 깔끔하다. 이걸로 node.js 연습해야지 ㅎㅎhttps://poiemaweb.com/
# 체크 1. Django 스터디 오리엔테이션 준비- github.io 로 django study 블로그 만들기- Oritentation 내용 준비 : 필수적으로 해야할 내용, 회차, 방식, 스터디 규칙 등 마크다운이 아직 익숙하지 않지만...
# 최우수상최우수상!!!!!!쵠우리누루시낭최우수상! 한숨도 못자면서 계속 django만 붙잡고 있었는데.. 결과물에 반영이 안되서 아쉬웠다. 장고 스터디하면서 꼭 취업하기 전에 저때 완성 못했던 거 완성해야지.아두이노도 만들고 싶었는데 못만들어서 아쉽다.만들고 싶었던 제품을 위해서 코코아팹, 알리익스프레스 뒤적거리다가 쿠팡에서 주문했다.어떻게 만드는지 모르지만 구글이 알려줄 것이다.
# 계획1. 창업 메이커톤 체크 1. 창업 메이커톤- 21일 - 도서관으로 공부하러 가다가 공대 게시판에서 메이커톤 포스터 발견- 3시간 전인가 접수하고 참석 - 팀원들과 아이디어 회의
# 계획1. 웹 프로젝트 2. Baccarat 체크 1. 버클리 대학 machine learning 강의 머신러닝 온라인 스터디가 거의 망해서 대안으로 버클리 대학의 machine learning 강의를 시작했다. 머신러닝에 필요한 기초 개념을 알려준다.주피터로 실습하는데, 교수님 주피터를 보고 마크다운을 쓰는 방법, 단축키 등 주피터의 추가적인 기능도 알게 됐다.. ㅋ 배운 내용 : 평균, 중앙값, 표준편차, 체비쇼프의 부등식2. 구글 머신러닝 단기집중 과정 (강의 + 실습) - 머신러닝 용어 - 만델브로 집합 실습 (fractal image 출력하기) : tensorflow를 설치하려는데, 개발 환경이 안맞아서 anaconda를 다시 설치하느라 시간이 많이.......
# 이번 문제에서는 최저 경비를 구하는 문제지만, 달러 대신 km로 단위를 바꾸면 최단 경로 구하기라고 할 수 있다. 1. Atlanta에서 각 도시로 가는 최저 경비 구하기여행할 때 이 도시에서 저 도시로 정신없이 이동한다고 할 때, 우리는 어떻게 해야 가장 적은 경비로 이동할 수 있을까?이 문제를 풀기 위해 다이크스트라 알고리즘을 쓸 수 있다. 현재 노드에서 목적지 노드까지 가려면 여러 노드를 거쳐 가야하는데, 이때 어느 경로로 가야 가장 빨리 갈 수 있을지 구한다.(라우터가 목적지 라우터에 패킷을 보낼 때 가장 빠른 경로를 찾는 라우팅 프로토콜도 이 알고리즘을 쓴다고 한다.)너비 우선 탐색 알고리즘은 queue에 인접 노드.......
# 1. 우리 동네 이웃 사람들은 누구일까?사교성이 좋은 Alice는 자신의 마을에 어떤 사람들이 살고 있는지 궁금하다.각 집이 다른 집의 사람을 알고 있다고 할 때(일방적으로 알고 있다고 가정한다), 우리는 네트워크를 통해 이 마을에 어떤 집들이 있는지 하나하나 방문하며 파악해볼 수 있다.(이미 방문한 곳에는 방문하지 않는다.)알고리즘으로 접근하면, 그래프로 현재 노드의 인접 노드와, 인접 노드의 인접 노드까지 방문함으로써 현재 노드의 전체 네트워크를 파악한다고 말할 수 있다.전체 네트워크를 파악하기 위한 방법으로 &#x27;너비 우선 탐색&#x27; 방법을 썼다.2. 너비 우선 탐색&#x27;너비 우선 탐색&#x27; 알고리즘은 &.......
# 계획1. 웹 프로젝트 2. 파이썬 스터디 3. Baccarat4. 토익 체크 1. 웹 프로젝트 - migrations에 있는 폴더를 건드렸다가 계속 에러가 나서 그냥 싹 밀어버렸다.새로 프로젝트 폴더를 만들어서 원격 깃 저장소에 연결해 초기화하고, 현재 폴더의 내용을 깃에 푸쉬했다. 그리고 다시 프로젝트, 앱을 설치하고 템플릿과 폼을 연결하는데 1시간 안되게 걸린 것 같다.(다행히 멀쩡했을 때 백업해둔게 있어서)날려먹은 놈은 용서해도 백업 안해둔 놈은 용서가 안된다고, 그래도 백업해두길 잘했다. 2. 파이썬 스터디 종료- 파이썬 스터디 마지막날이었다. 퇴사 후 파이썬 스터디를 이유로 매주 1회씩 가서 퇴사한 느낌이 들지 않았는데, .......
# 계획1. 웹 프로젝트 - projects 페이지에 model 연결- form 까지 작성 2. 자료 구조와 알고리즘- 그래프 - 알고리즘 문제(python)3. Baccarat- sprites 객체 추가하기 4. 잡플래닛 등록되면 가고 싶은 회사, 직군 등록하기 5. 파이썬 스터디 준비 체크 1. 웹 프로젝트 - project 카드를 새로 만들거나 편집할 때, redirect하는데, url이 계속 뒤에 덧붙여서 나왔다. 어떻게 해야하나 고민하던 찰나에, 이와 전혀 상관없는 곳에서 ../~.html과 같은 형태를 쓰는 걸 보고 혹시해서 써봤더니 해결 됐다. 2. Baccarat- 메인 파일에 있던 코드를 거의 반 이상 줄였다. event()에 모여있던 대부분의 기능을 sprites.py 폴더로 옮겼다.......
# 1. 이진트리은진 송씨 족보 중 일부이다. 시대에 안맞게 족보 타령하는 건 아니고, 족보의 모습이 이진트리와 비슷해서 가져왔다. - 족보에도 시조가 있듯이 이진 트리에도 뿌리가 있다. - 족보는 각 세대마다 자손의 수는 다 다르다. 하지만, 이진트리의 각 노드는 최대 2명 이하의 자식 노드를 둔다. (0, 1, 2개)&lt; 이진 트리의 노드를 구현한 소스코드 &gt;그리고 이진 트리에는 한 가지 특이한 점이 있다. 부모 노드의 값보다 작은 값을 가진 자식은 왼쪽에, 큰 값을 가진 자식은 오른쪽에 배치된다이러한 특징 덕분에 이진 트리는 이진 검색과 같이 값의 크기를 비교해 경우의 수를 줄일 수 있다. 찾는 값이 10보다.......
# 계획1. 웹 프로젝트 2. 알고리즘- 알고리즘 문제 풀기(손코딩)3. Baccarat체크 1. 웹 프로젝트 : new, edit 2. 알고리즘- 알고리즘 문제 풀기(손코딩) : 9012 괄호 - 스택 사용스택을 이용해 여는 괄호가 나오면 스택에 push, 닫는 괄호가 나오면 여는 괄호를 pop한다. pop할 때 조건 분기에 따라 유효한 괄호인지 그렇지 않은지 answer 변수에 저장하고, 마지막 단계에서 answer를 출력한다. 근데 왠걸.. 계속 틀린다.. 테스트 케이스트는 다 맞는데, 예외적인 상황을 못잡고 있다. 뭘까..?중첩문이 많아서 수정을 해야겠다. 3. Baccarat- Baccarat 코드가 너무 뒤죽박죽이라 pygame 책을 보면서 하나씩 기능.......
# 계획1. 웹 프로젝트 - 디자인 끝내기 - django랑 연결하기 2. Baccarat 체크 1. 웹 프로젝트 - 디자인 끝내기 1) nav-top : nav 태그의 클래스 안에 있는 클래스 중, transparent 속성을 갖는 클래스 이름을 nav-top으로 지었다.javascript에서 스크롤이 15 이상 내려가면 nav-top이 nav태그의 클래스에서 사라지고, 그 뒤에 있던 nav-bg가 나타난다. 2) smooth-scroll : css 파일에서 html 태그에 scroll-behavior:smooth를 주면 페이지 내 이동 시 부드럽게 이동한다. 3) slow image load : image가 늦게 로드되는 문제 해결하기- django랑 연결하기 2. Baccarat 3. java의 정석 (p.57~p.136 연산자) : 새벽.......
# 계획1. 웹 프로젝트 - css 다듬기 2. 자료 구조와 알고리즘- 알고리즘 문제 풀기 - 박연오 블로그 - 파이썬 8장 3. Baccarat- 카드 deal 눈에 보이게 하기  체크 1. 웹 프로젝트 - projects 페이지 / 스크롤바 디자인(얇게) / 프로젝트 카드 디자인 / 스와이프 슬라이드 2. 자료 구조와 알고리즘- 알고리즘 문제 풀기 : 부녀회장이 될거야! 개연성 떨어지는 내용의 문제여서 몰입하기 어려웠다. 재귀도 쓰고, 저번주에 배운 리스트 조건제시법도 쓰고, if 조건부식도 쓰고... 스터디에서 배운 내용을 활용했다.&lt;문제&gt; : 백준 2775번&lt;풀이&gt;- 박연오 블로그, 파이썬 8장 (1~2)같은 값을 가진 유형의 객.......
# 1. 연결리스트와 큐 기존 연결리스트는 바로 다음의 노드만을 가리킨다. 따라서, 끝의 노드를 찾기 위해서는 연결리스트의 처음부터 찾아야했기 때문에 O(N)이 걸린다.하지만, 이중 연결리스트는 앞 뒤 노드를 동시에 가리켜, 앞이든 뒤이든 한 번에 맨 끝의 노드에 접근할 수 있다. 따라서 맨 끝 노드의 읽기, 검색, 삽입, 삭제 모두 O(1)이다. 이런 이중 연결리스트의 특징은 어디에 활용할 수 있을까? 바로 큐이다. 스택은 선입후출(FILO)방식으로, 삭제할 때 맨 끝 데이터부터 삭제한다. 이는 이중 연결리스트에서도 좋지만 배열도 맨 끝 데이터를 삭제하는데 O(1)이 걸리기때문에 연결리스트가 배열보다 특별히 좋은 것은 없다.하지만, .......
# 계획1. 웹 프로젝트 - css 다듬기 2. 파이썬 프로그래밍 - 알고리즘 문제 풀이- 박연오 블로그 파이썬 8장 3. Baccarat체크 1. 웹 프로젝트 - css 다듬기 : about me, features / projects 페이지 features 파트처럼 3칸으로 나누려면, col-md-4클래스로 12의 공간을 3등분하면 된다. 이때 세로로 쌓이기 때문에, display:flex / flex:wrap 속성을 가진 row로 감싸준다. 2. 파이썬 프로그래밍 - 알고리즘 문제 풀이- 박연오 블로그 파이썬 8장 3. Baccarat- 게임 진행을 위한 코드는 모두 작성했다. 더불어 user의 점수, 랭크도 프로필에 추가했다. 처음 만들 때는 메인 파일에 모두 게임 진행의 내용을 넣어서.......
# 배열의 읽기(O(1))를 제외하고는 연결리스트와 배열의 연산 효율은 비슷하다. 수치적으로 보면 연결리스트의 효율성은 그리 좋지 않다. 하지만 연결 리스트의 특징, &#x27;연결&#x27;을 생각하면 쓸만하다.그럼, 연결 리스트는 어떤 경우에 효과적으로 쓸 수 있을까? 한 리스트를 검사해서 &#x27;많은 원소&#x27;를 &#x27;삽입&#x27;, &#x27;삭제&#x27;할 때이다. 연결리스트는 삽입, 삭제 자체는 실행 단계가 1번 뿐이다.많은 원소를 &#x27;삭제&#x27;하는 경우를 예로 들어보자. 배열에서는 삭제를 할 때마다, 빈 공간을 메꾸기 위해 오른쪽의 데이터를 왼쪽으로 한 칸씩 옮겨야 한다. 즉, O(N)이 걸린다.따라서, 전체 원소의 개수가 N이.......
# 연결리스트 읽기와 검색의 효율성은 O(N)으로 그리 효율적이지 않았다. 삽입과 삭제는 어떨까? 일반 배열의 경우, 중간에 데이터를 삽입 혹은 삭제하기 위해 그 오른쪽의 데이터들을 한 칸씩 밀거나 당겨야 했다. 연결리스트는 중간에서 연결을 끊은 뒤 새로운 노드를 다음 노드로 연결하고, 삭제는 그저 노드를 삭제한 뒤 끊어진 노드끼리 연결한다. 결론부터 말하면, 삽입과 삭제 자체에 드는 실행 단계는 1번이지만, 삽입 및 삭제할 노드의 자리를 찾기 위해서는 읽기 단계 N번을 수행해야 한다. 직접 해보면서 확인하자. 1. 연결리스트 : 노드의 삽입 1. 노드의 삽입 과정 : 중간에 새로운 노드를 삽입한다.- 노드 생성- 새로운 노.......
# 계획1. 웹 프로젝트 - css 다듬기 2. 자료 구조와 알고리즘- 다이크스트라 알고리즘 + 공간복잡도 공부 - 알고리즘 문제3. Baccarat- 카드 dealing 코드 만들기 4. 가고 싶은 회사, 직군 정하기 5. 토익 공부 체크 1. 웹 프로젝트 - css 다듬기 : 부트스트랩을 이용해 css를 다듬었다. navigation bar랑 그 다음의 div container가 계속해서 시간을 잡아먹었다. div container에 커버 사진을 넣고 nav영역까지 사진을 확장해서 보여주려고 했는데, nav 영역에는 먹히지 않았다. 그래서 nav 영역에 다음과 같은 속성을 줬다. - z-index 는 레이어 순서라고 보면된다. ppt를 쓸 때 &#x27;맨 앞으로 보내기, 맨 뒤로 보내기&#x2.......
# 체크 파이썬 스터디 준비 - 스터디를 하면 좋은 게 내가 공부해간 부분은 확실히 공부가 되는 동시에 - 다른 사람의 지식을 덤으로 얻을 수 있어 좋다. 오늘도 연오님께 새로운 걸 많이 배웠다.- 배우다가 스터디 전 버스에서 읽은 파이썬 프로그래밍에 나왔던 &#x27;리스트 조건제시법&#x27;을 그대로 알려주셔서 재밌었다. - 정말 표지는 따분하기 그지 없지만, 내용은 너무너무 좋은 책이다. - 오늘 발표한 것 - 오늘 배운 것
# 저번 포스팅에서 연결리스트가 어떤 것인지는 알았다. 이번 포스팅에서는 연결 리스트가 어떤 연산에서 강점을 발휘하는 지 알아본다. 먼저 연산하기 전에 저번 포스팅의 노드 데이터를 숫자에서 알파벳으로 살짝 바꾸었다. 또, 마지막 노드의 데이터를 없앴다. (파이썬의 null은 None이다.)1. 읽기 : 특정 인덱스의 값을 찾는다. 연결 리스트를 따라가기 위해 curr_node와 next_node를 만들어주자. 각 노드를 가리키는 포인터 같은 것이라고 생각하면 된다.현재 노드가 가리킬 첫번째 노드로 head를 정해주었다. 현재 index는 0이다. - curr_index +&#x3D; 1 : 다음 노드로 옮길 때마다 curr_index를 한 차례씩 늘려가며 re.......
# 1. 파이썬은 스크립트 언어다? 스크립트 언어의 정의파이썬은 스크립트 언어다? 늘 아, 그렇구나하고 넘어갔던 &#x27;스크립트&#x27; 언어에 대해 알아보고자 한다. 스크립트 언어는 연극 용어에서 따온 말이다. 연극에서의 &#x27;스크립트&#x27;는 배우의 대사를 중점으로 배우의 표정, 등장과 퇴장, 무대장치을 중심으로 지시해놓은 내용을 말한다.아래는 예시를 위해 가져온 스크립트 샘플이다. (심심하면 읽어보시길) 프로그래밍에서 &#x27;스크립트 언어&#x27;의 역할을 생각해보면 왜 스크립트라고 했는지 이해가 될 것이다. 프로그래밍의 스크립트 언어는 기존에 이미 존재하는 소프트웨어를 제어하기 위한 용도를 쓰이는 언어이다. .......
# 1. 매핑1. 매핑 : {키 : 값 } 형식으로 저장된 데이터 / 다른 언어에서는 해시 맵, 해시 테이블이라고도 한다. 읽기와 검색 연산 시 실행 단계가 한 번 밖에 걸리지 않기 때문에 효율적이다.2. 시퀀스와 매핑- 시퀀스 : 순서가 있는 데이터 나열 / 값을 찾을 때 인덱스의 처음부터 값이 나올 때까지 찾는다.- 매핑 : 순서가 없고 값을 찾을 때 키를 이용 / 값을 찾을 때 &#x27;키&#x27;를 이용해 한 번에 값을 찾는다. 3. 사전 - 사전 : 직접 정의하는 경우 - 기본값 사전 : 사전의 기본적인 형태만 정의해주는 경우 2. 기본값 사전(default dict)1. 기본값 사전을 쓰는 이유는 뭘까? 뭐가 불편해서 만들었을까?이유, 이유. 항상.......
# 계획 1. 자료 구조와 알고리즘- 그래프 - 알고리즘 문제(python)2. Baccarat- 3. 파이썬 스터디 준비 - 중첩 컬렉션 생성 및 순회  체크 1. 자료 구조와 알고리즘- 그래프 : 데이크스트라 알고리즘그래프로 각 노드에서 다른 노드로 가는 가장 빠른 경로를 구한다고 했을 때 바로 라우터가 생각났다. 실제로 데이크스트라 알고리즘을 라우팅 프로토콜에 사용된다고 한다. 책에서 배운 Atlanta에서 다른 도시로 가는 최단 경비를 구하는 알고리즘을 파이썬으로 구현했다(데이크스트라 알고리즘의 일반적인 형태는 아니고 바로 전에 배웠던 너비 우선 탐색 알고리즘을 이용했다). - 각 도시 및 경로 구성하기 - 각 도시로 가는.......
# 계획1. 자료 구조와 알고리즘- 그래프 데이터베이스 : - 알고리즘 문제(C)2. Baccarat- betting 기능 만들기  체크 1. 자료 구조와 알고리즘- 그래프 데이터베이스 : + 가중 그래프 - 알고리즘 문제(C) : 아침에 백준 알고리즘 문제 중 &#x27;벌집&#x27;에서 최소 경로 구하기 문제를 풀었다. 등비수열은 금방 풀었는데, 계속해서 에러가 났다. 아무리 봐도 완벽해보이는데 뭐가 문제일까! 왜 시간 초과가 나오는 걸까! 해보니 너무 간단한 조건을 빼먹고 있었다. 범위 비교를 하기 위해 각 degree의 첫 수와 마지막 수를 구했는데, while 루프문에서 첫 수는 무조건 2부터 시작하기 때문에 목적지 숫자가 1인 경우, if문에 들어가.......
# 계획1. 웹 프로젝트 - projects 페이지에 model 연결- form 까지 작성 2. 자료 구조와 알고리즘- 그래프 - 알고리즘 문제(python)3. Baccarat- sprites 객체 추가하기 체크 1. 웹 프로젝트 에러 : The view didn&#x27;t return an HttpResponse object / &#x27;form&#x27; referenced before assigned (form이 선언되지 않았는데 어떻게 참조하느냐) &lt;틀린 코드&gt;1. 첫번째 에러 해결의 KEY : request에 따라 return하는 응답이 달라져야 한다 각 요청에 대한 응답을 준비해둬야 한다.페이지에 접근하여 보여달라는 건 get 요청. 그런데 이 코드를 보면 모든 대응이 if request.method&#x3D;&#x3D;&quot;POST&quot; 안.......
# 참고 서적 : 컴퓨터 과학 · 데이터 과학 입문을 위한 파이썬 프로그래밍  1. 알고리즘계산적 사고란?모든 지식은 &#x27;서술적 지식&#x27;과 &#x27;절차적 지식&#x27;으로 나뉜다.서술적 지식 : 사실을 진술한 것. &#x27;1+1&#x3D;2&#x27;이다. 너무나 자명한 사실이지만, 우리는 어린 아이에게 1+1이 왜 2인지 설명하라고 하면 설명하지 못한다. 서술적 지식은 있지만, 절차적 지식은 없다. (나도 없다)절차적 지식 : 1+1 이라는 값이 2가 맞는지 증명하는 데에는 각 단계가 있고, 조건문에 따라 실행 흐름이 통제되기도 한다(이를 증명하는 &#x27;페아노 공리계&#x27;라는 것이 있다고 한다). 이런 과정을 알고리즘이라고 한다. .......
# 1. MVC (Model - View - Controller)프로그램을 개발할 때 어떤 방법으로 개발할 지 설계한 것을 디자인 패턴이라 한다. 개발자는 디자인 패턴의 특정한 규칙에 따라 프로그램을 개발한다. MVC는 그런 디자인 패턴의 한 종류이다. 2. M, V, C의 역할 MVC의 가장 큰 특징이자 장점이라고 할 수 있는 것은 사용자에게 &#x27;보이는 영역&#x27;과 사용자의 요청을 &#x27;처리하는 영역&#x27;을 분리시켜 놓은 것이다. 보이는 영역은 &#x27;view&#x27;에서 담당하며, 처리 영역은 &#x27;controller&#x27;에서 담당한다. - controller : view와 model을 컨트롤하여 사용자의 요청을 처리한다. - view : controller로부터 요청을 받으면 그.......
# 1만 개의 별을 찍는 데 걸리는 시간은 얼마일까? 별찍기 문제하면 생각나는 것은 이중 for문이다. 하지만 이중 for문을 사용하지 않고 직사각형 별을 찍는 방법이 3가지 더 있다. 풀던 방식으로만 풀면 어떤 게 좋고, 어떤 게 나쁜지 알지 못한다. 그래서 C와 파이썬으로 다양한 방식으로 접근하려 한다. 이중 반복문, 단일 반복문, 그리고 아예 반복문을 쓰지 않고 가장 빨리 별을 찍을 수 있는 방법을 소개한다. 1. 이중 for문 가장 먼저 떠오르는 이중 for문.2. for문 &amp; if문 문제를 푼 후, 혹시 이중 for문 외에 다른 방식으로 문제를 푼 사람이 있나 찾아봤다. 스크롤을 한참 내려도 없길래 &#x27;없나?&#x27;했는데 이중 f.......
# 계획1. 웹 프로젝트 - projects 페이지에 모델 연결- form 까지 만들기 2. 자료 구조와 알고리즘- 이진 트리 마무리 (활용)- 알고리즘 문제 (C로 풀기) 3. Baccarat- pygame 4. 개발 용어 공부- MVC 체크 1. 웹 프로젝트 - projects 페이지에 모델 연결- form 까지 만들기 2. 자료 구조와 알고리즘- 이진 트리 마무리 (활용) :- 알고리즘 문제 (C, Python) : 직사각형 별 찍기는 흔히 이중 for문으로 처리할 것이다. 하지만 직사각형 별찍기는 3가지 방법으로 풀 수 있다. 같은 문제를 매번 푸는 방식으로만 풀면 더 나은 방법을 찾을 수 없다. 또, 어떤 게 나쁘고 어떤 게 좋은 방법인지 알지 못한다. 같은 문제를 다양.......
# 1. 비즈니스 로직 사용자 눈에는 보이지 않지만 사용자의 요청을 처리하기 위해 어플리케이션이 동작하는 방식을 구조화해놓은 것이다. 쉽게 말하면 문제, 또는 요청을 해결하는 과정이다. 내가 블로그에 포스팅하는 것도 내 입장에서는 아주 간단한 일이다. 하지만, 작성 중인 텍스트를 어떻게 보여주고 포스팅을 업로드하면 데이터베이스에 어떻게 저장되고, 이전의 포스팅을 어떻게 보여줄 건지는 로직에서 처리한다. 사용자는 몰라도 되지만, 사용자가 서비스를 이용하기 위해 프로그래머에 의해 구상되는 부분이다. 실제 동작은 코드에 의해 실행되지만, 코드로 만들어진 각 객체를 어떻게 활용하고 어떤 과정으로 처리하는 지 결정하는.......

# %%
import nltk 
from konlpy.tag import Okt; t = Okt()

# %%
blog_text = ''

for each_line in my_text[:10000] :
    blog_text = blog_text + each_line + '\n'

# %%
tokens_ko = t.morphs(blog_text)
tokens_ko
# Out:
# ['체크',
#  '1',
#  '.',
#  'Django',
#  'Q',
#  '&',
#  'amp',
#  ';',
#  'A',
#  '업로드',
#  '어제',
#  '마크다운',
#  '문서',
#  '에',
#  '생긴',
#  '오류로',
#  '업로드',
#  '가',
#  '안',
#  '됐던',
#  '문제',
#  '해결',
#  '.',
#  '블로그',
#  '에',
#  '업로드',
#  '.(',
#  '썸네일',
#  '의',
#  '몰라',
#  '용',
#  '과',
#  'MTV',
#  '패턴',
#  '이라는',
#  '단어',
#  '사이',
#  '에',
#  '뭔가',
#  '괴리감',
#  '이',
#  '느껴진다',
#  ')https://djangohy.github.io/MTV-QA2',
#  '.',
#  'javascript',
#  '기본',
#  '문법',
#  '-',
#  'Object',
#  '-',
#  '원시',
#  ',',
#  '참조',
#  '데이터',
#  '타입',
#  '3',
#  '.',
#  'R',
#  '프로그래밍',
#  '-',
#  'hypergeometric',
#  ',',
#  'binomial',
#  '-',
#  'plot',
#  'option',
#  '-',
#  'if',
#  'else',
#  '어렵다',
#  '.',
#  '강의',
#  '내용',
#  '은',
#  '잘',
#  '들어오지',
#  '않는다',
#  '.',
#  '영상',
#  '사이',
#  '에',
#  '들리는',
#  '새',
#  '지',
#  '저',
#  '귀',
#  '는',
#  '소리',
#  '가',
#  '너무',
#  '좋다',
#  '.',
#  '\n',
#  '내',
#  '삽질',
#  '기',
#  '가',
#  '궁금하지',
#  '않은',
#  '분',
#  '들',
#  '은',
#  '바로',
#  '스',
#  '크롤',
#  '내려서',
#  '해결',
#  '파트',
#  '확인',
#  '문제',
#  '어제',
#  'Django',
#  '스터디',
#  '블로그',
#  '에',
#  '올릴',
#  '마크다운',
#  '문서',
#  '작성',
#  '하고',
#  '업로드',
#  '하려는데',
#  '계속',
#  'build',
#  '에',
#  '실패했다',
#  '.',
#  'github',
#  '에서',
#  '알려',
#  '준',
#  '오류',
#  '내용',
#  '을',
#  '보니',
#  '161',
#  '라인',
#  '근처',
#  '의',
#  'url',
#  '태그',
#  '가',
#  '잘',
#  '못',
#  '되었다는',
#  '것',
#  '.',
#  '그',
#  '라인',
#  '부근',
#  '에는',
#  '이런',
#  '코드',
#  '가',
#  '있었다',
#  '.',
#  '혹시',
#  '이',
#  '문장',
#  '을',
#  'url',
#  '로',
#  '잘못',
#  '인식',
#  '한',
#  '게',
#  '아닌가',
#  '싶어',
#  '(',
#  '마크다운',
#  '에서는',
#  'url',
#  '태그',
#  '가',
#  '[',
#  'alt',
#  '](',
#  '링크',
#  '주소',
#  ')',
#  '이다',
#  '.)',
#  '여기',
#  '대괄호',
#  '앞뒤',
#  '에',
#  'escape',
#  '문자',
#  '로',
#  'backtick',
#  '(&#',
#  'x',
#  '60',
#  ';)',
#  '을',
#  '써',
#  '봤지만',
#  'github',
#  '는',
#  '꿈쩍',
#  '도',
#  '않고',
#  '내게',
#  '독촉',
#  '장',
#  '을',
#  '보내왔다',
#  '.',
#  '(',
#  '깃',
#  '헙',
#  '블로그',
#  'build',
#  '에',
#  '실패하면',
#  '오류',
#  '원인',
#  '을',
#  '알려주는',
#  '메일',
#  '이',
#  '온다',
#  '.)',
#  '2시간',
#  '동안',
#  '저',
#  '대괄호',
#  '만',
#  '붙잡고',
#  '삽질',
#  '하다가',
#  'gg',
#  '치',
#  '.......',
#  '\n',
#  '체크',
#  '1',
#  '.',
#  'Django',
#  '스터디',
#  '첫',
#  '스터디',
#  '발표',
#  '는',
#  'MTV',
#  '였다',
#  '.',
#  'Django',
#  '가',
#  '어떻게',
#  '돌아가는지',
#  '설명',
#  '하기',
#  '위',
#  '한',
#  '발표',
#  '였는데',
#  ',',
#  '너무',
#  '장황하여',
#  '오히려',
#  '더',
#  '복잡하게',
#  '느껴졌던',
#  '것',
#  '같다',
#  '.',
#  '발표',
#  '가',
#  '끝나고',
#  '모두',
#  '침울한',
#  '분위기',
#  '라',
#  '다시',
#  '분위기',
#  '를',
#  '띄우려고',
#  '애씄다',
#  '.',
#  '오늘',
#  '전공',
#  '강의',
#  '에서도',
#  '배운',
#  '것',
#  '이',
#  '&#',
#  'x',
#  '27',
#  ';',
#  '선택',
#  '과',
#  '집중',
#  '&#',
#  'x',
#  '27',
#  ';',
#  '이었는데',
#  '...',
#  '너무',
#  '많은',
#  '것',
#  '을',
#  '전달',
#  '하려다',
#  '보니',
#  '핵심',
#  '은',
#  '놓친',
#  '게',
#  '아닌가',
#  '싶다',
#  '.',
#  '+',
#  '질문',
#  '을',
#  '받으면서',
#  '내',
#  '가',
#  '안다고',
#  '생각',
#  '했던',
#  '것',
#  '들',
#  '이',
#  '사실',
#  '몰랐던',
#  '것',
#  '이고',
#  ',',
#  '더',
#  '공부',
#  '를',
#  '열심히',
#  '해야겠다고',
#  '느꼈다',
#  '.',
#  '질문',
#  '을',
#  '받지',
#  '않았다면',
#  '안다고',
#  '착각',
#  '한',
#  '채',
#  '공부',
#  '하지',
#  '못',
#  '했을',
#  '것',
#  '이다',
#  '.',
#  '나도',
#  '많이',
#  '질문',
#  '할',
#  '것',
#  '이고',
#  ',',
#  '스터디',
#  '원',
#  '들',
#  '도',
#  '많이',
#  '질문',
#  '하면',
#  '좋겠다',
#  '.',
#  '2',
#  '.',
#  '자바스크립트',
#  '기본',
#  '문',
#  '.......',
#  '\n',
#  '체크',
#  '1',
#  '.',
#  'R',
#  '프로그래밍',
#  '-',
#  '문자열',
#  ',',
#  '문자열',
#  '뒤집기',
#  '-',
#  '정규분포',
#  '/',
#  '카이',
#  '제곱',
#  '검증',
#  '함수',
#  '구현',
#  '하기',
#  '-',
#  'dotchart',
#  ',',
#  'ggvis',
#  '-',
#  'tapply',
#  '카이',
#  '제곱',
#  '검증',
#  '함수',
#  '부터',
#  '삐걱',
#  '거리',
#  '기',
#  '시작',
#  '했다',
#  '.',
#  '그',
#  '이후',
#  '강의',
#  '는',
#  '와르르',
#  '..',
#  '프로그래밍',
#  '이',
#  '문제',
#  '가',
#  '아니라',
#  '통계',
#  '지식',
#  '이',
#  '더',
#  '중요한',
#  '것',
#  '같다',
#  '.',
#  '통계',
#  '지식',
#  '이',
#  '없으니',
#  '이',
#  '함수',
#  '가',
#  '왜',
#  '필요하고',
#  ',',
#  '어떤',
#  '용도',
#  '로',
#  '쓰는지',
#  '알',
#  '수',
#  '없다',
#  '.',
#  '연장',
#  '을',
#  '들고도',
#  '쓰지',
#  '못',
#  '하는',
#  '상태',
#  '..',
#  '2',
#  '.',
#  '서울',
#  '의',
#  '인구',
#  '대비',
#  'CCTV',
#  '설치',
#  '현황',
#  '데이터',
#  '분석',
#  '[',
#  '파이썬',
#  '으로',
#  '데이터',
#  '주물',
#  '주물',
#  '하기',
#  ':)',
#  ']-',
#  '라이브러리',
#  ':',
#  'matplotlib',
#  ',',
#  'numpy',
#  ',',
#  'pandas',
#  '-',
#  'pandas',
#  '기초',
#  '+',
#  'matplotlib',
#  '으로',
#  '시각',
#  '화하기',
#  '-',
#  '일반',
#  '적',
#  '으로',
#  '서울',
#  '에서는',
#  '인구',
#  '에',
#  '비례',
#  '하여',
#  '인구',
#  '당',
#  'CCTV',
#  '비율',
#  '도',
#  '높아진다',
#  '.-',
#  '다만',
#  '이',
#  '경향',
#  '에',
#  '.......',
#  '\n',
#  '만',
#  '델브',
#  '로',
#  '셋',
#  '튜토리얼',
#  '하려다가',
#  'tensorflow',
#  '설치',
#  '에만',
#  '1시간',
#  '삽질',
#  '후',
#  '정리',
#  '하는',
#  '글',
#  '.',
#  '텐서',
#  '플로우',
#  '설치는',
#  '2',
#  '단계',
#  '이다',
#  '.-',
#  '텐서',
#  '플로우',
#  '설치',
#  '전',
#  '설치',
#  '환경',
#  '을',
#  '확인',
#  '-',
#  '설치',
#  '환경',
#  '이',
#  '적합하면',
#  'tensorflow',
#  '설치',
#  '1',
#  '.',
#  '설치',
#  '환경',
#  '1',
#  '.',
#  '32',
#  'bit',
#  '?',
#  '64',
#  'bit',
#  '?',
#  '텐서',
#  '플로우',
#  '는',
#  '윈도우',
#  '64',
#  '비트',
#  '의',
#  'python',
#  '3.5',
#  '.',
#  'x',
#  '또는',
#  '3.6',
#  '.',
#  'x',
#  '버전',
#  '만',
#  '지원',
#  '한',
#  '다',
#  '.',
#  '만약',
#  'tensorflow',
#  '설치',
#  '가',
#  '안되서',
#  '찾아온거라면',
#  ',',
#  '내',
#  '아나콘다',
#  '가',
#  '설치',
#  '된',
#  '경로',
#  '로',
#  '가서',
#  'anaconda',
#  '의',
#  'bit',
#  '를',
#  '확인',
#  '하고',
#  '32',
#  'bit',
#  '라면',
#  '64',
#  'bit',
#  '로',
#  '다시',
#  '깔자',
#  '.',
#  '2',
#  '.',
#  '버전',
#  '확인',
#  ':',
#  '텐서',
#  '플로우',
#  '는',
#  'python',
#  '3.6',
#  '까지',
#  '지원',
#  '-',
#  '파이썬',
#  '버전',
#  '확인',
#  '커맨드',
#  '라인',
#  '이나',
#  '아나콘다',
#  '프롬프트',
#  '에서',
#  '실행',
#  'python',
#  '3.7',
#  '은',
#  '아나콘다',
#  '에서',
#  '다운',
#  '그레이드',
#  '해야',
#  '한다',
#  '.',
#  '-',
#  '버전',
#  '다',
#  '.......',
#  '\n',
#  '체크',
#  '1',
#  '.',
#  'Javascript',
#  '기본',
#  '문법',
#  '-',
#  '정규표현식',
#  '-',
#  '변수',
#  '유효',
#  '범위',
#  '-',
#  '콜백',
#  '함수',
#  ',',
#  '비',
#  '동기',
#  '처리',
#  'AJAX',
#  '-',
#  '클로저',
#  '-',
#  '유사',
#  '배열',
#  'arguments',
#  '/',
#  'apply',
#  '()',
#  '2',
#  '.',
#  'Pandas',
#  '핵심',
#  'functions',
#  '-',
#  'groupby',
#  '-',
#  'drop',
#  ',',
#  'drop',
#  '_',
#  'duplicates',
#  ',',
#  'duplication',
#  '-',
#  'apply',
#  ',',
#  'map',
#  ',',
#  'applymap',
#  '-',
#  'concat',
#  ',',
#  'unique',
#  '등등',
#  '강의',
#  '를',
#  '마치',
#  '면',
#  '수료증',
#  '을',
#  '준다',
#  '(',
#  '주는',
#  '강의',
#  '도',
#  '있고',
#  '안주',
#  '는',
#  '강의',
#  '도',
#  '있다',
#  ')',
#  '3',
#  '.',
#  'R',
#  '프로그래밍',
#  '-',
#  'value',
#  ',',
#  'match',
#  ',',
#  'which',
#  '-',
#  'dataframe',
#  '-',
#  'tidyr',
#  '-',
#  'dice',
#  'simulation',
#  ',',
#  'barplot',
#  '데이터',
#  '애',
#  '널리',
#  '틱',
#  '스',
#  '강의',
#  '에',
#  'R',
#  '프로그래밍',
#  '이',
#  '필수',
#  '라',
#  '독학',
#  '을',
#  '시작',
#  '했다',
#  '.',
#  '생각',
#  '보다',
#  '재밌다',
#  '.',
#  '시각',
#  '화가',
#  '편리하고',
#  ',',
#  'Pandas',
#  '와',
#  '비슷한',
#  '명령어',
#  ',',
#  '문법',
#  '이',
#  '있어서',
#  '많이',
#  '낯설지는',
#  '않았다',
#  '.',
#  '다만',
#  ',',
#  'index',
#  '가',
#  '0',
#  '이',
#  '아니라',
#  '1',
#  '부터',
#  '시작',
#  '하는',
#  '것',
#  ',',
#  '슬',
#  '.......',
#  '\n',
#  '1',
#  '.',
#  '문제',
#  '상황',
#  '-',
#  '아나콘다',
#  '프롬프트',
#  '에서',
#  'import',
#  'pandas',
#  ',',
#  'import',
#  'tensorflow',
#  ',',
#  'import',
#  'sklearn',
#  '을',
#  '하면',
#  '정상',
#  '적',
#  '으로',
#  '실행',
#  '됨',
#  '-',
#  '그러나',
#  '같은',
#  'python',
#  '환경',
#  '의',
#  '주피터',
#  '노트북',
#  '에서는',
#  'no',
#  'name',
#  'module',
#  '&#',
#  'x',
#  '27',
#  ';',
#  'pandas',
#  '&#',
#  'x',
#  '27',
#  ';',
#  '와',
#  '같은',
#  '에러',
#  '가',
#  '뜸',
#  '-',
#  '주피터',
#  '에서',
#  '!',
#  'pip',
#  'install',
#  'pandas',
#  '명령',
#  '을',
#  '실행',
#  '시켜도',
#  '아래',
#  '와',
#  '같은',
#  '문구',
#  '만',
#  '뜬다',
#  '.',
#  '※',
#  '참고',
#  '로',
#  'tensorflow',
#  '설치',
#  '가',
#  '안되는',
#  '사람',
#  '은',
#  '이',
#  '포스팅',
#  '을',
#  '확인',
#  '하길',
#  '바란다',
#  '.',
#  '2',
#  '.',
#  '해결',
#  '방법',
#  '1',
#  '.',
#  '원인',
#  ':',
#  '주피터',
#  '노트북',
#  '의',
#  '커널',
#  '이',
#  '잘',
#  '못',
#  '된',
#  '경로',
#  '에',
#  '있는',
#  'python',
#  '환경',
#  '을',
#  '가리키고',
#  '있는',
#  '경우',
#  '라이브러리',
#  '를',
#  '인식',
#  '하지',
#  '못',
#  '한다',
#  '.',
#  '2',
#  '.',
#  '해결',
#  '-',
#  '아나콘다',
#  '프롬',
#  '프트',
#  '열기',
#  '-',
#  'python',
#  '환경',
#  '실행',
#  ':',
#  '프롬프트',
#  '에서',
#  '아래',
#  '명령어',
#  '를',
#  '입력',
#  '해',
#  '에러',
#  '가',
#  '나고',
#  '있는',
#  '환경',
#  '.......',
#  '\n',
#  '체크',
#  '1',
#  '.',
#  'javascript',
#  '(',
#  '웹',
#  ')',
#  '-',
#  'Object',
#  'Model',
#  '-',
#  'BOM',
#  '-',
#  '전역',
#  '객체',
#  'Window',
#  '-',
#  'alert',
#  ',',
#  'console',
#  '.',
#  'log',
#  ',',
#  'confirm',
#  ',',
#  'prompt',
#  '2',
#  '.',
#  'javacript',
#  '(',
#  '기본',
#  '문법',
#  ')-',
#  '줄',
#  '바꿈',
#  '과',
#  '여백',
#  '~',
#  'UI',
#  '와',
#  'API',
#  '문서',
#  '3',
#  '.',
#  'machine',
#  'learing',
#  '-',
#  'kNN',
#  ',',
#  '나',
#  '이브',
#  '베',
#  '이즈',
#  ',',
#  '선형',
#  '회귀',
#  ',',
#  'kmean',
#  '클러스터링',
#  ...]

# %%
ko = nltk.Text(tokens_ko, name='블로그')
print(len(ko.tokens))
print(len(set(ko.tokens)))
# Out:
# 6924
# 1807

# %%
ko = nltk.Text(tokens_ko, name='여자친구 선물')
ko.vocab().most_common(100)
# Out:
# [('.', 357),
#  ('-', 170),
#  (',', 167),
#  ('을', 124),
#  ('를', 118),
#  ('의', 98),
#  ('에', 91),
#  (';', 87),
#  ('1', 85),
#  ('x', 82),
#  ('&#', 76),
#  ('27', 73),
#  ('이', 70),
#  ('가', 67),
#  ('(', 65),
#  (':', 64),
#  ('는', 56),
#  (')', 53),
#  ('2', 52),
#  ('로', 50),
#  ('\n', 50),
#  ('으로', 44),
#  ('.......', 41),
#  ('알고리즘', 41),
#  ('한다', 40),
#  ('은', 37),
#  ('한', 37),
#  ('에서', 36),
#  ('할', 36),
#  ('노드', 35),
#  ('때', 34),
#  ('이다', 32),
#  ('문제', 32),
#  ('수', 31),
#  ('것', 31),
#  ('와', 30),
#  ('하기', 30),
#  ('3', 28),
#  ('데이터', 28),
#  ('하는', 28),
#  ('체크', 27),
#  ('파이썬', 27),
#  ('스터디', 26),
#  ('프로젝트', 25),
#  ('웹', 24),
#  ('연결', 24),
#  ('리스트', 22),
#  ('/', 22),
#  ('값', 20),
#  ('적', 20),
#  ('테이블', 20),
#  ('있다', 18),
#  ('문', 18),
#  ('과', 18),
#  ('다', 17),
#  ('위해', 17),
#  ('Baccarat', 17),
#  ('프로그래밍', 17),
#  ('블로그', 16),
#  ('했다', 16),
#  ('강의', 15),
#  ('코드', 15),
#  ('들', 15),
#  ('도', 15),
#  ('처리', 14),
#  ('?', 14),
#  ('삭제', 14),
#  ('설치', 13),
#  ('어떤', 13),
#  ('내용', 13),
#  ('실습', 13),
#  ('계획', 13),
#  ('구조', 12),
#  ('각', 12),
#  ('하면', 12),
#  ('_', 12),
#  ('위', 12),
#  ('함수', 11),
#  ('하고', 11),
#  ('이중', 11),
#  ('자료', 11),
#  ('게', 11),
#  ('환경', 11),
#  ('같은', 11),
#  ('python', 11),
#  ('참고', 11),
#  ('까지', 11),
#  ('안', 10),
#  ('방법', 10),
#  ('지식', 10),
#  ('에서는', 10),
#  ('스크립트', 10),
#  ('삽입', 10),
#  ('연오', 10),
#  ('어떻게', 10),
#  ('실행', 10),
#  ('언어', 10),
#  ('.-', 10),
#  ('해', 10),
#  ('기본', 10)]

# %%
stop_words = ['.-', '안', '에서는', '게', '_', '위', '하면', '각', '?', '과', '다', '했다', '이다',
             '2', '\n', '.', '-', ',', '2', '1', ';', '을', '를', '의', '에', '들', '도', '위해'
             ,'수', '것', '와', '이', '가', '27', '로', 'x', '가요', '.......', '하고', '하면',
              '&#', '(', ')', ':', '는', '은', '으로', '한다', '한', '에서', '3', '하는', '할', '/', '해']

tokens_ko = [each_word for each_word in tokens_ko if each_word not in stop_words]

ko = nltk.Text(tokens_ko, name='블로그')
ko.vocab().most_common(50)
# Out:
# [('알고리즘', 41),
#  ('노드', 35),
#  ('때', 34),
#  ('문제', 32),
#  ('하기', 30),
#  ('데이터', 28),
#  ('체크', 27),
#  ('파이썬', 27),
#  ('스터디', 26),
#  ('프로젝트', 25),
#  ('웹', 24),
#  ('연결', 24),
#  ('리스트', 22),
#  ('값', 20),
#  ('테이블', 20),
#  ('적', 20),
#  ('있다', 18),
#  ('문', 18),
#  ('Baccarat', 17),
#  ('프로그래밍', 17),
#  ('블로그', 16),
#  ('강의', 15),
#  ('코드', 15),
#  ('삭제', 14),
#  ('처리', 14),
#  ('설치', 13),
#  ('어떤', 13),
#  ('내용', 13),
#  ('실습', 13),
#  ('계획', 13),
#  ('구조', 12),
#  ('함수', 11),
#  ('이중', 11),
#  ('자료', 11),
#  ('환경', 11),
#  ('같은', 11),
#  ('python', 11),
#  ('참고', 11),
#  ('까지', 11),
#  ('삽입', 10),
#  ('방법', 10),
#  ('지식', 10),
#  ('스크립트', 10),
#  ('연오', 10),
#  ('어떻게', 10),
#  ('실행', 10),
#  ('언어', 10),
#  ('기본', 10),
#  ('못', 10),
#  ('예외', 10)]

# %%
from matplotlib import font_manager, rc 
import pandas as pd
import numpy as np
import platform
import matplotlib.pyplot as plt 

# %matplotlib inline

path = "C:/Windows/Fonts/malgun.ttf"

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system. Sooooorry.')

plt.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(15, 6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
data = ko.vocab().most_common(300)

wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      relative_scaling = 0.5,
                      background_color='white'
                     ).generate_from_frequencies(dict(data))
plt.figure(figsize=(16, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import gensim
from gensim.models import word2vec

# %%
t = Okt()
results = []
lines = my_text

for line in lines :
    malist = t.pos(line, norm=True, stem=True)
    r = []
    
    for word in malist :
        if not word[1] in ["Josa", "Eomi", "Punctuation"] :
            r.append(word[0])
            
    r1 = (" ".join(r)).strip()
    results.append(r1)
    
    print(r1)
# Out:
# 체크 1 Django Q amp A 업로드 어제 마크다운 문서 생기다 오류로 업로드 안 돼다 문제 해결 블로그 업로드 썸네일 모르다 용 MTV 패턴 단어 사이 뭔가 괴리감 느껴지다 )https://djangohy.github.io/MTV-QA2 javascript 기본 문법 Object 원시 참조 데이터 타입 3 R 프로그래밍 hypergeometric binomial plot option if else 어렵다 강의 내용 자다 들어오다 않다 영상 사이 들리다 새 지 저 귀 소리 너무 좋다
# 내 삽질 기 궁금하다 않다 분 들 바로 스 크롤 내다 해결 파트 확인 문제 어제 Django 스터디 블로그 올리다 마크다운 문서 작성 업로드 하다 계속 build 실패하다 github 알다 준 오류 내용 보다 161 라인 근처 url 태그 잘 못 되어다 것 그 라인 부근 이렇다 코드 있다 혹시 이 문장 url 로 잘못 인식 게 아니다 싶다 마크다운 url 태그 alt 링크 주소 여기 대괄호 앞뒤 escape 문자 backtick x 60 써다 보다 github 늘다 꿈쩍 않다 내다 독촉 장 보내오다 깃 허다 블로그 build 실패하다 오류 원인 알다 메일 오다 2시간 동안 저 대괄호 붙잡다 삽질 하다 gg 치
# 체크 1 Django 스터디 첫 스터디 발표 MTV 이다 Django 가다 어떻다 돌아가다 설명 하다 위 발표 이다 너무 장황하다 오히려 더 복잡하다 느껴지다 것 같다 발표 끝나다 모두 침울하다 분위기 다시 분위기 띄우다 애씄다 오늘 전공 강의 배우다 것 x 27 선택 집중 x 27 이다 너무 많다 것 전달 하다 보다 핵심 놓치다 게 아니다 싶다 질문 받다 내 안다 생각 하다 것 들 사실 모르다 것 더 공부 열심히 하다 느끼다 질문 받다 않다 안다 착각 채 공부 하다 못 하다 것 나다 많이 질문 하다 것 스터디 원 들 많이 질문 하다 좋다 2 자바스크립트 기본 문
# 체크 1 R 프로그래밍 문자열 문자열 뒤지다 정규분포 카이 제곱 검증 함수 구현 하다 dotchart ggvis tapply 카이 제곱 검증 함수 삐걱 거리 기 시작 하다 그 이후 강의 와르르 프로그래밍 문제 아니다 통계 지식 더 중요하다 것 같다 통계 지식 없다 이 함수 왜 필요하다 어떻다 용도 쓰다 알 수 없다 연장 들다 쓰다 못 하다 상태 2 서울 인구 대비 CCTV 설치 현황 데이터 분석 파이썬 데이터 주물 주물 하다 라이브러리 matplotlib numpy pandas pandas 기초 matplotlib 시각 화하다 일반 적 서울 인구 비례 하다 인구 당 CCTV 비율 높아지다 다만 이 경향
# 만 델브 셋 튜토리얼 하다 tensorflow 설치 1시간 삽질 후 정리 하다 글 텐서 플로우 설치다 2 단계 텐서 플로우 설치 전 설치 환경 확인 설치 환경 적합하다 tensorflow 설치 1 설치 환경 1 32 bit 64 bit 텐서 플로우 윈도우 64 비트 python 3.5 x 또는 3.6 x 버전 지원 다 만약 tensorflow 설치 안되다 찾아오다 내 아나콘다 설치 되다 경로 가다 anaconda 의 bit 를 확인 32 bit 라면 64 bit 로 다시 깔다 2 버전 확인 텐서 플로우 python 3.6 지원 파이썬 버전 확인 커맨드 라인 아나콘다 프롬프트 실행 python 3.7 은 아나콘다 다운 그레이드 하다 하다 버전 다
# 체크 1 Javascript 기본 문법 정규표현식 변수 유효 범위 콜백 함수 비 동기 처리 AJAX 클로저 유사 배열 arguments apply 2 Pandas 핵심 functions groupby drop drop duplicates duplication apply map applymap concat unique 등등 강의 마치 수료증 주다 주다 강의 있다 안주 강의 있다 3 R 프로그래밍 value match which dataframe tidyr dice simulation barplot 데이터 애 널리 틱 스 강의 R 프로그래밍 필수 독학 시작 하다 생각 재밌다 시각 화가 편리하다 Pandas 오다 비슷하다 명령어 문법 있다 많이 낯설다 않다 다만 index 가다 0 이 아니다 1 부터 시작 하다 것 슬
# 1 문제 상황 아나콘다 프롬프트 import pandas import tensorflow import sklearn 하다 정상 적 실행 되다 그러나 같다 python 환경 주피터 노트북 no name module x 27 pandas x 27 오다 같다 에러 뜸 주피터 pip install pandas 명령 실행 시키다 아래 같다 문구 뜨다 ※ 참고 tensorflow 설치 안되다 사람 이 포스팅 확인 하다 바라다 2 해결 방법 1 원인 주피터 노트북 커널 잘 못 되다 경로 있다 python 환경 가리키다 있다 경우 라이브러리 인식 하다 못 하다 2 해결 아나콘다 프롬 프트 열기 python 환경 실행 프롬프트 아래 명령어 입력 하다 에러 나다 있다 환경
# 체크 1 javascript 웹 Object Model BOM 전역 객체 Window alert console log confirm prompt 2 javacript 기본 문법 줄 바꿈 여백 UI 오다 API 문서 3 machine learing kNN 나 이브 베 이즈 선형 회귀 kmean 클러스터링 kaggle 타이타닉 생존자 예측 하다 4 Twitter Crawling 참고 파이썬 이용 트위터 크롤 링 Medium python 트위터 크롤 링 환경 python 3.5 jupyter chromedriver 사용 되다 라이브러리 beautifulsoup selenium pandas matplotlib 코드 목적 2월 15일 부터 3월 4일 까지의 코멘트 중 x 27 KIA x 27 키 워드 빈도 수 측정 다음 텍스트 전 처리 위 NLP
# 체크 1 react native 로 날씨 앱 만들기 노마드 코더 개발 환경 expo npm node js 안드로이드 폰 안드로이드 애뮬 레이 터 react native 관련 개념 loading view weather view error 메시지 출력 아이콘 API 호출 2 파이썬 프로그래밍 입문 끝 박 연오 블로그 텍스트 양식 화 re 정규 표현 식 datetime time 모듈 파일 디렉터리 다루다 웹 정보 주고받다
# 체크 1 독서 파이썬 코딩 기술 PEP 8 표준 파이썬 코딩 하다 p 37 p 114
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 1 번 채다 터 털 이해 하다 SQL JOIN 은 캐글 관련 없다 Kaggle JOIN 알다 INNER JOIN 안 나오다 내용 추가 하다 1 털 이해 하다 SQL JOIN 퇴사 전 SQL 속성 강의 하다 때 예시 위해 사용 하다 짤 캐글 SQL BigQuery 과정 InnerJoin 대한 실습 나오다 있다 아래 짤 보다 후 설명 들다 JOIN 의 이해 더 쉬다 것 1 INNER JOIN 예 들다 x 27 학생 x 27 테이블 x 27 신청 과목 x 27 테이블 있다 때 x 27 학생 x 27 테이블 x 27 id x 27 컬럼 x 27 신청 과목 x 27 테이블 x 27 student id x
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 Aliasing 그리고 임시 테이블 1 AS 별명 column table 원하다 이름 부르다 수 있다 x 27 AS x 27 늘다 생략 하다 수 있다 2 WITH AS AS 늘다 WITH 오다 함께 사용 하다 때 더 강력하다 WITH AS 로 만들다 테이블 CTE common table expression 하다 CTE 늘다 우리 쿼리 만들다 임시 테이블 임시 이기 때문 나중 다시 참조 하다 수 없다 위 같다 테이블 WITH AS 로 Seniors 새롭다 임시 테이블 만들다 그리고 이 테이블 조회 하다 임시 테이블 만들다 때 걸다 두다 조건 Years old gt 5 를 만족하다 row 들이다 나오다
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 1 Order by Order by 늘다 데이터 조회 하다 때 필수 아니다 하지만 방대하다 양 데이터 조회 하다 때 x 27 가독성 x 27 위해 혹은 데이터 순서 중요하다 때 꼭 필요하다 명령어 날짜 별로 날씨 정리 테이블 조회 다 고 하자 이 테이블 특이하다 점 날짜 별로 날씨 기록 하다 않다 것 억지스럽다 일단 상황 가정 해보다 whether 를 조회 하다 때 date 컬럼 조회 하다 테이블 순서 정리 하다 만약 내리다 차순 정리 싶다 컬럼 뒤 DESC 를 붙이다 descending 의 약자 2 Extract 특정 데이터 데이터 베
# 체크 1 파이썬 모듈 패키지 연오 세다 블로그 모듈 기능 별로 나누다 놓다 소스 코드 파일 라이브러리 다른 프로그램 포함 시키다 위해 기능 미리 나누다 묶다 놓다 것 표준 라이브러리 언어 함께 제공 되다 프로그래밍 필요하다 기본 기능 제 3 자 라이브러리 Third Party Library 비공식 적 누군가 만들다 모듈 최 상위 모듈 검사 패키지 모듈 파일 들 묶다 것 init py 패키지 디렉토리 x 27 패키지 x 27 로 인식 시키다 하다 init py 파일 생 성하다 하다 2 React 로 Movie Web App 만들기 노마드 코더 강의 gt 실습 총 4시간 강의 2시간 원래 React Nati
# 체크 1 Python 예외 처리 연오 세다 블로그 except 예외 1 예외 2 여러 예외 일괄 처리 raise 예외 예외 발생 시키다 assert 검증 식 처리 문 식 검증 예외 처리 특정 예외 처리 하다 수 없다 예외 유형 정의 Exception 클래스 상속 하다 예외 클래스 만들기 BaseException 직접 상속 하다 않다 finally 중복 코드 방지 하다 위해 exept 코드 블럭 끝나다 후 맨 마지막 실행 되어다 하다 코드 위치 시키다 2 django MTV 패턴 Django 프로젝트 구성 Django 앱 디자인 기본 오늘 정리 내용 MTV 패턴 좀 흥미롭다 소개 하다 수 없다 고민 하다 좋다 영상 발견 하다 블로그
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 1 강의 1 count 테이블 해당 컬럼 명 몇 개 존재 하다 지다 카운트 하다 알다 주다 count 늘다 컬럼 안 값 들 집계 연산 하다 집계 함수 중 하나 집계 함수 aggregation function avg sum 과 같다 함수 있다 집계 함수 컬럼 통해 많다 행 들 rows 인자 받다 결국 반환 하다 값 하나 평균 총 합 등 그렇다 때문 group by 오다 같이 어떻다 기준 결과 행 들 통합 하다 건지다 알다 하다 2 Group by student 테이블 studentID 오다 gender 컬럼 있다 이 때 학생 들 수 세다 남 여 학생 나누다 각각 몇 명 존
# 체크 1 아두이노 어제 받다 택배 뜯다 제품 확인 하다 아두이노 나노 USB 케이블 아귀 안 맞다 USB mini b 케이블 사다 이상하다 구글링 해보다 나노 용이 따로 있다 아두이노 날다 USB mini B 케이블 다시 구매 ㅠㅠ 2 하다 숟갈 더 스터디 Django Study 이름 욕심 많다 스터디 돼다 좋다 오늘 올리다 실습 환경 준비 하다 다수 사용 하다 github 블로그 운영 하다 되다 pull request 그리고 원본 저 장소 수정 사항 어떻다 반영 하다 fetch 또는 pull 알 돼다 3 박 연오 블로그 try except 공부 4 소켓 프로그래밍 참고 https://itsaessak.tistory.com/126Baccarat 코딩 하다 크다 라이
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 SQL 의 핵심 Select From Where 가다 나오다 select from where 만 알다 SQL 은 너무 재밌다 인턴 하다 때 처음 뭐 테이블 뭐 컬럼 로우 모르다 야근 하다 한참 헤매다 Select From 처음 쿼리 문 성공하다 때 감격 하다 기억 나다 크크 추억 팔이 kaggle 배우다 건 특이하다 SQL 쓰기 위해 DBeaver 나 TeamSQL 툴 사용 하다 하다 BigQuery 늘다 그렇다 필요 없다 SQL 쿼리 문 데이터 조회 이 데이터 변수 담다 BigQuery 의 함수 Pandas 데이터 프레임 바꾸다 주다 뭔 말 싶다 코드 보다 알 수 있다
# ※ 링크 참고 캐글 사이트 실습 하다 Fork 를 누르다 하다 hacker news 데이터 BigQuery 함수 설명 마지막 Chicago 의 범죄 관련 데이터 배우다 함수 활용 1 강의 1 BigQuery 임 포트 하다 import bq helper 2 BigQueryHelper 오브젝트 생 성 특정 데이터 셋 가리키다 위해 BigQueryHelper 오브젝트 생 성하다 하다 3 스키마 데이터 셋 구 조우리 원하다 데이터베이스 요청 query 하다 위해 스키마 이해해 하다 BigQueryHelper list tables 은 데이터 셋 안 테이블 들 리스트 업 하다 데이터베이스 자체 여러 개 테이블 들 갖다 있다 이 메서드 쓰다 hacker news 데이터
# 체크 1 Django 스터디 OT 커리어 개발 센터 11시 에서 스터디 OT 진행 간단하다 자기 소개 스터디 시간 및 장소 정함 진행 일정 공유 발표 순서 정함 다 들다 시간 여유 되다 github 블로그 작성 하다 수 있다 fork 뜨다 법 pull request 하다 법 배움 연오 세다 스터디 목차 대해 조언 구 해보다 튜토리얼 프로젝트 위주 실습 하다 게 좋다 판단 2 삼성 SDS 프로그래밍 멘토링 삼성 SDS 개발자 멘토링 강연 가깝다 인문 계열 비 전공자 위 SCSA 채용 과정 왜 삼성 SCSA 를 진행 하다 x 27 융 복합 인재 x 27 를 뽑기 위 하다 개발자 개발 하다 시대 넘어서다 사용자 어떻다
# 체크 1 Django 스터디 오리엔테이션 준비 jekyll now 템플릿 너무 단순하다 디자인 폰트 그리고 작성자 표시 하다 수 없다 다른 템플릿 바꾸다 jekyll jasper 로 바꾸다 위 요구 모두 만족하다 2 웹 myfolio 프로젝트 디테일 과정 추가 하다 위해 projects detail 페이지 추가 하다 3 웹 프로그래밍 튜토리얼 django 스터디 하다 때 발표 자 들이다 참고 하다 하다 사이트 찾다 좋다 웹 프로그래밍 튜토리얼 사이트 발견 하다 너무 깔끔하다 이 것 node js 연습 하다 ㅎ ㅎhttps://poiemaweb.com/
# 체크 1 Django 스터디 오리엔테이션 준비 github io 로 django study 블로그 만들기 Oritentation 내용 준비 필수 적 하다 하다 내용 회차 방식 스터디 규칙 등 마크다운 아직 익숙하다 않다
# 최우수상 최우수상 쵠 우리 누 루시 낭 최우수상 한숨 못자다 계속 django 만 붙잡다 있다 결과물 반영 안되다 아쉽다 장고 스터디 하다 꼭 취업 하다 전 저 때 완성 못 하다 거 완성 하다 아두이노 만들다 싶다 못 만들다 아쉽다 만들다 싶다 제품 위해 코코아 팹 알리 익스 프레 스 뒤 적 거리 다가 쿠팡 주문 하다 어떻다 만들다 모르다 구글 알다 것
# 계획 1 창업 메이커 톤 체크 1 창업 메이커 톤 21일 도서관 공부 하다 가다가 공대 게시판 메이커 톤 포스터 발견 3시간 전인 접수 참석 팀원 들 아이디어 회의
# 계획 1 웹 프로젝트 2 Baccarat 체크 1 버클리 대학 machine learning 강의 머신 러닝 온라인 스터디 거의 망하다 대안 버클리 대학 machine learning 강의 시작 하다 머신 러닝 필요하다 기초 개념 알다 주다 주피터 실습 하다 교수 님 주피터 보고 마크다운 쓰다 방법 단축키 등 주피터 추가 적 기능 알 돼다 ㅋ 배우다 내용 평균 중앙 값 표준편차 체비쇼프 부등식 2 구글 머신 러닝 단기 집중 과정 강의 실습 머신 러닝 용어 만 델브 집합 실습 fractal image 출력 하다 tensorflow 를 설치 하다 개발 환경 안 맞다 anaconda 를 다시 설치 하다 시간 많이
# 이번 문제 최저 경비 구 하다 문제 달러 대신 km 로 단위 바꾸다 최단 경로 구 하다 하다 수 있다 1 Atlanta 각 도시 가다 최저 경비 구 하다 여행 하다 때 이 도시 저 도시 정신없이 이동 다 고 하다 때 우리 어떻다 하다 가장 적다 경비 이동 하다 수 있다 이 문제 풀기 위해 다이크 스트 알고리즘 쓸다 수 있다 현재 노드 목적지 노드 가다 여러 노드 거치다 가야 하다 이 때 어느 경로 가야 가장 빨리 갈다 수 있다 구한 다 라우터 목적지 라우터 패킷 보내다 때 가장 빠르다 경로 찾다 라우팅 프로토콜 이 알고리즘 쓴다 하다 너비 우선 탐색 알고리즘 queue 인접 노드
# 1 우리 동네 이웃 사람 들 누구 이다 사교성 좋다 Alice 늘다 자신 마을 어떻다 사람 들 살 있다 궁금하다 각 집 다른 집의 사람 알 있다 하다 때 일방 적 알 있다 가정 하다 우리 네트워크 통해 이 마을 어떻다 집들이 있다 하나 하나 방문 하다 파악 해보다 수 있다 이미 방문 곳 방문 하다 않다 알고리즘 접근 하다 그래프 현재 노드 인접 노드 인접 노드 인접 노드 방문 함 현재 노드 전체 네트워크 파악 하다 말 하다 수 있다 전체 네트워크 파악 하다 위 방법 x 27 너비 우선 탐색 x 27 방법 써다 2 너비 우선 탐색 x 27 너비 우선 탐색 x 27 알고리즘
# 계획 1 웹 프로젝트 2 파이썬 스터디 3 Baccarat 4 토익 체크 1 웹 프로젝트 migrations 있다 폴더 건드리다 계속 에러 나서다 그냥 싹 밀다 버리다 새롭다 프로젝트 폴더 만들다 원격 깃 저 장소 연결하다 초기 화 현재 폴더 내용 깃 푸다 쉬 하다 그리고 다시 프로젝트 앱 설치 템플릿 폼 연결하다 1시간 안되다 걸리다 것 같다 다행하다 멀쩡하다 때 백업 하다 두다 있다 날다 먹다 놈 용서 하다 백업 안 하다 두다 놈 용서 안되다 그래도 백업 하다 두다 잘 하다 2 파이썬 스터디 종료 파이썬 스터디 마지막 날다 퇴사 후 파이썬 스터디 이유 매주 1회 씩 가다 퇴사 느낌 들다 않다
# 계획 1 웹 프로젝트 projects 페이지 model 연결 form 작성 2 자료 구조 알고리즘 그래프 알고리즘 문제 python 3 Baccarat sprites 객체 추가 하다 4 잡플래닛 등록 되다 가다 싶다 회사 직 군 등록 하다 5 파이썬 스터디 준비 체크 1 웹 프로젝트 project 카드 새롭다 만들다 편집 하다 때 redirect 하다 url 이 계속 뒤 덧붙이다 나오다 어떻다 하다 고민 하다 찰나 이 전혀 상관없다 곳 html 과 같다 형태 쓰다 걸 보고 혹시 하다 써다 보다 해결 돼다 2 Baccarat 메인 파일 있다 코드 거의 반 이상 줄이다 event 모이다 대부분 기능 sprites py 폴더 옮기다
# 1 이진트리 은진 송씨 족보 중 일부 시대 안 맞다 족보 타령 하다 건 아니다 족보 모습 이진트리 비슷하다 가져오다 족보 시조 있다 이진 트리 뿌리 있다 족보 각 세대 자손 수 다 다르다 하지만 이진트리 각 노드 최대 2 명 이하 자식 노드 두다 0 1 2 개 lt 이진 트리 노드 구현 소스코드 gt 그리고 이진 트리 하다 가지 특이하다 점 있다 부모 노드 값 작다 값 가지다 자식 왼쪽 크다 값 가지다 자식 오른쪽 배치 되다 이러하다 특징 덕분 이진 트리 이진 검색 같이 값 크기 비교 하다 경우 수 줄이다 수 있다 찾다 값 10 보다
# 계획 1 웹 프로젝트 2 알고리즘 알고리즘 문제 풀기 손 코딩 3 Baccarat 체크 1 웹 프로젝트 new edit 2 알고리즘 알고리즘 문제 풀기 손 코딩 9012 괄호 스택 사용 스택 이용 하다 여 괄호 나오다 스택 push 닫다 괄호 나오다 여 괄호 pop 하다 pop 하다 때 조건 분기 따르다 유효하다 괄호 그렇다 않다 answer 변수 저장 마지막 단계 answer 를 출력 하다 근데 왠 걸 계속 틀리다 테스트 케이스 틀다 다 맞다 예 외적인 상황 못자다 있다 뭘 끄다 중첩문 많다 수정 하다 3 Baccarat Baccarat 코드 너무 뒤죽박죽 pygame 책 보다 하나 씩 기능
# 계획 1 웹 프로젝트 디자인 끝내기 django 연결하다 2 Baccarat 체크 1 웹 프로젝트 디자인 끝내기 1 nav top nav 태그 클래스 안 있다 클래스 중 transparent 속성 갖다 클래스 이름 nav top 지다 javascript 스크롤 15 이상 내려가다 nav top 이 nav 태그 클래스 사라지다 그 뒤 있다 nav bg 가다 나타나다 2 smooth scroll css 파일 html 태그 scroll behavior smooth 를 주다 페이지 내 이동 시 부드럽다 이동 다 3 slow image load image 가다 늦다 로드 되다 문제 해결 하다 django 연결하다 2 Baccarat 3 java 의 정석 p 57 p 136 연산자 새벽
# 계획 1 웹 프로젝트 css 다듬다 2 자료 구조 알고리즘 알고리즘 문제 풀기 박 연오 블로그 파이썬 8 장 3 Baccarat 카드 deal 눈 보이 하다 체크 1 웹 프로젝트 projects 페이지 스 크롤 바 디자인 얇다 프로젝트 카드 디자인 스 와이프 슬라이드 2 자료 구조 알고리즘 알고리즘 문제 풀기 부녀회 장이 되다 개연 성 떨어지다 내용 문제 몰입 하다 어렵다 재귀 쓰다 저번 주 배우다 리스트 조건 제시 법도 쓰다 if 조건 부식 쓰다 스터디 배우다 내용 활용 하다 lt 문제 gt 백 준 2775 번 lt 풀이 gt 박 연오 블로그 파이썬 8 장 1~2 같다 값 가지다 유형 객
# 1 연결 리스트 큐 기존 연결 리스트 바로 다음 노드 가리키다 따라서 끝 노드 찾기 위 하다 연결 리스트 처음 찾다 야하다 때문 O N 이 걸리다 하지만 이중 연결 리스트 앞 뒤 노드 동시 가리키다 앞 뒤 하다 번 맨 끝 노드 접근 하다 수 있다 따라서 맨 끝 노드 읽다 검색 삽입 삭제 모두 O 1 이렇다 이중 연결 리스트 특징 어디 활용 하다 수 있다 바로 큐 스택 선입후 추다 FILO 방식 삭제 하다 때 맨 끝 데이터 삭제 하다 이다 이중 연결 리스트 좋다 배열 맨 끝 데이터 삭제 하다 O 1 이 걸리다 때문 연결 리스트 배열 특별하다 좋다 것 없다 하지만
# 계획 1 웹 프로젝트 css 다듬다 2 파이썬 프로그래밍 알고리즘 문제 풀이 박 연오 블로그 파이썬 8 장 3 Baccarat 체크 1 웹 프로젝트 css 다듬다 about me features projects 페이지 features 파트 3 칸 나누다 col md 4 클래스 12 의 공간 3등 분하면 되다 이 때 세로 쌓이다 때문 display flex flex wrap 속성 가지다 row 로 감싸다 2 파이썬 프로그래밍 알고리즘 문제 풀이 박 연오 블로그 파이썬 8 장 3 Baccarat 게임 진행 위 코드 모두 작성 하다 더불다 user 의 점수 랭크 프로필 추가 하다 처음 만들다 때 메인 파일 모두 게임 진행 내용 넣다
# 배열 읽다 O 1 를 제외 연결 리스트 배열 연산 효율 비슷하다 수치 적 보다 연결 리스트 효율 성은 그리다 좋다 않다 하지만 연결 리스트 특징 x 27 연결 x 27 생각 하다 쓸다 만하 그렇다 연결 리스트 어떻다 경우 효과 적 쓸다 수 있다 하다 리스트 검사 하다 x 27 많다 원소 x 27 를 x 27 삽입 x 27 x 27 삭제 x 27 하다 때 연결 리스트 삽입 삭제 자체 실행 단계 1 번 뿐 많다 원소 x 27 삭제 x 27 하다 경우 예 들다 보다 배열 삭제 하다 때 빈 공간 메 꾸다 위해 오른쪽 데이터 왼쪽 하다 칸 씩 옮기다 하다 즉 O N 이 걸리다 따라서 전체 원소 개수 N 이
# 연결 리스트 읽다 검색 효율 성은 O N 그리다 효율 적 않다 삽입 삭제 어떻다 일반 배열 경우 중간 데이터 삽입 혹은 삭제 하다 위해 그 오른쪽 데이터 들 하다 칸 씩 밀다 당기다 하다 연결 리스트 중간 연결 끊다 뒤 새롭다 노드 다음 노드 연결하다 삭제 그저 노드 삭제 뒤 끊어지다 노드 끼리 연결하다 결론 말 하다 삽입 삭제 자체 들다 실행 단계 1 번 삽입 및 삭제 하다 노드 자리 찾기 위 하다 읽다 단계 N 번 수행 하다 하다 직접 해보다 확인 하다 1 연결 리스트 노드 삽입 1 노드 삽입 과정 중간 새롭다 노드 삽입 하다 노드 생 성 새롭다 노
# 계획 1 웹 프로젝트 css 다듬다 2 자료 구조 알고리즘 다이크 스트 알고리즘 공간 복 잡다 공부 알고리즘 문제 3 Baccarat 카드 dealing 코드 만들기 4 가다 싶다 회사 직 군 정 하다 5 토익 공부 체크 1 웹 프로젝트 css 다듬다 부트스트랩 이용 하다 css 를 다듬다 navigation bar 그 다음 div container 가다 계속 하다 시간 잡아먹다 div container 커버 사진 넣다 nav 영역 사진 확장 하다 보여주다 하다 nav 영역 먹히다 않다 그래서 nav 영역 다음 같다 속성 주다 z index 늘다 레이어 순서 보다 되다 ppt 를 쓸다 때 x 27 맨 앞 보내다 맨 뒤 보내다 x 2
# 체크 파이썬 스터디 준비 스터디 하다 좋다 게 내 공부 하다 간 부분 확실하다 공부 되다 동시 다른 사람 지식 덤 얻다 수 있다 좋다 오늘 연오 님 새롭다 걸 많이 배우다 배우다 스터디 전 버스 읽다 파이썬 프로그래밍 나오다 x 27 리스트 조건 제 시법 x 27 그대로 알다 재밌다 정말 표지 따분하다 그 없다 내용 너무 너무 좋다 책 오늘 발표 것 오늘 배우다 것
# 저번 포스팅 연결 리스트 어떻다 것 인 알다 이번 포스팅 연결 리스트 어떻다 연산 강점 발휘 하다 지다 알아보다 먼저 연산 하다 전 저번 포스팅 노드 데이터 숫자 알파벳 살짝 바꾸다 또 마지막 노드 데이터 없애다 파이썬 null 은 None 1 읽다 특정 인덱스 값 찾다 연결 리스트 따라가다 위해 curr node 오다 next node 를 만들다 각 노드 가리키다 포인터 같다 것 생각 하다 되다 현재 노드 가리키다 첫 번째 노드 head 를 정 해주다 현재 index 늘다 0 curr index x 3 D 1 다음 노드 옮기다 때 curr index 를 하다 차례 씩 늘리다 re
# 1 파이썬 스크립트 언어 스크립트 언어 정의 파이썬 스크립트 언어 늘 아 그렇다 구나 넘어가다 x 27 스크립트 x 27 언어 대해 알아보다 하다 스크립트 언어 연극 용어 따오다 말 연극 x 27 스크립트 x 27 늘다 배우 대사 중점 배우 표정 등장 퇴장 무대 장 치다 중심 지시 하다 내용 말 하다 아래 예시 위해 가져오다 스크립트 샘플 심심하다 읽다 보다 프로그래밍 x 27 스크립트 언어 x 27 의 역할 생각 해보다 왜 스크립트 하다 이해 되다 것 프로그래밍 스크립트 언어 기존 이미 존재 하다 소프트웨어 제어 하다 위 용도 쓰이다 언어
# 1 매핑 1 매핑 키 값 형식 저장 되다 데이터 다른 언어 해시 맵 해시 테이블 하다 읽다 검색 연산 시 실행 단계 하다 번 걸리다 않다 때문 효율 적 2 시퀀스 매핑 시퀀스 순서 있다 데이터 나열 값 찾다 때 인덱스 처음 값 나오다 때 찾다 매핑 순서 없다 값 찾다 때 키 이용 값 찾다 때 x 27 키 x 27 를 이용 하다 하다 번 값 찾다 3 사전 사전 직접 정의 하다 경우 기본 값 사전 사전 기본 적 형태 정의 해주다 경우 2 기본 값 사전 default dict 1 기본 값 사전 쓰다 이유 뭘 끄다 뭐 불편하다 만들다 이유 이유 항상
# 계획 1 자료 구조 알고리즘 그래프 알고리즘 문제 python 2 Baccarat 3 파이썬 스터디 준비 중첩 컬렉션 생 성 및 순회 체크 1 자료 구조 알고리즘 그래프 데이크스트라 알고리즘 그래프 각 노드 다른 노드 가다 가장 빠르다 경로 구한 다 고 하다 때 바로 라우터 생각나다 실제 데이크스트라 알고리즘 라우팅 프로토콜 사용 되다 하다 책 배우다 Atlanta 다른 도시 가다 최단 경비 구 하다 알고리즘 파이썬 구현 하다 데이크스트라 알고리즘 일반 적 형태 아니다 바로 전 배우다 너비 우선 탐색 알고리즘 이용 하다 각 도시 및 경로 구성 하다 각 도시 가다
# 계획 1 자료 구조 알고리즘 그래프 데이터베이스 알고리즘 문제 C 2 Baccarat betting 기능 만들기 체크 1 자료 구조 알고리즘 그래프 데이터베이스 가중 그래프 알고리즘 문제 C 아침 백 준 알고리즘 문제 중 x 27 벌집 x 27 최소 경로 구 하다 문제 풀다 등비수열 금방 풀다 계속 하다 에러 나다 아무리 보다 완벽 해보다 뭐 문 제일 끄다 왜 시간 초과 나오다 걸다 해보다 너무 간단하다 조건 빼먹다 있다 범위 비교 하다 위해 각 degree 의 첫 수 마지막 수 구 하다 while 루프 문 첫 수 무조건 2 부터 시작 하다 때문 목적지 숫자 1 인 경우 if 문 들어가다
# 계획 1 웹 프로젝트 projects 페이지 model 연결 form 작성 2 자료 구조 알고리즘 그래프 알고리즘 문제 python 3 Baccarat sprites 객체 추가 하다 체크 1 웹 프로젝트 에러 The view didn x 27 t return an HttpResponse object x 27 form x 27 referenced before assigned form 이 선언 되다 않다 어떻다 참조 하다 lt 틀리다 코드 gt 1 첫 번째 에러 해결 KEY request 따르다 return 하다 응답 달라지다 하다 각 요청 대한 응답 준비 하다 두다 하다 페이지 접근 하다 보이다 달라 건 get 요청 그런데 이 코드 보다 모든 대응 if request method x 3 D x 3 D quot POST quot 안
# 참고 서적 컴퓨터 과학 데이터 과학 입문 위 파이썬 프로그래밍 1 알고리즘 계산 적 사다 모든 지식 x 27 서술 적 지식 x 27 과 x 27 절차 적 지식 x 27 나뉘다 서술 적 지식 사실 진술 것 x 27 1 1 x 3 D 2 x 27 너무나 자명하다 사실 우리 어리다 아이 1 1 이 왜 2 인지 설명 하 하다 설명 하다 못 하다 서술 적 지식 있다 절차 적 지식 없다 나다 없다 절차 적 지식 1 1 값 2 가다 맞다 증명 하다 데 각 단계 있다 조건문 따르다 실행 흐름 통제 되다 기도 하다 이르다 증명 하다 x 27 페아노 공리 계 x 27 것 있다 하다 이렇다 과정 알고리즘 하다
# 1 MVC Model View Controller 프로그램 개발 하다 때 어떻다 방법 개발 하다 지다 설계 것 디자인 패턴 하다 개발자 디자인 패턴 특정하다 규칙 따르다 프로그램 개발 하다 MVC 늘다 그렇다 디자인 패턴 하다 종류 2 M V C 의 역할 MVC 의 가장 크다 특징 이자 장점 하다 수 있다 것 사용자 x 27 보이다 영역 x 27 과 사용자 요청 x 27 처리 하다 영역 x 27 분리 시키다 놓다 것 보이다 영역 x 27 view x 27 담당 하다 처리 영역 x 27 controller x 27 담당 다 controller view 오다 model 컨트롤 하다 사용자 요청 처리 하다 view controller 로부터 요청 받다 그
# 1만 개 별 찍다 데 걸리다 시간 얼마 이다 별찍기 문제 하다 생각나다 것 이중 for 문 하지만 이중 for 문 사용 하다 않다 직사각형 별 찍다 방법 3 가지 더 있다 풀다 방식 풀 어떻다 게 좋다 어떻다 게 나쁘다 알 못 하다 그래서 C 오다 파이썬 다양하다 방식 접근 하다 하다 이중 반복 문 단일 반복 문 그리고 아예 반복 문 쓰다 않다 가장 빨리 별 찍 수 있다 방법 소개 다 1 이중 for 문 가장 먼저 떠오르다 이중 for 문 2 for 문 amp if 문 문제 푼 후 혹시 이중 for 문 외 다른 방식 문제 푼 사람 있다 찾아보다 스크롤 한참 내다 없다 x 27 없다 x 27 하다 이중 f
# 계획 1 웹 프로젝트 projects 페이지 모델 연결 form 만들기 2 자료 구조 알고리즘 이진 트리 마무리 활용 알고리즘 문제 C 로 풀기 3 Baccarat pygame 4 개발 용어 공부 MVC 체크 1 웹 프로젝트 projects 페이지 모델 연결 form 만들기 2 자료 구조 알고리즘 이진 트리 마무리 활용 알고리즘 문제 C Python 직사각형 별 찍기 흔하다 이중 for 문 처리 하다 것 하지만 직사각형 별찍기 3 가지 방법 풀 수 있다 같다 문제 매번 푸다 방식 풀 더 나은 방법 찾다 수 없다 또 어떻다 게 나쁘다 어떻다 게 좋다 방법 알 못 하다 같다 문제 다양
# 1 비즈니스 로직 사용자 눈 보이지 않다 사용자 요청 처리 하다 위해 어플리케이션 동작 하다 방식 구조 화하다 것 쉬다 말 하다 문제 또는 요청 해결 하다 과정 내 블로그 포스팅 하다 것 내 입장 아주 간단하다 일이 하지만 작성 중인 텍스트 어떻다 보여주다 포스팅 업로드 하다 데이터베이스 어떻다 저장 되다 이전 포스팅 어떻다 보여주다 건지다 로직 처리 하다 사용자 모르다 되다 사용자 서비스 이용 하다 위해 프로그래머 의하다 구상 되다 부분 실제 동작 코드 의하다 실행 되다 코드 만들어지다 각 객체 어떻다 활용 어떻다 과정 처리 하다 지다 결정 하다

# %%
data_file = 'my_text'

with open(data_file, 'w', encoding='utf=8') as fp :
    fp.write("\n".join(results))

# %%
data = word2vec.LineSentence(data_file)
model = word2vec.Word2Vec(data, size=200, window=10, hs=1, min_count=2, sg=1)

model.save('my_text.data')

# %%
model = word2vec.Word2Vec.load("my_text.data")

# %%
model.most_similar(positive=['연오'])
# Out:
# C:\Users\guseo\AppData\Local\conda\conda\envs\py35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('블로그', 0.9947835803031921),
#  ('8', 0.9940285682678223),
#  ('작성', 0.9934390187263489),
#  ('C', 0.9913380146026611),
#  ('준비', 0.9901577234268188),
#  ('카드', 0.9899927973747253),
#  ('3', 0.988692045211792),
#  ('박', 0.9838689565658569),
#  ('풀기', 0.9838278889656067),
#  ('만들기', 0.9830283522605896)]
